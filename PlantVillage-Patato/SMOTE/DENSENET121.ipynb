# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']


train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Patato/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 2152 images belonging to 3 classes.
# (2152, 224, 224, 3)
# (2152, 3)

# %%
#Converting  our color images to a vector
x=x.reshape(2152,224*224*3)

# %%
x.shape
# Out:
# (2152, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (3000, 150528)

# %%
y_smote.shape
# Out:
# (3000, 3)

# %%
X_smote=X_smote.reshape(3000,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (2152, 150528)
# Shape of X after SMOTE: (3000, 224, 224, 3)

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (3000, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
from keras.applications.densenet import DenseNet121
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = densenet(x)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(3,activation = 'softmax', name='root')(x)

    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_dense = build_densenet()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 3)       84
#
#  densenet121 (Functional)    (None, None, None, 1024   7037504
#                              )
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  batch_normalization (Batch  (None, 1024)              4096
#  Normalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 3)                 771
#
# =================================================================
# Total params: 7305879 (27.87 MB)
# Trainable params: 7219671 (27.54 MB)
# Non-trainable params: 86208 (336.75 KB)
# _________________________________________________________________

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist_dense=model_dense.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 0.5964 - accuracy: 0.7950
# Epoch 1: val_accuracy improved from -inf to 0.59833, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - 107s 965ms/step - loss: 0.5964 - accuracy: 0.7950 - val_loss: 0.9118 - val_accuracy: 0.5983
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9692
# Epoch 2: val_accuracy improved from 0.59833 to 0.71167, saving model to best_model.h5
# 38/38 [==============================] - 28s 735ms/step - loss: 0.0920 - accuracy: 0.9692 - val_loss: 0.6951 - val_accuracy: 0.7117
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9883
# Epoch 3: val_accuracy improved from 0.71167 to 0.80333, saving model to best_model.h5
# 38/38 [==============================] - 29s 758ms/step - loss: 0.0368 - accuracy: 0.9883 - val_loss: 0.4674 - val_accuracy: 0.8033
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9954
# Epoch 4: val_accuracy improved from 0.80333 to 0.85667, saving model to best_model.h5
# 38/38 [==============================] - 29s 759ms/step - loss: 0.0193 - accuracy: 0.9954 - val_loss: 0.3326 - val_accuracy: 0.8567
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9975
# Epoch 5: val_accuracy improved from 0.85667 to 0.89000, saving model to best_model.h5
# 38/38 [==============================] - 28s 751ms/step - loss: 0.0108 - accuracy: 0.9975 - val_loss: 0.2656 - val_accuracy: 0.8900
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9975
# Epoch 6: val_accuracy did not improve from 0.89000
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0091 - accuracy: 0.9975 - val_loss: 0.3134 - val_accuracy: 0.8833
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9975
# Epoch 7: val_accuracy improved from 0.89000 to 0.93833, saving model to best_model.h5
# 38/38 [==============================] - 29s 758ms/step - loss: 0.0104 - accuracy: 0.9975 - val_loss: 0.1758 - val_accuracy: 0.9383
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9987
# Epoch 8: val_accuracy improved from 0.93833 to 0.94500, saving model to best_model.h5
# 38/38 [==============================] - 29s 755ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.1532 - val_accuracy: 0.9450
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9975
# Epoch 9: val_accuracy improved from 0.94500 to 0.96500, saving model to best_model.h5
# 38/38 [==============================] - 29s 768ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.0972 - val_accuracy: 0.9650
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9992
# Epoch 10: val_accuracy improved from 0.96500 to 0.98333, saving model to best_model.h5
# 38/38 [==============================] - 29s 755ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.0448 - val_accuracy: 0.9833
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9992
# Epoch 11: val_accuracy improved from 0.98333 to 0.98667, saving model to best_model.h5
# 38/38 [==============================] - 29s 758ms/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.0310 - val_accuracy: 0.9867
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9996
# Epoch 12: val_accuracy improved from 0.98667 to 0.98833, saving model to best_model.h5
# 38/38 [==============================] - 29s 757ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.0320 - val_accuracy: 0.9883
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 13: val_accuracy improved from 0.98833 to 0.99167, saving model to best_model.h5
# 38/38 [==============================] - 29s 757ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0171 - val_accuracy: 0.9917
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9917
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 15: val_accuracy improved from 0.99167 to 0.99333, saving model to best_model.h5
# 38/38 [==============================] - 29s 758ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9933
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 16: val_accuracy improved from 0.99333 to 0.99500, saving model to best_model.h5
# 38/38 [==============================] - 29s 759ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0068 - val_accuracy: 0.9950
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 8.3280e-04 - accuracy: 1.0000
# Epoch 17: val_accuracy improved from 0.99500 to 0.99833, saving model to best_model.h5
# 38/38 [==============================] - 29s 757ms/step - loss: 8.3280e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9983
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 18: val_accuracy improved from 0.99833 to 1.00000, saving model to best_model.h5
# 38/38 [==============================] - 29s 758ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 8.3590e-04 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 8.3590e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 8.8986e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 8.8986e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 21: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0066 - val_accuracy: 0.9967
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 22: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0056 - val_accuracy: 0.9983
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 24: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 730ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9992
# Epoch 25: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 726ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9992
# Epoch 26: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0061 - val_accuracy: 0.9983
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9979
# Epoch 27: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9983
# Epoch 28: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0123 - val_accuracy: 0.9967
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9996
# Epoch 29: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.0058 - val_accuracy: 0.9983
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 30: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0075 - val_accuracy: 0.9983
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 31: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0038 - val_accuracy: 0.9983
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 5.1202e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 5.1202e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 0.9983
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 7.8306e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 7.8306e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9983
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 4.0433e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 4.0433e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9983
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 35: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0051 - val_accuracy: 0.9983
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 8.9802e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 8.9802e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9983
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9996
# Epoch 37: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.0027 - val_accuracy: 0.9983
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9992
# Epoch 38: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 729ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0044 - val_accuracy: 0.9983
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 39: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0029 - val_accuracy: 0.9983
# Epoch 40/100
# 38/38 [==============================] - ETA: 0s - loss: 6.2666e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 6.2666e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 0.9983
# Epoch 41/100
# 38/38 [==============================] - ETA: 0s - loss: 5.2592e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 5.2592e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 0.9983
# Epoch 42/100
# 38/38 [==============================] - ETA: 0s - loss: 6.6484e-04 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 6.6484e-04 - accuracy: 1.0000 - val_loss: 9.0385e-04 - val_accuracy: 1.0000
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 4.5538e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 4.5538e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 44/100
# 38/38 [==============================] - ETA: 0s - loss: 6.2732e-04 - accuracy: 0.9996
# Epoch 44: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 6.2732e-04 - accuracy: 0.9996 - val_loss: 0.0023 - val_accuracy: 0.9983
# Epoch 45/100
# 38/38 [==============================] - ETA: 0s - loss: 4.9350e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 726ms/step - loss: 4.9350e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9983
# Epoch 46/100
# 38/38 [==============================] - ETA: 0s - loss: 3.8728e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 3.8728e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9983
# Epoch 47/100
# 38/38 [==============================] - ETA: 0s - loss: 5.2521e-04 - accuracy: 0.9996
# Epoch 47: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 5.2521e-04 - accuracy: 0.9996 - val_loss: 0.0020 - val_accuracy: 0.9983
# Epoch 48/100
# 38/38 [==============================] - ETA: 0s - loss: 4.8891e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 4.8891e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 0.9983
# Epoch 49/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9987
# Epoch 49: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0065 - val_accuracy: 0.9983
# Epoch 50/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9979
# Epoch 50: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0104 - val_accuracy: 0.9967
# Epoch 51/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 51: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0049 - val_accuracy: 0.9983
# Epoch 52/100
# 38/38 [==============================] - ETA: 0s - loss: 7.0606e-04 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 7.0606e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9983
# Epoch 53/100
# 38/38 [==============================] - ETA: 0s - loss: 4.9973e-04 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 4.9973e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9983
# Epoch 54/100
# 38/38 [==============================] - ETA: 0s - loss: 7.4420e-04 - accuracy: 0.9996
# Epoch 54: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 7.4420e-04 - accuracy: 0.9996 - val_loss: 0.0086 - val_accuracy: 0.9983
# Epoch 55/100
# 38/38 [==============================] - ETA: 0s - loss: 4.0762e-04 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 729ms/step - loss: 4.0762e-04 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9983
# Epoch 56/100
# 38/38 [==============================] - ETA: 0s - loss: 6.1352e-04 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 6.1352e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9983
# Epoch 57/100
# 38/38 [==============================] - ETA: 0s - loss: 2.6180e-04 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 2.6180e-04 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9983
# Epoch 58/100
# 38/38 [==============================] - ETA: 0s - loss: 2.8900e-04 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 2.8900e-04 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9967
# Epoch 59/100
# 38/38 [==============================] - ETA: 0s - loss: 2.7707e-04 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 2.7707e-04 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9983
# Epoch 60/100
# 38/38 [==============================] - ETA: 0s - loss: 5.6900e-04 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 5.6900e-04 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9983
# Epoch 61/100
# 38/38 [==============================] - ETA: 0s - loss: 9.8137e-04 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 729ms/step - loss: 9.8137e-04 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9983
# Epoch 62/100
# 38/38 [==============================] - ETA: 0s - loss: 2.0584e-04 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 726ms/step - loss: 2.0584e-04 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9983
# Epoch 63/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8059e-04 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 1.8059e-04 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9983
# Epoch 64/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6624e-04 - accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 1.6624e-04 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 0.9983
# Epoch 65/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2736e-04 - accuracy: 1.0000
# Epoch 65: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 1.2736e-04 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9983
# Epoch 66/100
# 38/38 [==============================] - ETA: 0s - loss: 3.0130e-04 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 3.0130e-04 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9983
# Epoch 67/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 67: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0074 - val_accuracy: 0.9983
# Epoch 68/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9987
# Epoch 68: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0022 - accuracy: 0.9987 - val_loss: 0.0310 - val_accuracy: 0.9933
# Epoch 69/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9983
# Epoch 70/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 70: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0112 - val_accuracy: 0.9983
# Epoch 71/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9979
# Epoch 71: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0103 - accuracy: 0.9979 - val_loss: 0.0038 - val_accuracy: 0.9983
# Epoch 72/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9946
# Epoch 72: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 729ms/step - loss: 0.0135 - accuracy: 0.9946 - val_loss: 0.1636 - val_accuracy: 0.9617
# Epoch 73/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9987
# Epoch 73: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.0146 - val_accuracy: 0.9933
# Epoch 74/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9975
# Epoch 74: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 726ms/step - loss: 0.0064 - accuracy: 0.9975 - val_loss: 0.2467 - val_accuracy: 0.9500
# Epoch 75/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9979
# Epoch 75: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.7141 - val_accuracy: 0.8850
# Epoch 76/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9954
# Epoch 76: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0191 - accuracy: 0.9954 - val_loss: 0.2906 - val_accuracy: 0.9317
# Epoch 77/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9987
# Epoch 77: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0134 - val_accuracy: 0.9950
# Epoch 78/100
# 38/38 [==============================] - ETA: 0s - loss: 7.0064e-04 - accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 7.0064e-04 - accuracy: 1.0000 - val_loss: 3.9978e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 38/38 [==============================] - ETA: 0s - loss: 6.7015e-04 - accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 6.7015e-04 - accuracy: 1.0000 - val_loss: 2.5294e-04 - val_accuracy: 1.0000
# Epoch 80/100
# 38/38 [==============================] - ETA: 0s - loss: 4.3090e-04 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 4.3090e-04 - accuracy: 1.0000 - val_loss: 3.0522e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8458e-04 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 1.8458e-04 - accuracy: 1.0000 - val_loss: 2.4205e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 38/38 [==============================] - ETA: 0s - loss: 2.8353e-04 - accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 2.8353e-04 - accuracy: 1.0000 - val_loss: 1.5715e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 38/38 [==============================] - ETA: 0s - loss: 2.6536e-04 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 2.6536e-04 - accuracy: 1.0000 - val_loss: 1.7213e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 38/38 [==============================] - ETA: 0s - loss: 2.4485e-04 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 2.4485e-04 - accuracy: 1.0000 - val_loss: 1.0462e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 38/38 [==============================] - ETA: 0s - loss: 5.6978e-04 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 5.6978e-04 - accuracy: 1.0000 - val_loss: 1.5329e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9996
# Epoch 86: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.0076 - val_accuracy: 0.9967
# Epoch 87/100
# 38/38 [==============================] - ETA: 0s - loss: 2.7861e-04 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 2.7861e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 88/100
# 38/38 [==============================] - ETA: 0s - loss: 2.6235e-04 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 2.6235e-04 - accuracy: 1.0000 - val_loss: 3.3980e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 38/38 [==============================] - ETA: 0s - loss: 3.4451e-04 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 729ms/step - loss: 3.4451e-04 - accuracy: 1.0000 - val_loss: 2.1330e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6623e-04 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 729ms/step - loss: 1.6623e-04 - accuracy: 1.0000 - val_loss: 1.2676e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 38/38 [==============================] - ETA: 0s - loss: 7.1345e-05 - accuracy: 1.0000
# Epoch 91: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 7.1345e-05 - accuracy: 1.0000 - val_loss: 1.1126e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5973e-04 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 1.5973e-04 - accuracy: 1.0000 - val_loss: 1.0387e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 38/38 [==============================] - ETA: 0s - loss: 2.0278e-04 - accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 2.0278e-04 - accuracy: 1.0000 - val_loss: 1.3806e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 38/38 [==============================] - ETA: 0s - loss: 7.2511e-05 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 7.2511e-05 - accuracy: 1.0000 - val_loss: 1.2693e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1041e-04 - accuracy: 1.0000
# Epoch 95: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 729ms/step - loss: 1.1041e-04 - accuracy: 1.0000 - val_loss: 1.1387e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 38/38 [==============================] - ETA: 0s - loss: 4.3605e-04 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 729ms/step - loss: 4.3605e-04 - accuracy: 1.0000 - val_loss: 1.8865e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 38/38 [==============================] - ETA: 0s - loss: 7.7717e-05 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 7.7717e-05 - accuracy: 1.0000 - val_loss: 2.6494e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9992
# Epoch 98: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 99/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 99: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 728ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0064 - val_accuracy: 0.9967
# Epoch 100/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 100: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 28s 727ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 4.2830e-04 - val_accuracy: 1.0000

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 19/19 [==============================] - 3s 93ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("SquezeNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# SquezeNet MODEL SONUÇLARI
# Doğruluk:  1.0
# F1_Skor:  1.0
# Hassasiyet:  1.0
# Duyarlılık:  1.0

# %%
plt.plot(hist_dense.history['accuracy'])
plt.plot(hist_dense.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist_dense.history['loss'])
plt.plot(hist_dense.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[217   0   0]
#  [  0 197   0]
#  [  0   0 186]]
# <Axes: >
