# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import keras
import numpy as np # linear algebra
import keras.backend as K
import time as ti
import cv2
import os
import glob # for including images
import scipy.io as sio
from sklearn.metrics import classification_report, confusion_matrix
from keras import layers
from keras import models
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.layers import *

from tensorflow.python.keras.optimizers import *
from keras.callbacks import *
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.activations import *
import keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']


train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Patato/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 2152 images belonging to 3 classes.
# (2152, 224, 224, 3)
# (2152, 3)

# %%
#Converting  our color images to a vector
x=x.reshape(2152,224*224*3)

# %%
x.shape
# Out:
# (2152, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (3000, 150528)

# %%
y_smote.shape
# Out:
# (3000, 3)

# %%
X_smote=X_smote.reshape(3000,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (2152, 150528)
# Shape of X after SMOTE: (3000, 224, 224, 3)

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (3000, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
pip install keras_applications
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %%
pip install Keras
# Out:
# Requirement already satisfied: Keras in /usr/local/lib/python3.10/dist-packages (2.14.0)

# %%
from keras.utils import plot_model
from keras_applications.imagenet_utils import _obtain_input_shape
#from tensorflow.keras.engine.topology import get_source_inputs
from keras.layers import Input, Conv2D, MaxPool2D, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.layers import Activation, Dense
from keras.models import Model
import keras.backend as K



import os
from keras import backend as K
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.layers import Activation, Add, Concatenate, Conv2D, GlobalMaxPooling2D
from keras.layers import GlobalAveragePooling2D,Input, Dense
from keras.layers import MaxPool2D,AveragePooling2D, BatchNormalization, Lambda, DepthwiseConv2D
import numpy as np


def channel_split(x, name=''):
    # equipartition
    in_channles = x.shape.as_list()[-1]
    ip = in_channles // 2
    c_hat = Lambda(lambda z: z[:, :, :, 0:ip], name='%s/sp%d_slice' % (name, 0))(x)
    c = Lambda(lambda z: z[:, :, :, ip:], name='%s/sp%d_slice' % (name, 1))(x)
    return c_hat, c

def channel_shuffle(x):
    height, width, channels = x.shape.as_list()[1:]
    channels_per_split = channels // 2
    x = K.reshape(x, [-1, height, width, 2, channels_per_split])
    x = K.permute_dimensions(x, (0,1,2,4,3))
    x = K.reshape(x, [-1, height, width, channels])
    return x


def shuffle_unit(inputs, out_channels, bottleneck_ratio,strides=2,stage=1,block=1):
    if K.image_data_format() == 'channels_last':
        bn_axis = -1
    else:
        raise ValueError('Only channels last supported')

    prefix = 'stage{}/block{}'.format(stage, block)
    bottleneck_channels = int(out_channels * bottleneck_ratio)
    if strides < 2:
        c_hat, c = channel_split(inputs, '{}/spl'.format(prefix))
        inputs = c

    x = Conv2D(bottleneck_channels, kernel_size=(1,1), strides=1, padding='same', name='{}/1x1conv_1'.format(prefix))(inputs)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_1'.format(prefix))(x)
    x = Activation('relu', name='{}/relu_1x1conv_1'.format(prefix))(x)
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same', name='{}/3x3dwconv'.format(prefix))(x)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_3x3dwconv'.format(prefix))(x)
    x = Conv2D(bottleneck_channels, kernel_size=1,strides=1,padding='same', name='{}/1x1conv_2'.format(prefix))(x)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_2'.format(prefix))(x)
    x = Activation('relu', name='{}/relu_1x1conv_2'.format(prefix))(x)

    if strides < 2:
        ret = Concatenate(axis=bn_axis, name='{}/concat_1'.format(prefix))([x, c_hat])
    else:
        s2 = DepthwiseConv2D(kernel_size=3, strides=2, padding='same', name='{}/3x3dwconv_2'.format(prefix))(inputs)
        s2 = BatchNormalization(axis=bn_axis, name='{}/bn_3x3dwconv_2'.format(prefix))(s2)
        s2 = Conv2D(bottleneck_channels, kernel_size=1,strides=1,padding='same', name='{}/1x1_conv_3'.format(prefix))(s2)
        s2 = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_3'.format(prefix))(s2)
        s2 = Activation('relu', name='{}/relu_1x1conv_3'.format(prefix))(s2)
        ret = Concatenate(axis=bn_axis, name='{}/concat_2'.format(prefix))([x, s2])

    ret = Lambda(channel_shuffle, name='{}/channel_shuffle'.format(prefix))(ret)

    return ret


def block(x, channel_map, bottleneck_ratio, repeat=1, stage=1):
    x = shuffle_unit(x, out_channels=channel_map[stage-1],
                      strides=2,bottleneck_ratio=bottleneck_ratio,stage=stage,block=1)

    for i in range(1, repeat+1):
        x = shuffle_unit(x, out_channels=channel_map[stage-1],strides=1,
                          bottleneck_ratio=bottleneck_ratio,stage=stage, block=(1+i))

    return x


def ShuffleNetV2(include_top=True,
                 input_tensor=None,
                 scale_factor=1.0,
                 pooling='max',
                 input_shape=(32,32,3),
                 load_model=None,
                 num_shuffle_units=[3,7,3],
                 bottleneck_ratio=1,
                 classes=131):
    if K.backend() != 'tensorflow':
        raise RuntimeError('Only tensorflow supported for now')
    name = 'ShuffleNetV2_{}_{}_{}'.format(scale_factor, bottleneck_ratio, "".join([str(x) for x in num_shuffle_units]))
    input_shape = _obtain_input_shape(input_shape, default_size=224, min_size=28, require_flatten=include_top,
                                      data_format=K.image_data_format())
    out_dim_stage_two = {0.5:48, 1:116, 1.5:176, 2:244}

    if pooling not in ['max', 'avg']:
        raise ValueError('Invalid value for pooling')
    if not (float(scale_factor)*4).is_integer():
        raise ValueError('Invalid value for scale_factor, should be x over 4')
    exp = np.insert(np.arange(len(num_shuffle_units), dtype=np.float32), 0, 0)  # [0., 0., 1., 2.]
    out_channels_in_stage = 2**exp
    out_channels_in_stage *= out_dim_stage_two[bottleneck_ratio]  #  calculate output channels for each stage
    out_channels_in_stage[0] = 24  # first stage has always 24 output channels
    out_channels_in_stage *= scale_factor
    out_channels_in_stage = out_channels_in_stage.astype(int)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    # create shufflenet architecture
    x = Conv2D(filters=out_channels_in_stage[0], kernel_size=(3, 3), padding='same', use_bias=False, strides=(2, 2),
               activation='relu', name='conv1')(img_input)
    x = MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same', name='maxpool1')(x)

    # create stages containing shufflenet units beginning at stage 2
    for stage in range(len(num_shuffle_units)):
        repeat = num_shuffle_units[stage]
        x = block(x, out_channels_in_stage,
                   repeat=repeat,
                   bottleneck_ratio=bottleneck_ratio,
                   stage=stage + 2)

    if bottleneck_ratio < 2:
        k = 1024
    else:
        k = 2048
    x = Conv2D(k, kernel_size=1, padding='same', strides=1, name='1x1conv5_out', activation='relu')(x)

    if pooling == 'avg':
        x = GlobalAveragePooling2D(name='global_avg_pool')(x)
    elif pooling == 'max':
        x = GlobalMaxPooling2D(name='global_max_pool')(x)

    if include_top:
        x = Dense(classes, name='fc')(x)
        x = Activation('softmax', name='softmax')(x)

    if input_tensor:
        inputs = get_source_inputs(input_tensor)

    else:
        inputs = img_input

    model = Model(inputs, x, name=name)

    if load_model:
        model.load_weights('imagenet', by_name=True)

    return model

# %%
model = ShuffleNetV2(include_top=True, input_shape=(224, 224, 3), classes=3)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "ShuffleNetV2_1.0_1_373"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1 (Conv2D)              (None, 112, 112, 24)         648       ['input_1[0][0]']
#
#  maxpool1 (MaxPooling2D)     (None, 56, 56, 24)           0         ['conv1[0][0]']
#
#  stage2/block1/1x1conv_1 (C  (None, 56, 56, 116)          2900      ['maxpool1[0][0]']
#  onv2D)
#
#  stage2/block1/bn_1x1conv_1  (None, 56, 56, 116)          464       ['stage2/block1/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block1/relu_1x1conv  (None, 56, 56, 116)          0         ['stage2/block1/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block1/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block1/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block1/3x3dwconv_2   (None, 28, 28, 24)           240       ['maxpool1[0][0]']
#  (DepthwiseConv2D)
#
#  stage2/block1/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block1/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block1/bn_3x3dwconv  (None, 28, 28, 24)           96        ['stage2/block1/3x3dwconv_2[0]
#  _2 (BatchNormalization)                                            [0]']
#
#  stage2/block1/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block1/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block1/1x1_conv_3 (  (None, 28, 28, 116)          2900      ['stage2/block1/bn_3x3dwconv_2
#  Conv2D)                                                            [0][0]']
#
#  stage2/block1/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block1/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block1/bn_1x1conv_3  (None, 28, 28, 116)          464       ['stage2/block1/1x1_conv_3[0][
#   (BatchNormalization)                                              0]']
#
#  stage2/block1/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block1/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block1/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block1/bn_1x1conv_3[0
#  _3 (Activation)                                                    ][0]']
#
#  stage2/block1/concat_2 (Co  (None, 28, 28, 232)          0         ['stage2/block1/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block1/relu_1x1conv_3
#                                                                     [0][0]']
#
#  stage2/block1/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block1/concat_2[0][0]
#  fle (Lambda)                                                       ']
#
#  stage2/block2/spl/sp1_slic  (None, 28, 28, 116)          0         ['stage2/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block2/1x1conv_1 (C  (None, 28, 28, 116)          13572     ['stage2/block2/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage2/block2/bn_1x1conv_1  (None, 28, 28, 116)          464       ['stage2/block2/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block2/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block2/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block2/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block2/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block2/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block2/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block2/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block2/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block2/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block2/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block2/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block2/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block2/spl/sp0_slic  (None, 28, 28, 116)          0         ['stage2/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block2/concat_1 (Co  (None, 28, 28, 232)          0         ['stage2/block2/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block2/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage2/block2/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block2/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage2/block3/spl/sp1_slic  (None, 28, 28, 116)          0         ['stage2/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block3/1x1conv_1 (C  (None, 28, 28, 116)          13572     ['stage2/block3/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage2/block3/bn_1x1conv_1  (None, 28, 28, 116)          464       ['stage2/block3/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block3/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block3/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block3/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block3/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block3/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block3/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block3/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block3/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block3/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block3/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block3/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block3/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block3/spl/sp0_slic  (None, 28, 28, 116)          0         ['stage2/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block3/concat_1 (Co  (None, 28, 28, 232)          0         ['stage2/block3/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block3/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage2/block3/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block3/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage2/block4/spl/sp1_slic  (None, 28, 28, 116)          0         ['stage2/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block4/1x1conv_1 (C  (None, 28, 28, 116)          13572     ['stage2/block4/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage2/block4/bn_1x1conv_1  (None, 28, 28, 116)          464       ['stage2/block4/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block4/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block4/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block4/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block4/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block4/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block4/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block4/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block4/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block4/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block4/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block4/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block4/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block4/spl/sp0_slic  (None, 28, 28, 116)          0         ['stage2/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block4/concat_1 (Co  (None, 28, 28, 232)          0         ['stage2/block4/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block4/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage2/block4/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block4/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block1/1x1conv_1 (C  (None, 28, 28, 232)          54056     ['stage2/block4/channel_shuffl
#  onv2D)                                                             e[0][0]']
#
#  stage3/block1/bn_1x1conv_1  (None, 28, 28, 232)          928       ['stage3/block1/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block1/relu_1x1conv  (None, 28, 28, 232)          0         ['stage3/block1/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block1/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block1/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block1/3x3dwconv_2   (None, 14, 14, 232)          2320      ['stage2/block4/channel_shuffl
#  (DepthwiseConv2D)                                                  e[0][0]']
#
#  stage3/block1/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block1/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block1/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block1/3x3dwconv_2[0]
#  _2 (BatchNormalization)                                            [0]']
#
#  stage3/block1/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block1/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block1/1x1_conv_3 (  (None, 14, 14, 232)          54056     ['stage3/block1/bn_3x3dwconv_2
#  Conv2D)                                                            [0][0]']
#
#  stage3/block1/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block1/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block1/bn_1x1conv_3  (None, 14, 14, 232)          928       ['stage3/block1/1x1_conv_3[0][
#   (BatchNormalization)                                              0]']
#
#  stage3/block1/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block1/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block1/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block1/bn_1x1conv_3[0
#  _3 (Activation)                                                    ][0]']
#
#  stage3/block1/concat_2 (Co  (None, 14, 14, 464)          0         ['stage3/block1/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block1/relu_1x1conv_3
#                                                                     [0][0]']
#
#  stage3/block1/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block1/concat_2[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block2/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block2/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block2/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block2/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block2/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block2/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block2/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block2/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block2/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block2/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block2/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block2/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block2/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block2/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block2/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block2/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block2/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block2/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block2/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block2/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block2/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block2/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block2/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block3/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block3/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block3/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block3/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block3/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block3/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block3/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block3/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block3/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block3/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block3/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block3/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block3/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block3/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block3/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block3/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block3/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block3/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block3/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block3/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block3/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block3/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block3/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block4/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block4/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block4/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block4/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block4/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block4/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block4/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block4/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block4/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block4/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block4/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block4/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block4/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block4/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block4/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block4/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block4/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block4/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block4/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block4/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block4/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block4/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block4/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block5/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block4/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block5/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block5/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block5/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block5/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block5/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block5/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block5/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block5/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block5/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block5/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block5/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block5/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block5/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block5/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block5/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block5/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block5/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block4/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block5/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block5/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block5/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block5/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block5/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block6/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block5/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block6/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block6/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block6/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block6/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block6/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block6/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block6/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block6/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block6/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block6/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block6/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block6/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block6/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block6/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block6/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block6/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block6/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block5/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block6/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block6/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block6/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block6/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block6/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block7/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block6/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block7/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block7/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block7/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block7/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block7/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block7/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block7/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block7/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block7/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block7/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block7/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block7/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block7/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block7/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block7/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block7/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block7/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block6/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block7/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block7/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block7/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block7/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block7/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block8/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block7/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block8/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block8/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block8/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block8/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block8/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block8/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block8/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block8/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block8/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block8/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block8/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block8/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block8/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block8/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block8/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block8/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block8/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block7/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block8/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block8/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block8/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block8/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block8/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block1/1x1conv_1 (C  (None, 14, 14, 464)          215760    ['stage3/block8/channel_shuffl
# ...
#  (DepthwiseConv2D)                                                  e[0][0]']
#
#  stage4/block1/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block1/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block1/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block1/3x3dwconv_2[0]
#  _2 (BatchNormalization)                                            [0]']
#
#  stage4/block1/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block1/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block1/1x1_conv_3 (  (None, 7, 7, 464)            215760    ['stage4/block1/bn_3x3dwconv_2
#  Conv2D)                                                            [0][0]']
#
#  stage4/block1/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block1/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block1/bn_1x1conv_3  (None, 7, 7, 464)            1856      ['stage4/block1/1x1_conv_3[0][
#   (BatchNormalization)                                              0]']
#
#  stage4/block1/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block1/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block1/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block1/bn_1x1conv_3[0
#  _3 (Activation)                                                    ][0]']
#
#  stage4/block1/concat_2 (Co  (None, 7, 7, 928)            0         ['stage4/block1/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block1/relu_1x1conv_3
#                                                                     [0][0]']
#
#  stage4/block1/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block1/concat_2[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block2/spl/sp1_slic  (None, 7, 7, 464)            0         ['stage4/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block2/1x1conv_1 (C  (None, 7, 7, 464)            215760    ['stage4/block2/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage4/block2/bn_1x1conv_1  (None, 7, 7, 464)            1856      ['stage4/block2/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block2/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block2/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage4/block2/3x3dwconv (D  (None, 7, 7, 464)            4640      ['stage4/block2/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage4/block2/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block2/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block2/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block2/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block2/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block2/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block2/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block2/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block2/spl/sp0_slic  (None, 7, 7, 464)            0         ['stage4/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block2/concat_1 (Co  (None, 7, 7, 928)            0         ['stage4/block2/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block2/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage4/block2/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block2/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block3/spl/sp1_slic  (None, 7, 7, 464)            0         ['stage4/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block3/1x1conv_1 (C  (None, 7, 7, 464)            215760    ['stage4/block3/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage4/block3/bn_1x1conv_1  (None, 7, 7, 464)            1856      ['stage4/block3/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block3/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block3/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage4/block3/3x3dwconv (D  (None, 7, 7, 464)            4640      ['stage4/block3/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage4/block3/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block3/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block3/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block3/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block3/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block3/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block3/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block3/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block3/spl/sp0_slic  (None, 7, 7, 464)            0         ['stage4/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block3/concat_1 (Co  (None, 7, 7, 928)            0         ['stage4/block3/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block3/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage4/block3/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block3/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block4/spl/sp1_slic  (None, 7, 7, 464)            0         ['stage4/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block4/1x1conv_1 (C  (None, 7, 7, 464)            215760    ['stage4/block4/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage4/block4/bn_1x1conv_1  (None, 7, 7, 464)            1856      ['stage4/block4/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block4/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block4/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage4/block4/3x3dwconv (D  (None, 7, 7, 464)            4640      ['stage4/block4/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage4/block4/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block4/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block4/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block4/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block4/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block4/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block4/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block4/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block4/spl/sp0_slic  (None, 7, 7, 464)            0         ['stage4/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block4/concat_1 (Co  (None, 7, 7, 928)            0         ['stage4/block4/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block4/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage4/block4/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block4/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  1x1conv5_out (Conv2D)       (None, 7, 7, 1024)           951296    ['stage4/block4/channel_shuffl
#                                                                     e[0][0]']
#
#  global_max_pool (GlobalMax  (None, 1024)                 0         ['1x1conv5_out[0][0]']
#  Pooling2D)
#
#  fc (Dense)                  (None, 3)                    3075      ['global_max_pool[0][0]']
#
#  softmax (Activation)        (None, 3)                    0         ['fc[0][0]']
#
# ==================================================================================================
# Total params: 4021815 (15.34 MB)
# Trainable params: 3993695 (15.23 MB)
# Non-trainable params: 28120 (109.84 KB)
# __________________________________________________________________________________________________
# None

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist=model.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 1.9511 - accuracy: 0.5796
# Epoch 1: val_accuracy improved from -inf to 0.31000, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - 53s 318ms/step - loss: 1.9511 - accuracy: 0.5796 - val_loss: 1.1009 - val_accuracy: 0.3100
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4594 - accuracy: 0.8042
# Epoch 2: val_accuracy did not improve from 0.31000
# 38/38 [==============================] - 8s 220ms/step - loss: 0.4594 - accuracy: 0.8042 - val_loss: 1.1082 - val_accuracy: 0.3100
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9262
# Epoch 3: val_accuracy did not improve from 0.31000
# 38/38 [==============================] - 8s 221ms/step - loss: 0.1956 - accuracy: 0.9262 - val_loss: 1.1231 - val_accuracy: 0.3100
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9750
# Epoch 4: val_accuracy did not improve from 0.31000
# 38/38 [==============================] - 8s 224ms/step - loss: 0.0687 - accuracy: 0.9750 - val_loss: 1.1630 - val_accuracy: 0.3100
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9871
# Epoch 5: val_accuracy did not improve from 0.31000
# 38/38 [==============================] - 8s 224ms/step - loss: 0.0423 - accuracy: 0.9871 - val_loss: 1.2489 - val_accuracy: 0.3100
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9725
# Epoch 6: val_accuracy did not improve from 0.31000
# 38/38 [==============================] - 9s 225ms/step - loss: 0.0695 - accuracy: 0.9725 - val_loss: 1.3511 - val_accuracy: 0.3100
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9463
# Epoch 7: val_accuracy did not improve from 0.31000
# 38/38 [==============================] - 9s 227ms/step - loss: 0.1593 - accuracy: 0.9463 - val_loss: 1.4898 - val_accuracy: 0.3100
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9842
# Epoch 8: val_accuracy did not improve from 0.31000
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0430 - accuracy: 0.9842 - val_loss: 1.5380 - val_accuracy: 0.3100
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9942
# Epoch 9: val_accuracy did not improve from 0.31000
# 38/38 [==============================] - 9s 229ms/step - loss: 0.0129 - accuracy: 0.9942 - val_loss: 1.7149 - val_accuracy: 0.3100
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9896
# Epoch 10: val_accuracy improved from 0.31000 to 0.32833, saving model to best_model.h5
# 38/38 [==============================] - 9s 248ms/step - loss: 0.0238 - accuracy: 0.9896 - val_loss: 2.0113 - val_accuracy: 0.3283
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9900
# Epoch 11: val_accuracy did not improve from 0.32833
# 38/38 [==============================] - 9s 229ms/step - loss: 0.0287 - accuracy: 0.9900 - val_loss: 2.5111 - val_accuracy: 0.3283
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9937
# Epoch 12: val_accuracy did not improve from 0.32833
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 2.9551 - val_accuracy: 0.3100
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9883
# Epoch 13: val_accuracy did not improve from 0.32833
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0359 - accuracy: 0.9883 - val_loss: 3.6066 - val_accuracy: 0.3283
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9896
# Epoch 14: val_accuracy did not improve from 0.32833
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0252 - accuracy: 0.9896 - val_loss: 4.7093 - val_accuracy: 0.3167
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9925
# Epoch 15: val_accuracy improved from 0.32833 to 0.46167, saving model to best_model.h5
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0256 - accuracy: 0.9925 - val_loss: 5.6728 - val_accuracy: 0.4617
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9925
# Epoch 16: val_accuracy did not improve from 0.46167
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0195 - accuracy: 0.9925 - val_loss: 6.9039 - val_accuracy: 0.4383
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9896
# Epoch 17: val_accuracy improved from 0.46167 to 0.50500, saving model to best_model.h5
# 38/38 [==============================] - 9s 246ms/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 5.7631 - val_accuracy: 0.5050
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9917
# Epoch 18: val_accuracy improved from 0.50500 to 0.52500, saving model to best_model.h5
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0253 - accuracy: 0.9917 - val_loss: 4.3819 - val_accuracy: 0.5250
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9904
# Epoch 19: val_accuracy improved from 0.52500 to 0.90500, saving model to best_model.h5
# 38/38 [==============================] - 9s 247ms/step - loss: 0.0307 - accuracy: 0.9904 - val_loss: 0.4589 - val_accuracy: 0.9050
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9908
# Epoch 20: val_accuracy did not improve from 0.90500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0218 - accuracy: 0.9908 - val_loss: 0.7918 - val_accuracy: 0.8083
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9921
# Epoch 21: val_accuracy improved from 0.90500 to 0.93167, saving model to best_model.h5
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0194 - accuracy: 0.9921 - val_loss: 0.2462 - val_accuracy: 0.9317
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9950
# Epoch 22: val_accuracy improved from 0.93167 to 0.96167, saving model to best_model.h5
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.1334 - val_accuracy: 0.9617
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9967
# Epoch 23: val_accuracy did not improve from 0.96167
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.1956 - val_accuracy: 0.9517
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9975
# Epoch 24: val_accuracy did not improve from 0.96167
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0088 - accuracy: 0.9975 - val_loss: 0.3174 - val_accuracy: 0.9467
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9912
# Epoch 25: val_accuracy did not improve from 0.96167
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0212 - accuracy: 0.9912 - val_loss: 0.3314 - val_accuracy: 0.9000
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9892
# Epoch 26: val_accuracy did not improve from 0.96167
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0323 - accuracy: 0.9892 - val_loss: 0.6680 - val_accuracy: 0.8817
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9921
# Epoch 27: val_accuracy did not improve from 0.96167
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0310 - accuracy: 0.9921 - val_loss: 1.2134 - val_accuracy: 0.8067
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9954
# Epoch 28: val_accuracy did not improve from 0.96167
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0126 - accuracy: 0.9954 - val_loss: 0.3397 - val_accuracy: 0.9317
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9983
# Epoch 29: val_accuracy improved from 0.96167 to 0.96333, saving model to best_model.h5
# 38/38 [==============================] - 9s 246ms/step - loss: 0.0039 - accuracy: 0.9983 - val_loss: 0.1555 - val_accuracy: 0.9633
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9929
# Epoch 30: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0225 - accuracy: 0.9929 - val_loss: 0.4219 - val_accuracy: 0.9067
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9833
# Epoch 31: val_accuracy improved from 0.96333 to 0.96500, saving model to best_model.h5
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0461 - accuracy: 0.9833 - val_loss: 0.1424 - val_accuracy: 0.9650
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9858
# Epoch 32: val_accuracy did not improve from 0.96500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0479 - accuracy: 0.9858 - val_loss: 0.5577 - val_accuracy: 0.9017
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9779
# Epoch 33: val_accuracy did not improve from 0.96500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0819 - accuracy: 0.9779 - val_loss: 4.2415 - val_accuracy: 0.6400
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9946
# Epoch 34: val_accuracy did not improve from 0.96500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.4749 - val_accuracy: 0.9083
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9962
# Epoch 35: val_accuracy did not improve from 0.96500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0087 - accuracy: 0.9962 - val_loss: 0.1704 - val_accuracy: 0.9567
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9987
# Epoch 36: val_accuracy did not improve from 0.96500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.8392 - val_accuracy: 0.8400
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 37: val_accuracy improved from 0.96500 to 0.98500, saving model to best_model.h5
# 38/38 [==============================] - 9s 246ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0530 - val_accuracy: 0.9850
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 3.7008e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 227ms/step - loss: 3.7008e-04 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9833
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 2.7401e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 2.7401e-04 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9850
# Epoch 40/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8465e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.8465e-04 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9833
# Epoch 41/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2168e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.2168e-04 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9833
# Epoch 42/100
# 38/38 [==============================] - ETA: 0s - loss: 9.5509e-05 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 9.5509e-05 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9817
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 1.7014e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.7014e-04 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9750
# Epoch 44/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1270e-04 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 229ms/step - loss: 1.1270e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9767
# Epoch 45/100
# 38/38 [==============================] - ETA: 0s - loss: 6.5318e-05 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 6.5318e-05 - accuracy: 1.0000 - val_loss: 0.1078 - val_accuracy: 0.9783
# Epoch 46/100
# 38/38 [==============================] - ETA: 0s - loss: 3.9835e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 3.9835e-04 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 0.9800
# Epoch 47/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6089e-04 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.6089e-04 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9800
# Epoch 48/100
# 38/38 [==============================] - ETA: 0s - loss: 4.4902e-05 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 227ms/step - loss: 4.4902e-05 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9783
# Epoch 49/100
# 38/38 [==============================] - ETA: 0s - loss: 1.7372e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.7372e-04 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9817
# Epoch 50/100
# 38/38 [==============================] - ETA: 0s - loss: 6.1809e-05 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 227ms/step - loss: 6.1809e-05 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9800
# Epoch 51/100
# 38/38 [==============================] - ETA: 0s - loss: 7.8157e-05 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 7.8157e-05 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9833
# Epoch 52/100
# 38/38 [==============================] - ETA: 0s - loss: 3.9204e-05 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 3.9204e-05 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9800
# Epoch 53/100
# 38/38 [==============================] - ETA: 0s - loss: 4.9423e-04 - accuracy: 0.9996
# Epoch 53: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 4.9423e-04 - accuracy: 0.9996 - val_loss: 0.1386 - val_accuracy: 0.9750
# Epoch 54/100
# 38/38 [==============================] - ETA: 0s - loss: 2.5775e-04 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 227ms/step - loss: 2.5775e-04 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9750
# Epoch 55/100
# 38/38 [==============================] - ETA: 0s - loss: 3.1011e-05 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 3.1011e-05 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9800
# Epoch 56/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2374e-04 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.2374e-04 - accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 0.9767
# Epoch 57/100
# 38/38 [==============================] - ETA: 0s - loss: 2.6053e-05 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 2.6053e-05 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9800
# Epoch 58/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3199e-05 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.3199e-05 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9817
# Epoch 59/100
# 38/38 [==============================] - ETA: 0s - loss: 2.1923e-05 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 2.1923e-05 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9817
# Epoch 60/100
# 38/38 [==============================] - ETA: 0s - loss: 3.4036e-05 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 227ms/step - loss: 3.4036e-05 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9817
# Epoch 61/100
# 38/38 [==============================] - ETA: 0s - loss: 6.8944e-05 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 6.8944e-05 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9817
# Epoch 62/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5503e-04 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.5503e-04 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9800
# Epoch 63/100
# 38/38 [==============================] - ETA: 0s - loss: 1.9917e-05 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.9917e-05 - accuracy: 1.0000 - val_loss: 0.0825 - val_accuracy: 0.9817
# Epoch 64/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8473e-05 - accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.8473e-05 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9833
# Epoch 65/100
# 38/38 [==============================] - ETA: 0s - loss: 4.6214e-04 - accuracy: 0.9996
# Epoch 65: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 4.6214e-04 - accuracy: 0.9996 - val_loss: 0.1136 - val_accuracy: 0.9767
# Epoch 66/100
# 38/38 [==============================] - ETA: 0s - loss: 2.9172e-04 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 227ms/step - loss: 2.9172e-04 - accuracy: 1.0000 - val_loss: 0.3357 - val_accuracy: 0.9633
# Epoch 67/100
# 38/38 [==============================] - ETA: 0s - loss: 2.3615e-05 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 2.3615e-05 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9767
# Epoch 68/100
# 38/38 [==============================] - ETA: 0s - loss: 6.1833e-05 - accuracy: 1.0000
# Epoch 68: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 227ms/step - loss: 6.1833e-05 - accuracy: 1.0000 - val_loss: 0.0900 - val_accuracy: 0.9817
# Epoch 69/100
# 38/38 [==============================] - ETA: 0s - loss: 2.9395e-05 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 2.9395e-05 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 0.9833
# Epoch 70/100
# 38/38 [==============================] - ETA: 0s - loss: 1.7937e-04 - accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 1.7937e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9700
# Epoch 71/100
# 38/38 [==============================] - ETA: 0s - loss: 3.8592e-05 - accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 3.8592e-05 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9750
# Epoch 72/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.9488
# Epoch 72: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.2635 - accuracy: 0.9488 - val_loss: 51940.5977 - val_accuracy: 0.3617
# Epoch 73/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9479
# Epoch 73: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.1541 - accuracy: 0.9479 - val_loss: 12674.8730 - val_accuracy: 0.3617
# Epoch 74/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9808
# Epoch 74: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0532 - accuracy: 0.9808 - val_loss: 270.4234 - val_accuracy: 0.4533
# Epoch 75/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9900
# Epoch 75: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0333 - accuracy: 0.9900 - val_loss: 21.9346 - val_accuracy: 0.6933
# Epoch 76/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9942
# Epoch 76: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 2.8540 - val_accuracy: 0.8283
# Epoch 77/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9954
# Epoch 77: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0108 - accuracy: 0.9954 - val_loss: 0.3961 - val_accuracy: 0.9050
# Epoch 78/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9942
# Epoch 78: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0128 - accuracy: 0.9942 - val_loss: 0.1159 - val_accuracy: 0.9667
# Epoch 79/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9958
# Epoch 79: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0108 - accuracy: 0.9958 - val_loss: 0.1843 - val_accuracy: 0.9517
# Epoch 80/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9975
# Epoch 80: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.1335 - val_accuracy: 0.9650
# Epoch 81/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9950
# Epoch 81: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0119 - accuracy: 0.9950 - val_loss: 0.2379 - val_accuracy: 0.9350
# Epoch 82/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9967
# Epoch 82: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0083 - accuracy: 0.9967 - val_loss: 0.4980 - val_accuracy: 0.9067
# Epoch 83/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9975
# Epoch 83: val_accuracy did not improve from 0.98500
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0062 - accuracy: 0.9975 - val_loss: 0.0644 - val_accuracy: 0.9717
# Epoch 84/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992
# Epoch 84: val_accuracy improved from 0.98500 to 0.98667, saving model to best_model.h5
# 38/38 [==============================] - 9s 246ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0420 - val_accuracy: 0.9867
# Epoch 85/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9992
# Epoch 85: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0636 - val_accuracy: 0.9817
# Epoch 86/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 86: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.3889 - val_accuracy: 0.9317
# Epoch 87/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9979
# Epoch 87: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 0.1445 - val_accuracy: 0.9367
# Epoch 88/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9954
# Epoch 88: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 0.3452 - val_accuracy: 0.9383
# Epoch 89/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9979
# Epoch 89: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.1168 - val_accuracy: 0.9633
# Epoch 90/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9942
# Epoch 90: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.5029 - val_accuracy: 0.9150
# Epoch 91/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9971
# Epoch 91: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0675 - val_accuracy: 0.9833
# Epoch 92/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9917
# Epoch 92: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0255 - accuracy: 0.9917 - val_loss: 0.3613 - val_accuracy: 0.9267
# Epoch 93/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9958
# Epoch 93: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0072 - accuracy: 0.9958 - val_loss: 0.3073 - val_accuracy: 0.9433
# Epoch 94/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9987
# Epoch 94: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.1699 - val_accuracy: 0.9667
# Epoch 95/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9987
# Epoch 95: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0024 - accuracy: 0.9987 - val_loss: 0.1773 - val_accuracy: 0.9583
# Epoch 96/100
# 38/38 [==============================] - ETA: 0s - loss: 1.9648e-04 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 1.9648e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9650
# Epoch 97/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9633
# Epoch 98/100
# 38/38 [==============================] - ETA: 0s - loss: 8.8946e-04 - accuracy: 0.9996
# Epoch 98: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 8.8946e-04 - accuracy: 0.9996 - val_loss: 0.1758 - val_accuracy: 0.9633
# Epoch 99/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 99: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 1.0150 - val_accuracy: 0.7517
# Epoch 100/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 100: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0718 - val_accuracy: 0.9833

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 19/19 [==============================] - 2s 41ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("ShuffleNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# ShuffleNet MODEL SONUÇLARI
# Doğruluk:  0.9866666666666667
# F1_Skor:  0.9869008453261968
# Hassasiyet:  0.9871957016120634
# Duyarlılık:  0.986675451797443

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
cm_dense = confusion_matrix(Y_val, y_pred)
print(cm_dense)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm_dense, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# Confusion Matrix
# [[215   2   0]
#  [  4 192   1]
#  [  1   0 185]]
# <Axes: >
