# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']


train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Patato/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 2152 images belonging to 3 classes.
# (2152, 224, 224, 3)
# (2152, 3)

# %%
#Converting  our color images to a vector
x=x.reshape(2152,224*224*3)

# %%
x.shape
# Out:
# (2152, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (3000, 150528)

# %%
y_smote.shape
# Out:
# (3000, 3)

# %%
X_smote=X_smote.reshape(3000,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (2152, 150528)
# Shape of X after SMOTE: (3000, 224, 224, 3)

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (3000, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
from keras.applications import MobileNetV2
def build_MobilNetV2():
    mobilnetv2 = MobileNetV2(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = mobilnetv2(x)
    x = Flatten(name="flatten")(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    # multi output
    output = Dense(3,activation = 'softmax', name='root')(x)
    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_mobilnet=build_MobilNetV2()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 3)       84
#
#  mobilenetv2_1.00_224 (Func  (None, None, None, 1280   2257984
#  tional)                     )
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dropout_2 (Dropout)         (None, 62720)             0
#
#  dense_1 (Dense)             (None, 256)               16056576
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 3)                 771
#
# =================================================================
# Total params: 18316439 (69.87 MB)
# Trainable params: 18281815 (69.74 MB)
# Non-trainable params: 34624 (135.25 KB)
# _________________________________________________________________

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist_mobilnetv1=model_mobilnet.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 0.5256 - accuracy: 0.8200
# Epoch 1: val_accuracy improved from -inf to 0.35167, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - 33s 357ms/step - loss: 0.5256 - accuracy: 0.8200 - val_loss: 4.5043 - val_accuracy: 0.3517
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9771
# Epoch 2: val_accuracy improved from 0.35167 to 0.36833, saving model to best_model.h5
# 38/38 [==============================] - 12s 313ms/step - loss: 0.0636 - accuracy: 0.9771 - val_loss: 3.5393 - val_accuracy: 0.3683
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9921
# Epoch 3: val_accuracy improved from 0.36833 to 0.39667, saving model to best_model.h5
# 38/38 [==============================] - 12s 312ms/step - loss: 0.0272 - accuracy: 0.9921 - val_loss: 3.1730 - val_accuracy: 0.3967
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9962
# Epoch 4: val_accuracy improved from 0.39667 to 0.42333, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 2.9748 - val_accuracy: 0.4233
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9983
# Epoch 5: val_accuracy improved from 0.42333 to 0.44167, saving model to best_model.h5
# 38/38 [==============================] - 12s 308ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 2.7283 - val_accuracy: 0.4417
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9992
# Epoch 6: val_accuracy did not improve from 0.44167
# 38/38 [==============================] - 11s 282ms/step - loss: 0.0055 - accuracy: 0.9992 - val_loss: 2.9776 - val_accuracy: 0.4317
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9992
# Epoch 7: val_accuracy improved from 0.44167 to 0.45667, saving model to best_model.h5
# 38/38 [==============================] - 12s 308ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 2.6354 - val_accuracy: 0.4567
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9983
# Epoch 8: val_accuracy improved from 0.45667 to 0.49167, saving model to best_model.h5
# 38/38 [==============================] - 12s 309ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 2.4147 - val_accuracy: 0.4917
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9992
# Epoch 9: val_accuracy did not improve from 0.49167
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 2.4003 - val_accuracy: 0.4883
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 10: val_accuracy improved from 0.49167 to 0.49667, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.4494 - val_accuracy: 0.4967
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9979
# Epoch 11: val_accuracy improved from 0.49667 to 0.53000, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 2.2330 - val_accuracy: 0.5300
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992
# Epoch 12: val_accuracy improved from 0.53000 to 0.55000, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 2.1190 - val_accuracy: 0.5500
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9975
# Epoch 13: val_accuracy did not improve from 0.55000
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0051 - accuracy: 0.9975 - val_loss: 2.9330 - val_accuracy: 0.4733
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996
# Epoch 14: val_accuracy did not improve from 0.55000
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 2.6089 - val_accuracy: 0.5000
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 15: val_accuracy improved from 0.55000 to 0.58000, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.8435 - val_accuracy: 0.5800
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 16: val_accuracy improved from 0.58000 to 0.59000, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 1.8454 - val_accuracy: 0.5900
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 17: val_accuracy improved from 0.59000 to 0.60000, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.7463 - val_accuracy: 0.6000
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 18: val_accuracy improved from 0.60000 to 0.63500, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 1.5500 - val_accuracy: 0.6350
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992
# Epoch 19: val_accuracy improved from 0.63500 to 0.63667, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 1.5431 - val_accuracy: 0.6367
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9992
# Epoch 20: val_accuracy improved from 0.63667 to 0.67833, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 1.2790 - val_accuracy: 0.6783
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992
# Epoch 21: val_accuracy did not improve from 0.67833
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 1.5479 - val_accuracy: 0.6617
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9987
# Epoch 22: val_accuracy did not improve from 0.67833
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0028 - accuracy: 0.9987 - val_loss: 1.4286 - val_accuracy: 0.6717
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 23: val_accuracy improved from 0.67833 to 0.70667, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.2407 - val_accuracy: 0.7067
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 24: val_accuracy improved from 0.70667 to 0.71333, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 1.2434 - val_accuracy: 0.7133
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 25: val_accuracy improved from 0.71333 to 0.72500, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 1.1661 - val_accuracy: 0.7250
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 26: val_accuracy improved from 0.72500 to 0.73333, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 1.0806 - val_accuracy: 0.7333
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9987
# Epoch 27: val_accuracy did not improve from 0.73333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0029 - accuracy: 0.9987 - val_loss: 1.1997 - val_accuracy: 0.7083
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9987
# Epoch 28: val_accuracy improved from 0.73333 to 0.78833, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0028 - accuracy: 0.9987 - val_loss: 0.8844 - val_accuracy: 0.7883
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 29: val_accuracy improved from 0.78833 to 0.79333, saving model to best_model.h5
# 38/38 [==============================] - 12s 309ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.8566 - val_accuracy: 0.7933
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 5.2640e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy improved from 0.79333 to 0.80333, saving model to best_model.h5
# 38/38 [==============================] - 12s 309ms/step - loss: 5.2640e-04 - accuracy: 1.0000 - val_loss: 0.7926 - val_accuracy: 0.8033
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 31: val_accuracy did not improve from 0.80333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.7569 - val_accuracy: 0.8000
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 32: val_accuracy did not improve from 0.80333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.8083 - val_accuracy: 0.8000
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 7.5181e-04 - accuracy: 0.9996
# Epoch 33: val_accuracy improved from 0.80333 to 0.83000, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 7.5181e-04 - accuracy: 0.9996 - val_loss: 0.6549 - val_accuracy: 0.8300
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 6.7269e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy improved from 0.83000 to 0.85333, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 6.7269e-04 - accuracy: 1.0000 - val_loss: 0.5936 - val_accuracy: 0.8533
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9987
# Epoch 35: val_accuracy did not improve from 0.85333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.7527 - val_accuracy: 0.8167
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 9.0043e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.85333
# 38/38 [==============================] - 11s 285ms/step - loss: 9.0043e-04 - accuracy: 1.0000 - val_loss: 0.6335 - val_accuracy: 0.8383
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9992
# Epoch 37: val_accuracy did not improve from 0.85333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.7293 - val_accuracy: 0.8133
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 5.9526e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.85333
# 38/38 [==============================] - 11s 285ms/step - loss: 5.9526e-04 - accuracy: 1.0000 - val_loss: 0.8777 - val_accuracy: 0.8000
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9996
# Epoch 39: val_accuracy did not improve from 0.85333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.8133 - val_accuracy: 0.8017
# Epoch 40/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 40: val_accuracy did not improve from 0.85333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.5367 - val_accuracy: 0.8533
# Epoch 41/100
# 38/38 [==============================] - ETA: 0s - loss: 8.5738e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.85333
# 38/38 [==============================] - 11s 284ms/step - loss: 8.5738e-04 - accuracy: 1.0000 - val_loss: 0.6664 - val_accuracy: 0.8267
# Epoch 42/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9992
# Epoch 42: val_accuracy improved from 0.85333 to 0.86667, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.4558 - val_accuracy: 0.8667
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 43: val_accuracy did not improve from 0.86667
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.5329 - val_accuracy: 0.8517
# Epoch 44/100
# 38/38 [==============================] - ETA: 0s - loss: 4.1366e-04 - accuracy: 1.0000
# Epoch 44: val_accuracy improved from 0.86667 to 0.87500, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 4.1366e-04 - accuracy: 1.0000 - val_loss: 0.4499 - val_accuracy: 0.8750
# Epoch 45/100
# 38/38 [==============================] - ETA: 0s - loss: 7.7038e-04 - accuracy: 0.9996
# Epoch 45: val_accuracy improved from 0.87500 to 0.88000, saving model to best_model.h5
# 38/38 [==============================] - 12s 309ms/step - loss: 7.7038e-04 - accuracy: 0.9996 - val_loss: 0.4412 - val_accuracy: 0.8800
# Epoch 46/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9992
# Epoch 46: val_accuracy improved from 0.88000 to 0.90333, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.3299 - val_accuracy: 0.9033
# Epoch 47/100
# 38/38 [==============================] - ETA: 0s - loss: 7.2352e-04 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.90333
# 38/38 [==============================] - 11s 284ms/step - loss: 7.2352e-04 - accuracy: 1.0000 - val_loss: 0.4268 - val_accuracy: 0.8583
# Epoch 48/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9992
# Epoch 48: val_accuracy did not improve from 0.90333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.3591 - val_accuracy: 0.8850
# Epoch 49/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 49: val_accuracy improved from 0.90333 to 0.91500, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.2895 - val_accuracy: 0.9150
# Epoch 50/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 50: val_accuracy did not improve from 0.91500
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.3323 - val_accuracy: 0.9117
# Epoch 51/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9983
# Epoch 51: val_accuracy did not improve from 0.91500
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0030 - accuracy: 0.9983 - val_loss: 0.3695 - val_accuracy: 0.8983
# Epoch 52/100
# 38/38 [==============================] - ETA: 0s - loss: 5.3273e-04 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.91500
# 38/38 [==============================] - 11s 284ms/step - loss: 5.3273e-04 - accuracy: 1.0000 - val_loss: 0.3975 - val_accuracy: 0.8933
# Epoch 53/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9996
# Epoch 53: val_accuracy did not improve from 0.91500
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.3387 - val_accuracy: 0.9067
# Epoch 54/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 54: val_accuracy improved from 0.91500 to 0.94167, saving model to best_model.h5
# 38/38 [==============================] - 12s 313ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.2076 - val_accuracy: 0.9417
# Epoch 55/100
# 38/38 [==============================] - ETA: 0s - loss: 8.7846e-04 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.94167
# 38/38 [==============================] - 11s 284ms/step - loss: 8.7846e-04 - accuracy: 1.0000 - val_loss: 0.2188 - val_accuracy: 0.9350
# Epoch 56/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 56: val_accuracy improved from 0.94167 to 0.94333, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.1702 - val_accuracy: 0.9433
# Epoch 57/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 57: val_accuracy improved from 0.94333 to 0.94500, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1924 - val_accuracy: 0.9450
# Epoch 58/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9992
# Epoch 58: val_accuracy improved from 0.94500 to 0.96333, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.1264 - val_accuracy: 0.9633
# Epoch 59/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9992
# Epoch 59: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 0.1565 - val_accuracy: 0.9600
# Epoch 60/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9996
# Epoch 60: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.1706 - val_accuracy: 0.9550
# Epoch 61/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9929
# Epoch 61: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0202 - accuracy: 0.9929 - val_loss: 0.3318 - val_accuracy: 0.9267
# Epoch 62/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9958
# Epoch 62: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.4760 - val_accuracy: 0.9017
# Epoch 63/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9958
# Epoch 63: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0110 - accuracy: 0.9958 - val_loss: 0.6457 - val_accuracy: 0.8617
# Epoch 64/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9967
# Epoch 64: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.6796 - val_accuracy: 0.8517
# Epoch 65/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9962
# Epoch 65: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0089 - accuracy: 0.9962 - val_loss: 0.4401 - val_accuracy: 0.9017
# Epoch 66/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9975
# Epoch 66: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 283ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.5339 - val_accuracy: 0.8817
# Epoch 67/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4648 - val_accuracy: 0.8983
# Epoch 68/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 68: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.5400 - val_accuracy: 0.8933
# Epoch 69/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9987
# Epoch 69: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.1760 - val_accuracy: 0.9500
# Epoch 70/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9992
# Epoch 70: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 0.2851 - val_accuracy: 0.9350
# Epoch 71/100
# 38/38 [==============================] - ETA: 0s - loss: 4.9566e-04 - accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 4.9566e-04 - accuracy: 1.0000 - val_loss: 0.2742 - val_accuracy: 0.9400
# Epoch 72/100
# 38/38 [==============================] - ETA: 0s - loss: 5.9822e-04 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 285ms/step - loss: 5.9822e-04 - accuracy: 1.0000 - val_loss: 0.3038 - val_accuracy: 0.9367
# Epoch 73/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9992
# Epoch 73: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.5978 - val_accuracy: 0.8933
# Epoch 74/100
# 38/38 [==============================] - ETA: 0s - loss: 3.7786e-04 - accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 285ms/step - loss: 3.7786e-04 - accuracy: 1.0000 - val_loss: 0.4266 - val_accuracy: 0.9233
# Epoch 75/100
# 38/38 [==============================] - ETA: 0s - loss: 2.4897e-04 - accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 2.4897e-04 - accuracy: 1.0000 - val_loss: 0.3283 - val_accuracy: 0.9333
# Epoch 76/100
# 38/38 [==============================] - ETA: 0s - loss: 2.5409e-04 - accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 2.5409e-04 - accuracy: 1.0000 - val_loss: 0.3240 - val_accuracy: 0.9333
# Epoch 77/100
# 38/38 [==============================] - ETA: 0s - loss: 6.9526e-05 - accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 6.9526e-05 - accuracy: 1.0000 - val_loss: 0.2748 - val_accuracy: 0.9417
# Epoch 78/100
# 38/38 [==============================] - ETA: 0s - loss: 1.7700e-04 - accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 1.7700e-04 - accuracy: 1.0000 - val_loss: 0.2920 - val_accuracy: 0.9367
# Epoch 79/100
# 38/38 [==============================] - ETA: 0s - loss: 6.3664e-04 - accuracy: 0.9996
# Epoch 79: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 6.3664e-04 - accuracy: 0.9996 - val_loss: 0.3074 - val_accuracy: 0.9350
# Epoch 80/100
# 38/38 [==============================] - ETA: 0s - loss: 3.1329e-04 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 285ms/step - loss: 3.1329e-04 - accuracy: 1.0000 - val_loss: 0.3162 - val_accuracy: 0.9383
# Epoch 81/100
# 38/38 [==============================] - ETA: 0s - loss: 1.4027e-04 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 284ms/step - loss: 1.4027e-04 - accuracy: 1.0000 - val_loss: 0.2775 - val_accuracy: 0.9400
# Epoch 82/100
# 38/38 [==============================] - ETA: 0s - loss: 2.8920e-04 - accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 285ms/step - loss: 2.8920e-04 - accuracy: 1.0000 - val_loss: 0.2147 - val_accuracy: 0.9483
# Epoch 83/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6891e-04 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 0.96333
# 38/38 [==============================] - 11s 285ms/step - loss: 1.6891e-04 - accuracy: 1.0000 - val_loss: 0.1937 - val_accuracy: 0.9483
# Epoch 84/100
# 38/38 [==============================] - ETA: 0s - loss: 7.6165e-04 - accuracy: 0.9996
# Epoch 84: val_accuracy improved from 0.96333 to 0.96500, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 7.6165e-04 - accuracy: 0.9996 - val_loss: 0.1438 - val_accuracy: 0.9650
# Epoch 85/100
# 38/38 [==============================] - ETA: 0s - loss: 1.9865e-04 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.96500
# 38/38 [==============================] - 11s 285ms/step - loss: 1.9865e-04 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9650
# Epoch 86/100
# 38/38 [==============================] - ETA: 0s - loss: 1.9181e-04 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.96500
# 38/38 [==============================] - 11s 285ms/step - loss: 1.9181e-04 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9650
# Epoch 87/100
# 38/38 [==============================] - ETA: 0s - loss: 2.3782e-04 - accuracy: 1.0000
# Epoch 87: val_accuracy improved from 0.96500 to 0.97000, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 2.3782e-04 - accuracy: 1.0000 - val_loss: 0.1080 - val_accuracy: 0.9700
# Epoch 88/100
# 38/38 [==============================] - ETA: 0s - loss: 8.9277e-05 - accuracy: 1.0000
# Epoch 88: val_accuracy improved from 0.97000 to 0.97833, saving model to best_model.h5
# 38/38 [==============================] - 12s 309ms/step - loss: 8.9277e-05 - accuracy: 1.0000 - val_loss: 0.0819 - val_accuracy: 0.9783
# Epoch 89/100
# 38/38 [==============================] - ETA: 0s - loss: 7.3970e-04 - accuracy: 0.9996
# Epoch 89: val_accuracy improved from 0.97833 to 0.98000, saving model to best_model.h5
# 38/38 [==============================] - 12s 310ms/step - loss: 7.3970e-04 - accuracy: 0.9996 - val_loss: 0.0601 - val_accuracy: 0.9800
# Epoch 90/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9975
# Epoch 90: val_accuracy improved from 0.98000 to 0.98333, saving model to best_model.h5
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0088 - accuracy: 0.9975 - val_loss: 0.0741 - val_accuracy: 0.9833
# Epoch 91/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 91: val_accuracy did not improve from 0.98333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1494 - val_accuracy: 0.9600
# Epoch 92/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9992
# Epoch 92: val_accuracy did not improve from 0.98333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0799 - val_accuracy: 0.9767
# Epoch 93/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9987
# Epoch 93: val_accuracy did not improve from 0.98333
# 38/38 [==============================] - 11s 285ms/step - loss: 0.0021 - accuracy: 0.9987 - val_loss: 0.1219 - val_accuracy: 0.9633
# Epoch 94/100
# 38/38 [==============================] - ETA: 0s - loss: 9.9283e-04 - accuracy: 0.9996
# Epoch 94: val_accuracy did not improve from 0.98333
# 38/38 [==============================] - 11s 284ms/step - loss: 9.9283e-04 - accuracy: 0.9996 - val_loss: 0.0914 - val_accuracy: 0.9683
# Epoch 95/100
# 38/38 [==============================] - ETA: 0s - loss: 8.4228e-04 - accuracy: 1.0000
# Epoch 95: val_accuracy did not improve from 0.98333
# 38/38 [==============================] - 11s 284ms/step - loss: 8.4228e-04 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9667
# Epoch 96/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 0.98333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.9650
# Epoch 97/100
# 38/38 [==============================] - ETA: 0s - loss: 5.4714e-04 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 0.98333
# 38/38 [==============================] - 11s 284ms/step - loss: 5.4714e-04 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9650
# Epoch 98/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9992
# Epoch 98: val_accuracy did not improve from 0.98333
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.1241 - val_accuracy: 0.9733
# Epoch 99/100
# 38/38 [==============================] - ETA: 0s - loss: 9.2114e-04 - accuracy: 0.9996
# Epoch 99: val_accuracy improved from 0.98333 to 0.99000, saving model to best_model.h5
# 38/38 [==============================] - 12s 309ms/step - loss: 9.2114e-04 - accuracy: 0.9996 - val_loss: 0.0400 - val_accuracy: 0.9900
# Epoch 100/100
# 38/38 [==============================] - ETA: 0s - loss: 5.3338e-04 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 11s 285ms/step - loss: 5.3338e-04 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 0.9883

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 19/19 [==============================] - 2s 45ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("ShuffleNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# ShuffleNet MODEL SONUÇLARI
# Doğruluk:  0.99
# F1_Skor:  0.9902094257505248
# Hassasiyet:  0.9901504936377304
# Duyarlılık:  0.9903714446861654

# %%
plt.plot(hist_mobilnetv1.history['accuracy'])
plt.plot(hist_mobilnetv1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist_mobilnetv1.history['loss'])
plt.plot(hist_mobilnetv1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
cm_dense = confusion_matrix(Y_val, y_pred)
print(cm_dense)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm_dense, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# Confusion Matrix
# [[213   4   0]
#  [  1 196   0]
#  [  0   1 185]]
# <Axes: >
