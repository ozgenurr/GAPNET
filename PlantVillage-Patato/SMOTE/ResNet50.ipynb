# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']


train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Patato/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 2152 images belonging to 3 classes.
# (2152, 224, 224, 3)
# (2152, 3)

# %%
#Converting  our color images to a vector
x=x.reshape(2152,224*224*3)

# %%
x.shape
# Out:
# (2152, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (3000, 150528)

# %%
y_smote.shape
# Out:
# (3000, 3)

# %%
X_smote=X_smote.reshape(3000,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (2152, 150528)
# Shape of X after SMOTE: (3000, 224, 224, 3)

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (3000, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE= 64
SIZE=224
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
from keras.applications import ResNet50
def build_resnet50():
    resnet = ResNet50(weights='imagenet', include_top=True)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = resnet(x)
    x = Flatten(name="flatten")(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    # multi output
    output = Dense(3,activation = 'softmax', name='root')(x)
    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_resnet50 = build_resnet50()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 5s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 3)       84
#
#  resnet50 (Functional)       (None, 1000)              25636712
#
#  flatten (Flatten)           (None, 1000)              0
#
#  dropout (Dropout)           (None, 1000)              0
#
#  dense (Dense)               (None, 256)               256256
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 3)                 771
#
# =================================================================
# Total params: 25894847 (98.78 MB)
# Trainable params: 25841215 (98.58 MB)
# Non-trainable params: 53632 (209.50 KB)
# _________________________________________________________________

# %%
hist_resnet50 = model_resnet50.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 0.7144 - accuracy: 0.7417
# Epoch 1: val_accuracy improved from -inf to 0.31000, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - 75s 880ms/step - loss: 0.7144 - accuracy: 0.7417 - val_loss: 1.0993 - val_accuracy: 0.3100
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.9367
# Epoch 2: val_accuracy improved from 0.31000 to 0.32833, saving model to best_model.h5
# 38/38 [==============================] - 25s 662ms/step - loss: 0.3061 - accuracy: 0.9367 - val_loss: 1.0996 - val_accuracy: 0.3283
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9867
# Epoch 3: val_accuracy improved from 0.32833 to 0.36167, saving model to best_model.h5
# 38/38 [==============================] - 25s 668ms/step - loss: 0.1272 - accuracy: 0.9867 - val_loss: 1.0967 - val_accuracy: 0.3617
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9912
# Epoch 4: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 24s 645ms/step - loss: 0.0629 - accuracy: 0.9912 - val_loss: 1.0971 - val_accuracy: 0.3617
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9983
# Epoch 5: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 649ms/step - loss: 0.0311 - accuracy: 0.9983 - val_loss: 1.1034 - val_accuracy: 0.3617
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9983
# Epoch 6: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 655ms/step - loss: 0.0191 - accuracy: 0.9983 - val_loss: 1.1130 - val_accuracy: 0.3617
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9967
# Epoch 7: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 657ms/step - loss: 0.0240 - accuracy: 0.9967 - val_loss: 1.1118 - val_accuracy: 0.3617
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9946
# Epoch 8: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 661ms/step - loss: 0.0301 - accuracy: 0.9946 - val_loss: 1.1098 - val_accuracy: 0.3617
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9921
# Epoch 9: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 664ms/step - loss: 0.0330 - accuracy: 0.9921 - val_loss: 1.1152 - val_accuracy: 0.3617
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9975
# Epoch 10: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 666ms/step - loss: 0.0167 - accuracy: 0.9975 - val_loss: 1.1677 - val_accuracy: 0.3617
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9987
# Epoch 11: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 1.3026 - val_accuracy: 0.3617
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.4422 - val_accuracy: 0.3617
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9992
# Epoch 13: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 671ms/step - loss: 0.0067 - accuracy: 0.9992 - val_loss: 1.4636 - val_accuracy: 0.3617
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.5851 - val_accuracy: 0.3617
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9996
# Epoch 15: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 1.6391 - val_accuracy: 0.3617
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9983
# Epoch 16: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0090 - accuracy: 0.9983 - val_loss: 1.7049 - val_accuracy: 0.3617
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9987
# Epoch 17: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 1.9574 - val_accuracy: 0.3617
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.0420 - val_accuracy: 0.3617
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9996
# Epoch 19: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 2.3878 - val_accuracy: 0.3617
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9992
# Epoch 20: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0065 - accuracy: 0.9992 - val_loss: 2.6953 - val_accuracy: 0.3617
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.36167
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.0678 - val_accuracy: 0.3617
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9971
# Epoch 22: val_accuracy improved from 0.36167 to 0.38500, saving model to best_model.h5
# 38/38 [==============================] - 27s 700ms/step - loss: 0.0148 - accuracy: 0.9971 - val_loss: 2.4558 - val_accuracy: 0.3850
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9937
# Epoch 23: val_accuracy did not improve from 0.38500
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0239 - accuracy: 0.9937 - val_loss: 3.2905 - val_accuracy: 0.3283
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9950
# Epoch 24: val_accuracy did not improve from 0.38500
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0178 - accuracy: 0.9950 - val_loss: 5.1918 - val_accuracy: 0.3617
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9942
# Epoch 25: val_accuracy did not improve from 0.38500
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0184 - accuracy: 0.9942 - val_loss: 3.4130 - val_accuracy: 0.3617
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9979
# Epoch 26: val_accuracy did not improve from 0.38500
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0097 - accuracy: 0.9979 - val_loss: 3.1676 - val_accuracy: 0.3750
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9987
# Epoch 27: val_accuracy improved from 0.38500 to 0.44167, saving model to best_model.h5
# 38/38 [==============================] - 27s 702ms/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 2.7830 - val_accuracy: 0.4417
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9971
# Epoch 28: val_accuracy improved from 0.44167 to 0.54000, saving model to best_model.h5
# 38/38 [==============================] - 27s 700ms/step - loss: 0.0074 - accuracy: 0.9971 - val_loss: 1.8328 - val_accuracy: 0.5400
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9996
# Epoch 29: val_accuracy improved from 0.54000 to 0.59500, saving model to best_model.h5
# 38/38 [==============================] - 26s 699ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 1.7843 - val_accuracy: 0.5950
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9996
# Epoch 30: val_accuracy improved from 0.59500 to 0.74333, saving model to best_model.h5
# 38/38 [==============================] - 26s 698ms/step - loss: 0.0081 - accuracy: 0.9996 - val_loss: 0.8440 - val_accuracy: 0.7433
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9954
# Epoch 31: val_accuracy did not improve from 0.74333
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0164 - accuracy: 0.9954 - val_loss: 2.6574 - val_accuracy: 0.5333
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9954
# Epoch 32: val_accuracy improved from 0.74333 to 0.88833, saving model to best_model.h5
# 38/38 [==============================] - 26s 698ms/step - loss: 0.0185 - accuracy: 0.9954 - val_loss: 0.4763 - val_accuracy: 0.8883
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9996
# Epoch 33: val_accuracy improved from 0.88833 to 0.92667, saving model to best_model.h5
# 38/38 [==============================] - 26s 698ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.2712 - val_accuracy: 0.9267
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9987
# Epoch 34: val_accuracy improved from 0.92667 to 0.95333, saving model to best_model.h5
# 38/38 [==============================] - 26s 698ms/step - loss: 0.0069 - accuracy: 0.9987 - val_loss: 0.1773 - val_accuracy: 0.9533
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9975
# Epoch 35: val_accuracy improved from 0.95333 to 0.98000, saving model to best_model.h5
# 38/38 [==============================] - 26s 698ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0961 - val_accuracy: 0.9800
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9983
# Epoch 36: val_accuracy did not improve from 0.98000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0077 - accuracy: 0.9983 - val_loss: 0.0954 - val_accuracy: 0.9750
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9975
# Epoch 37: val_accuracy improved from 0.98000 to 0.99167, saving model to best_model.h5
# 38/38 [==============================] - 26s 698ms/step - loss: 0.0122 - accuracy: 0.9975 - val_loss: 0.0527 - val_accuracy: 0.9917
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9992
# Epoch 38: val_accuracy improved from 0.99167 to 0.99500, saving model to best_model.h5
# 38/38 [==============================] - 26s 697ms/step - loss: 0.0053 - accuracy: 0.9992 - val_loss: 0.0180 - val_accuracy: 0.9950
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9996
# Epoch 39: val_accuracy improved from 0.99500 to 0.99833, saving model to best_model.h5
# 38/38 [==============================] - 26s 699ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.0111 - val_accuracy: 0.9983
# Epoch 40/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9992
# Epoch 40: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0336 - val_accuracy: 0.9917
# Epoch 41/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9987
# Epoch 41: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0777 - val_accuracy: 0.9867
# Epoch 42/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9992
# Epoch 42: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.0347 - val_accuracy: 0.9933
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9967
# Epoch 43: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0114 - accuracy: 0.9967 - val_loss: 0.0383 - val_accuracy: 0.9917
# Epoch 44/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9983
# Epoch 44: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0119 - accuracy: 0.9983 - val_loss: 0.0022 - val_accuracy: 0.9983
# Epoch 45/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9987
# Epoch 45: val_accuracy improved from 0.99833 to 1.00000, saving model to best_model.h5
# 38/38 [==============================] - 27s 708ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 5.1365e-04 - val_accuracy: 1.0000
# Epoch 46/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9992
# Epoch 46: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 671ms/step - loss: 0.0066 - accuracy: 0.9992 - val_loss: 0.1725 - val_accuracy: 0.9667
# Epoch 47/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9983
# Epoch 47: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.0203 - val_accuracy: 0.9950
# Epoch 48/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9971
# Epoch 48: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0120 - accuracy: 0.9971 - val_loss: 0.0457 - val_accuracy: 0.9900
# Epoch 49/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9992
# Epoch 49: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0207 - val_accuracy: 0.9950
# Epoch 50/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9992
# Epoch 50: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 51/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 51: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0078 - val_accuracy: 0.9983
# Epoch 52/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9983
# Epoch 53/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 53: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0105 - val_accuracy: 0.9983
# Epoch 54/100
# 38/38 [==============================] - ETA: 0s - loss: 5.4243e-04 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 5.4243e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9967
# Epoch 55/100
# 38/38 [==============================] - ETA: 0s - loss: 5.4391e-04 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 671ms/step - loss: 5.4391e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9983
# Epoch 56/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9975
# Epoch 56: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0100 - accuracy: 0.9975 - val_loss: 0.0592 - val_accuracy: 0.9883
# Epoch 57/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9942
# Epoch 57: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0263 - accuracy: 0.9942 - val_loss: 2.2129 - val_accuracy: 0.7717
# Epoch 58/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9962
# Epoch 58: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0183 - accuracy: 0.9962 - val_loss: 0.3774 - val_accuracy: 0.9517
# Epoch 59/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9992
# Epoch 59: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0747 - val_accuracy: 0.9867
# Epoch 60/100
# 38/38 [==============================] - ETA: 0s - loss: 7.6469e-04 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 7.6469e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9983
# Epoch 61/100
# 38/38 [==============================] - ETA: 0s - loss: 8.2122e-04 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 8.2122e-04 - accuracy: 1.0000 - val_loss: 9.4971e-04 - val_accuracy: 1.0000
# Epoch 62/100
# 38/38 [==============================] - ETA: 0s - loss: 6.0463e-04 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 6.0463e-04 - accuracy: 1.0000 - val_loss: 3.8397e-04 - val_accuracy: 1.0000
# Epoch 63/100
# 38/38 [==============================] - ETA: 0s - loss: 6.9349e-04 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 6.9349e-04 - accuracy: 1.0000 - val_loss: 1.5656e-04 - val_accuracy: 1.0000
# Epoch 64/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 64: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0918 - val_accuracy: 0.9850
# Epoch 65/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 65: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0258 - val_accuracy: 0.9900
# Epoch 66/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7622e-04 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 9.7622e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9983
# Epoch 67/100
# 38/38 [==============================] - ETA: 0s - loss: 6.2590e-04 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 6.2590e-04 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 0.9983
# Epoch 68/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 68: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0085 - val_accuracy: 0.9967
# Epoch 69/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9983
# Epoch 69: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0082 - accuracy: 0.9983 - val_loss: 0.0287 - val_accuracy: 0.9950
# Epoch 70/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 0.9800
# Epoch 71/100
# 38/38 [==============================] - ETA: 0s - loss: 4.5376e-04 - accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 4.5376e-04 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9883
# Epoch 72/100
# 38/38 [==============================] - ETA: 0s - loss: 3.2267e-04 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 3.2267e-04 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9950
# Epoch 73/100
# 38/38 [==============================] - ETA: 0s - loss: 8.0006e-04 - accuracy: 0.9996
# Epoch 73: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 8.0006e-04 - accuracy: 0.9996 - val_loss: 0.0517 - val_accuracy: 0.9867
# Epoch 74/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9992
# Epoch 74: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0219 - val_accuracy: 0.9933
# Epoch 75/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9975
# Epoch 75: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 0.0327 - val_accuracy: 0.9950
# Epoch 76/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9975
# Epoch 76: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.0684 - val_accuracy: 0.9733
# Epoch 77/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9983
# Epoch 77: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0088 - accuracy: 0.9983 - val_loss: 0.0115 - val_accuracy: 0.9983
# Epoch 78/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9975
# Epoch 78: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0130 - accuracy: 0.9975 - val_loss: 0.0379 - val_accuracy: 0.9933
# Epoch 79/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9996
# Epoch 79: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0053 - accuracy: 0.9996 - val_loss: 0.0087 - val_accuracy: 0.9983
# Epoch 80/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9996
# Epoch 80: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.0146 - val_accuracy: 0.9950
# Epoch 81/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9979
# Epoch 81: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0090 - accuracy: 0.9979 - val_loss: 0.0077 - val_accuracy: 0.9983
# Epoch 82/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9962
# Epoch 82: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0145 - accuracy: 0.9962 - val_loss: 0.0147 - val_accuracy: 0.9983
# Epoch 83/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9950
# Epoch 84/100
# 38/38 [==============================] - ETA: 0s - loss: 6.3957e-04 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 6.3957e-04 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9983
# Epoch 85/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9996
# Epoch 85: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.0085 - val_accuracy: 0.9950
# Epoch 86/100
# 38/38 [==============================] - ETA: 0s - loss: 7.1866e-04 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 7.1866e-04 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 0.9983
# Epoch 87/100
# 38/38 [==============================] - ETA: 0s - loss: 2.3292e-04 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 2.3292e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9983
# Epoch 88/100
# 38/38 [==============================] - ETA: 0s - loss: 6.4755e-04 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 6.4755e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9983
# Epoch 89/100
# 38/38 [==============================] - ETA: 0s - loss: 6.4829e-04 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 6.4829e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9983
# Epoch 90/100
# 38/38 [==============================] - ETA: 0s - loss: 6.7125e-04 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 6.7125e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 0.9983
# Epoch 91/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9996
# Epoch 91: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 7.8978e-05 - val_accuracy: 1.0000
# Epoch 92/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9987
# Epoch 92: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0078 - accuracy: 0.9987 - val_loss: 0.2257 - val_accuracy: 0.9600
# Epoch 93/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9987
# Epoch 93: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.1199 - val_accuracy: 0.9750
# Epoch 94/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9987
# Epoch 94: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0611 - val_accuracy: 0.9883
# Epoch 95/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9992
# Epoch 95: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0082 - val_accuracy: 0.9967
# Epoch 96/100
# 38/38 [==============================] - ETA: 0s - loss: 6.1690e-04 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 6.1690e-04 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9983
# Epoch 97/100
# 38/38 [==============================] - ETA: 0s - loss: 4.1227e-04 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 670ms/step - loss: 4.1227e-04 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9967
# Epoch 98/100
# 38/38 [==============================] - ETA: 0s - loss: 2.1182e-04 - accuracy: 1.0000
# Epoch 98: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 669ms/step - loss: 2.1182e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9967
# Epoch 99/100
# 38/38 [==============================] - ETA: 0s - loss: 3.4392e-04 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 3.4392e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9983
# Epoch 100/100
# 38/38 [==============================] - ETA: 0s - loss: 2.5479e-04 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 25s 668ms/step - loss: 2.5479e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 0.9983

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 19/19 [==============================] - 3s 96ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("ShuffleNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# ShuffleNet MODEL SONUÇLARI
# Doğruluk:  1.0
# F1_Skor:  1.0
# Hassasiyet:  1.0
# Duyarlılık:  1.0

# %%
plt.plot(hist_resnet50.history['accuracy'])
plt.plot(hist_resnet50.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist_resnet50.history['loss'])
plt.plot(hist_resnet50.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# Confusion Matrix
# [[217   0   0]
#  [  0 197   0]
#  [  0   0 186]]
# <Axes: >
