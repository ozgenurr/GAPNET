# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']


train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Patato/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 2152 images belonging to 3 classes.
# (2152, 224, 224, 3)
# (2152, 3)

# %%
#Converting  our color images to a vector
x=x.reshape(2152,224*224*3)

# %%
x.shape
# Out:
# (2152, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (3000, 150528)

# %%
y_smote.shape
# Out:
# (3000, 3)

# %%
X_smote=X_smote.reshape(3000,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (2152, 150528)
# Shape of X after SMOTE: (3000, 224, 224, 3)

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (3000, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
from keras.applications import Xception
def build_xception():
    xception = Xception(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = xception(x)
    x = Flatten(name="flatten")(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    # multi output
    output = Dense(3,activation = 'softmax', name='root')(x)
    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_xception= build_xception()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 5s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_4 (Conv2D)           (None, 224, 224, 3)       84
#
#  xception (Functional)       (None, None, None, 2048   20861480
#                              )
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dropout (Dropout)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 3)                 771
#
# =================================================================
# Total params: 46553727 (177.59 MB)
# Trainable params: 46498687 (177.38 MB)
# Non-trainable params: 55040 (215.00 KB)
# _________________________________________________________________

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist_xception=model_xception.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3950 - accuracy: 0.8746
# Epoch 1: val_accuracy improved from -inf to 0.49667, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - 80s 1s/step - loss: 0.3950 - accuracy: 0.8746 - val_loss: 1.8125 - val_accuracy: 0.4967
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9896
# Epoch 2: val_accuracy improved from 0.49667 to 0.58833, saving model to best_model.h5
# 38/38 [==============================] - 41s 1s/step - loss: 0.0290 - accuracy: 0.9896 - val_loss: 1.5647 - val_accuracy: 0.5883
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9950
# Epoch 3: val_accuracy improved from 0.58833 to 0.71500, saving model to best_model.h5
# 38/38 [==============================] - 42s 1s/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 0.9392 - val_accuracy: 0.7150
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9975
# Epoch 4: val_accuracy improved from 0.71500 to 0.78333, saving model to best_model.h5
# 38/38 [==============================] - 42s 1s/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.6868 - val_accuracy: 0.7833
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9996
# Epoch 5: val_accuracy improved from 0.78333 to 0.82167, saving model to best_model.h5
# 38/38 [==============================] - 41s 1s/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.6360 - val_accuracy: 0.8217
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 6: val_accuracy improved from 0.82167 to 0.84167, saving model to best_model.h5
# 38/38 [==============================] - 42s 1s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5809 - val_accuracy: 0.8417
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9983
# Epoch 7: val_accuracy improved from 0.84167 to 0.90500, saving model to best_model.h5
# 38/38 [==============================] - 41s 1s/step - loss: 0.0034 - accuracy: 0.9983 - val_loss: 0.3589 - val_accuracy: 0.9050
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9975
# Epoch 8: val_accuracy did not improve from 0.90500
# 38/38 [==============================] - 40s 1s/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.4287 - val_accuracy: 0.8850
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9983
# Epoch 9: val_accuracy improved from 0.90500 to 0.95167, saving model to best_model.h5
# 38/38 [==============================] - 41s 1s/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.1596 - val_accuracy: 0.9517
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 9.9268e-04 - accuracy: 1.0000
# Epoch 10: val_accuracy improved from 0.95167 to 0.96333, saving model to best_model.h5
# 38/38 [==============================] - 43s 1s/step - loss: 9.9268e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9633
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 5.4659e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy improved from 0.96333 to 0.97667, saving model to best_model.h5
# 38/38 [==============================] - 42s 1s/step - loss: 5.4659e-04 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9767
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 5.2922e-04 - accuracy: 1.0000
# Epoch 12: val_accuracy improved from 0.97667 to 0.98333, saving model to best_model.h5
# 38/38 [==============================] - 42s 1s/step - loss: 5.2922e-04 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9833
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9992
# Epoch 13: val_accuracy did not improve from 0.98333
# 38/38 [==============================] - 40s 1s/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 0.0521 - val_accuracy: 0.9833
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 8.0582e-04 - accuracy: 1.0000
# Epoch 14: val_accuracy improved from 0.98333 to 0.98500, saving model to best_model.h5
# 38/38 [==============================] - 42s 1s/step - loss: 8.0582e-04 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 0.9850
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9992
# Epoch 15: val_accuracy improved from 0.98500 to 0.98833, saving model to best_model.h5
# 38/38 [==============================] - 42s 1s/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.0577 - val_accuracy: 0.9883
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 2.8733e-04 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 40s 1s/step - loss: 2.8733e-04 - accuracy: 1.0000 - val_loss: 0.0513 - val_accuracy: 0.9883
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 3.2981e-04 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 40s 1s/step - loss: 3.2981e-04 - accuracy: 1.0000 - val_loss: 0.0509 - val_accuracy: 0.9883
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9992
# Epoch 18: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 40s 1s/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0509 - val_accuracy: 0.9850
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 7.0715e-04 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 40s 1s/step - loss: 7.0715e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9783
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 3.4706e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 40s 1s/step - loss: 3.4706e-04 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9850
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 8.6034e-04 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 40s 1s/step - loss: 8.6034e-04 - accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 0.9867
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 8.4686e-04 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 40s 1s/step - loss: 8.4686e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9883
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2817e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 40s 1s/step - loss: 1.2817e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9883
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 2.4446e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 40s 1s/step - loss: 2.4446e-04 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9883
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 3.9528e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy improved from 0.98833 to 0.99000, saving model to best_model.h5
# 38/38 [==============================] - 42s 1s/step - loss: 3.9528e-04 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9900
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 6.5194e-05 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 6.5194e-05 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9900
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 3.2464e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 3.2464e-04 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9867
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 6.8856e-05 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 6.8856e-05 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9900
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3874e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 1.3874e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9850
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8267e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 1.8267e-04 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9900
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 9.9425e-05 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 9.9425e-05 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9850
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3731e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 1.3731e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9850
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 3.2885e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 3.2885e-04 - accuracy: 1.0000 - val_loss: 0.0471 - val_accuracy: 0.9867
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 7.4640e-04 - accuracy: 0.9996
# Epoch 34: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 7.4640e-04 - accuracy: 0.9996 - val_loss: 0.0836 - val_accuracy: 0.9767
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 9.6282e-04 - accuracy: 0.9996
# Epoch 35: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 9.6282e-04 - accuracy: 0.9996 - val_loss: 0.0881 - val_accuracy: 0.9750
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 4.4716e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 4.4716e-04 - accuracy: 1.0000 - val_loss: 0.0493 - val_accuracy: 0.9867
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 3.0586e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 40s 1s/step - loss: 3.0586e-04 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9883
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 2.0123e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy improved from 0.99000 to 0.99500, saving model to best_model.h5
# 38/38 [==============================] - 41s 1s/step - loss: 2.0123e-04 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9950
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 9.9016e-05 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 9.9016e-05 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9950
# Epoch 40/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5190e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 1.5190e-04 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 0.9950
# Epoch 41/100
# 38/38 [==============================] - ETA: 0s - loss: 7.6153e-05 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 7.6153e-05 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9933
# Epoch 42/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8514e-04 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 1.8514e-04 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9933
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 7.0337e-05 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 7.0337e-05 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 0.9933
# Epoch 44/100
# 38/38 [==============================] - ETA: 0s - loss: 3.3102e-05 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 3.3102e-05 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 0.9933
# Epoch 45/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8988e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 1.8988e-04 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9900
# Epoch 46/100
# 38/38 [==============================] - ETA: 0s - loss: 8.1420e-05 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 8.1420e-05 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9917
# Epoch 47/100
# 38/38 [==============================] - ETA: 0s - loss: 7.2287e-05 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 7.2287e-05 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9933
# Epoch 48/100
# 38/38 [==============================] - ETA: 0s - loss: 7.7683e-05 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 7.7683e-05 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9950
# Epoch 49/100
# 38/38 [==============================] - ETA: 0s - loss: 6.4392e-05 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 40s 1s/step - loss: 6.4392e-05 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9933
# Epoch 50/100
# 38/38 [==============================] - ETA: 0s - loss: 2.0137e-04 - accuracy: 1.0000
# Epoch 50: val_accuracy improved from 0.99500 to 0.99667, saving model to best_model.h5
# 38/38 [==============================] - 42s 1s/step - loss: 2.0137e-04 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9967
# Epoch 51/100
# 38/38 [==============================] - ETA: 0s - loss: 4.9207e-05 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 4.9207e-05 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 0.9950
# Epoch 52/100
# 38/38 [==============================] - ETA: 0s - loss: 4.2762e-05 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 4.2762e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9933
# Epoch 53/100
# 38/38 [==============================] - ETA: 0s - loss: 3.3786e-05 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 3.3786e-05 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9933
# Epoch 54/100
# 38/38 [==============================] - ETA: 0s - loss: 2.9187e-05 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 2.9187e-05 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9933
# Epoch 55/100
# 38/38 [==============================] - ETA: 0s - loss: 2.7027e-05 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 2.7027e-05 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9933
# Epoch 56/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6136e-05 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 1.6136e-05 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 0.9933
# Epoch 57/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3058e-04 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 1.3058e-04 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9933
# Epoch 58/100
# 38/38 [==============================] - ETA: 0s - loss: 3.3617e-05 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 3.3617e-05 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9950
# Epoch 59/100
# 38/38 [==============================] - ETA: 0s - loss: 4.7397e-05 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 4.7397e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9950
# Epoch 60/100
# 38/38 [==============================] - ETA: 0s - loss: 2.9745e-05 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 2.9745e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9950
# Epoch 61/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8689e-05 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 1.8689e-05 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9950
# Epoch 62/100
# 38/38 [==============================] - ETA: 0s - loss: 2.7371e-05 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 2.7371e-05 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9933
# Epoch 63/100
# 38/38 [==============================] - ETA: 0s - loss: 5.1305e-05 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 5.1305e-05 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9950
# Epoch 64/100
# 38/38 [==============================] - ETA: 0s - loss: 5.7412e-05 - accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 5.7412e-05 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9950
# Epoch 65/100
# 38/38 [==============================] - ETA: 0s - loss: 3.0614e-05 - accuracy: 1.0000
# Epoch 65: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 3.0614e-05 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9967
# Epoch 66/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5994e-05 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 1.5994e-05 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9967
# Epoch 67/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3810e-05 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 1.3810e-05 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9967
# Epoch 68/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6125e-05 - accuracy: 1.0000
# Epoch 68: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 1.6125e-05 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9950
# Epoch 69/100
# 38/38 [==============================] - ETA: 0s - loss: 3.6615e-05 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 3.6615e-05 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9967
# Epoch 70/100
# 38/38 [==============================] - ETA: 0s - loss: 8.3294e-05 - accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 8.3294e-05 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9950
# Epoch 71/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9950
# Epoch 71: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 0.0121 - accuracy: 0.9950 - val_loss: 0.1593 - val_accuracy: 0.9667
# Epoch 72/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9871
# Epoch 72: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 0.0371 - accuracy: 0.9871 - val_loss: 0.1000 - val_accuracy: 0.9767
# Epoch 73/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9904
# Epoch 73: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 0.0378 - accuracy: 0.9904 - val_loss: 0.1404 - val_accuracy: 0.9717
# Epoch 74/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9979
# Epoch 74: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.0281 - val_accuracy: 0.9867
# Epoch 75/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9967
# Epoch 75: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 40s 1s/step - loss: 0.0158 - accuracy: 0.9967 - val_loss: 0.0342 - val_accuracy: 0.9900
# Epoch 76/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9950
# Epoch 76: val_accuracy improved from 0.99667 to 1.00000, saving model to best_model.h5
# 38/38 [==============================] - 41s 1s/step - loss: 0.0101 - accuracy: 0.9950 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 77/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9983
# Epoch 77: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0031 - accuracy: 0.9983 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 78/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9983
# Epoch 78: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0091 - accuracy: 0.9983 - val_loss: 0.0024 - val_accuracy: 0.9983
# Epoch 79/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9979
# Epoch 79: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0200 - val_accuracy: 0.9883
# Epoch 80/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 80: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0096 - val_accuracy: 0.9967
# Epoch 81/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9979
# Epoch 81: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0606 - val_accuracy: 0.9817
# Epoch 82/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9987
# Epoch 82: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 5.7945e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9992
# Epoch 83: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 6.8293e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 38/38 [==============================] - ETA: 0s - loss: 4.9702e-04 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 4.9702e-04 - accuracy: 1.0000 - val_loss: 5.2599e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 38/38 [==============================] - ETA: 0s - loss: 7.3397e-04 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 7.3397e-04 - accuracy: 1.0000 - val_loss: 4.2020e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 38/38 [==============================] - ETA: 0s - loss: 3.9655e-04 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 3.9655e-04 - accuracy: 1.0000 - val_loss: 9.5177e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 38/38 [==============================] - ETA: 0s - loss: 4.4722e-04 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 4.4722e-04 - accuracy: 1.0000 - val_loss: 4.8312e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 38/38 [==============================] - ETA: 0s - loss: 3.1495e-04 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 3.1495e-04 - accuracy: 1.0000 - val_loss: 3.3635e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 89: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 90/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9987
# Epoch 90: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.0032 - val_accuracy: 0.9983
# Epoch 91/100
# 38/38 [==============================] - ETA: 0s - loss: 9.0739e-04 - accuracy: 0.9996
# Epoch 91: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 9.0739e-04 - accuracy: 0.9996 - val_loss: 0.0154 - val_accuracy: 0.9950
# Epoch 92/100
# 38/38 [==============================] - ETA: 0s - loss: 2.9525e-04 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 2.9525e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 93/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2408e-04 - accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 1.2408e-04 - accuracy: 1.0000 - val_loss: 9.8737e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 38/38 [==============================] - ETA: 0s - loss: 1.7249e-04 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 1.7249e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 95/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 95: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 96/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9996
# Epoch 96: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.1295 - val_accuracy: 0.9717
# Epoch 97/100
# 38/38 [==============================] - ETA: 0s - loss: 4.5585e-04 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 4.5585e-04 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9850
# Epoch 98/100
# 38/38 [==============================] - ETA: 0s - loss: 2.6604e-04 - accuracy: 1.0000
# Epoch 98: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 2.6604e-04 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9950
# Epoch 99/100
# 38/38 [==============================] - ETA: 0s - loss: 8.4490e-04 - accuracy: 0.9996
# Epoch 99: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 8.4490e-04 - accuracy: 0.9996 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 100/100
# 38/38 [==============================] - ETA: 0s - loss: 5.2110e-05 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 40s 1s/step - loss: 5.2110e-05 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 19/19 [==============================] - 3s 144ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("ShuffleNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# ShuffleNet MODEL SONUÇLARI
# Doğruluk:  1.0
# F1_Skor:  1.0
# Hassasiyet:  1.0
# Duyarlılık:  1.0

# %%
plt.plot(hist_xception.history['accuracy'])
plt.plot(hist_xception.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist_xception.history['loss'])
plt.plot(hist_xception.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
cm_dense = confusion_matrix(Y_val, y_pred)
print(cm_dense)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm_dense, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# Confusion Matrix
# [[217   0   0]
#  [  0 197   0]
#  [  0   0 186]]
# <Axes: >
