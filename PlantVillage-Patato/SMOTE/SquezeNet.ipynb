# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']


train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Patato/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 2152 images belonging to 3 classes.
# (2152, 224, 224, 3)
# (2152, 3)

# %%
#Converting  our color images to a vector
x=x.reshape(2152,224*224*3)

# %%
x.shape
# Out:
# (2152, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (3000, 150528)

# %%
y_smote.shape
# Out:
# (3000, 3)

# %%
X_smote=X_smote.reshape(3000,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (2152, 150528)
# Shape of X after SMOTE: (3000, 224, 224, 3)

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (3000, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
pip install keras_applications
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
from keras_applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
from keras.layers import Input, Convolution2D, MaxPooling2D, Activation, concatenate, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.utils import get_file
#from keras.utils import layer_utils

sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"

WEIGHTS_PATH = "https://github.com/rcmalli/keras-squeezenet/releases/download/v1.0/squeezenet_weights_tf_dim_ordering_tf_kernels.h5"

# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3

    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


# Original SqueezeNet from paper.

def SqueezeNet(input_tensor=None, input_shape=None,
               weights='imagenet',
               classes=1000,
              use_bn_on_input = False, # to avoid preprocessing
               first_stride = 2
              ):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')


    input_shape = _obtain_input_shape(input_shape,
                                      default_size=227,
                                      min_size=48,
                                      data_format=K.image_data_format(),
                                     require_flatten = False)

    if input_tensor is None:
        raw_img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if use_bn_on_input:
        img_input = BatchNormalization()(raw_img_input)
    else:
        img_input = raw_img_input


    x = Convolution2D(64, (3, 3), strides=(first_stride, first_stride), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    x = fire_module(x, fire_id=9, squeeze=64, expand=256)
    x = Dropout(0.5, name='drop9')(x)

    x = Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = Activation('relu', name='relu_conv10')(x)
    x = GlobalAveragePooling2D()(x)
    out = Activation('softmax', name='loss')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = raw_img_input

    model = Model(inputs, out, name='squeezenet')

    # load weights
    if weights == 'imagenet':

        weights_path = get_file('squeezenet_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model

# %%
model = SqueezeNet(input_shape = X_train.shape[1:], weights = None, classes = Y_train.shape[1],
                  use_bn_on_input = True)
# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.Adam(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
loss_history = []
model.summary()
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  batch_normalization (Batch  (None, 224, 224, 3)          12        ['input_1[0][0]']
#  Normalization)
#
#  conv1 (Conv2D)              (None, 111, 111, 64)         1792      ['batch_normalization[0][0]']
#
#  relu_conv1 (Activation)     (None, 111, 111, 64)         0         ['conv1[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 55, 55, 64)           0         ['relu_conv1[0][0]']
#
#  fire2/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           1040      ['pool1[0][0]']
#
#  fire2/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire2/squeeze1x1[0][0]']
#  ivation)
#
#  fire2/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire2/expand1x1[0][0]']
#  vation)
#
#  fire2/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire2/expand3x3[0][0]']
#  vation)
#
#  fire2/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire2/relu_expand1x1[0][0]',
#                                                                      'fire2/relu_expand3x3[0][0]']
#
#  fire3/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           2064      ['fire2/concat[0][0]']
#
#  fire3/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire3/squeeze1x1[0][0]']
#  ivation)
#
#  fire3/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire3/expand1x1[0][0]']
#  vation)
#
#  fire3/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire3/expand3x3[0][0]']
#  vation)
#
#  fire3/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire3/relu_expand1x1[0][0]',
#                                                                      'fire3/relu_expand3x3[0][0]']
#
#  pool3 (MaxPooling2D)        (None, 27, 27, 128)          0         ['fire3/concat[0][0]']
#
#  fire4/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           4128      ['pool3[0][0]']
#
#  fire4/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire4/squeeze1x1[0][0]']
#  ivation)
#
#  fire4/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire4/expand1x1[0][0]']
#  vation)
#
#  fire4/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire4/expand3x3[0][0]']
#  vation)
#
#  fire4/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire4/relu_expand1x1[0][0]',
#                                                                      'fire4/relu_expand3x3[0][0]']
#
#  fire5/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           8224      ['fire4/concat[0][0]']
#
#  fire5/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire5/squeeze1x1[0][0]']
#  ivation)
#
#  fire5/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire5/expand1x1[0][0]']
#  vation)
#
#  fire5/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire5/expand3x3[0][0]']
#  vation)
#
#  fire5/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire5/relu_expand1x1[0][0]',
#                                                                      'fire5/relu_expand3x3[0][0]']
#
#  pool5 (MaxPooling2D)        (None, 13, 13, 256)          0         ['fire5/concat[0][0]']
#
#  fire6/squeeze1x1 (Conv2D)   (None, 13, 13, 48)           12336     ['pool5[0][0]']
#
#  fire6/relu_squeeze1x1 (Act  (None, 13, 13, 48)           0         ['fire6/squeeze1x1[0][0]']
#  ivation)
#
#  fire6/expand1x1 (Conv2D)    (None, 13, 13, 192)          9408      ['fire6/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire6/expand3x3 (Conv2D)    (None, 13, 13, 192)          83136     ['fire6/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire6/relu_expand1x1 (Acti  (None, 13, 13, 192)          0         ['fire6/expand1x1[0][0]']
#  vation)
#
#  fire6/relu_expand3x3 (Acti  (None, 13, 13, 192)          0         ['fire6/expand3x3[0][0]']
#  vation)
#
#  fire6/concat (Concatenate)  (None, 13, 13, 384)          0         ['fire6/relu_expand1x1[0][0]',
#                                                                      'fire6/relu_expand3x3[0][0]']
#
#  fire7/squeeze1x1 (Conv2D)   (None, 13, 13, 48)           18480     ['fire6/concat[0][0]']
#
#  fire7/relu_squeeze1x1 (Act  (None, 13, 13, 48)           0         ['fire7/squeeze1x1[0][0]']
#  ivation)
#
#  fire7/expand1x1 (Conv2D)    (None, 13, 13, 192)          9408      ['fire7/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire7/expand3x3 (Conv2D)    (None, 13, 13, 192)          83136     ['fire7/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire7/relu_expand1x1 (Acti  (None, 13, 13, 192)          0         ['fire7/expand1x1[0][0]']
#  vation)
#
#  fire7/relu_expand3x3 (Acti  (None, 13, 13, 192)          0         ['fire7/expand3x3[0][0]']
#  vation)
#
#  fire7/concat (Concatenate)  (None, 13, 13, 384)          0         ['fire7/relu_expand1x1[0][0]',
#                                                                      'fire7/relu_expand3x3[0][0]']
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#  fire8/squeeze1x1 (Conv2D)   (None, 13, 13, 64)           24640     ['fire7/concat[0][0]']
#
#  fire8/relu_squeeze1x1 (Act  (None, 13, 13, 64)           0         ['fire8/squeeze1x1[0][0]']
#  ivation)
#
#  fire8/expand1x1 (Conv2D)    (None, 13, 13, 256)          16640     ['fire8/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire8/expand3x3 (Conv2D)    (None, 13, 13, 256)          147712    ['fire8/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire8/relu_expand1x1 (Acti  (None, 13, 13, 256)          0         ['fire8/expand1x1[0][0]']
#  vation)
#
#  fire8/relu_expand3x3 (Acti  (None, 13, 13, 256)          0         ['fire8/expand3x3[0][0]']
#  vation)
#
#  fire8/concat (Concatenate)  (None, 13, 13, 512)          0         ['fire8/relu_expand1x1[0][0]',
#                                                                      'fire8/relu_expand3x3[0][0]']
#
#  fire9/squeeze1x1 (Conv2D)   (None, 13, 13, 64)           32832     ['fire8/concat[0][0]']
#
#  fire9/relu_squeeze1x1 (Act  (None, 13, 13, 64)           0         ['fire9/squeeze1x1[0][0]']
#  ivation)
#
#  fire9/expand1x1 (Conv2D)    (None, 13, 13, 256)          16640     ['fire9/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire9/expand3x3 (Conv2D)    (None, 13, 13, 256)          147712    ['fire9/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire9/relu_expand1x1 (Acti  (None, 13, 13, 256)          0         ['fire9/expand1x1[0][0]']
#  vation)
#
#  fire9/relu_expand3x3 (Acti  (None, 13, 13, 256)          0         ['fire9/expand3x3[0][0]']
#  vation)
#
#  fire9/concat (Concatenate)  (None, 13, 13, 512)          0         ['fire9/relu_expand1x1[0][0]',
#                                                                      'fire9/relu_expand3x3[0][0]']
#
#  drop9 (Dropout)             (None, 13, 13, 512)          0         ['fire9/concat[0][0]']
#
#  conv10 (Conv2D)             (None, 13, 13, 3)            1539      ['drop9[0][0]']
#
#  relu_conv10 (Activation)    (None, 13, 13, 3)            0         ['conv10[0][0]']
#
#  global_average_pooling2d (  (None, 3)                    0         ['relu_conv10[0][0]']
#  GlobalAveragePooling2D)
#
#  loss (Activation)           (None, 3)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 724047 (2.76 MB)
# Trainable params: 724041 (2.76 MB)
# Non-trainable params: 6 (24.00 Byte)
# __________________________________________________________________________________________________

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=227
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist=model.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0878 - accuracy: 0.5079
# Epoch 1: val_accuracy improved from -inf to 0.54500, saving model to best_model.h5
# 38/38 [==============================] - 20s 176ms/step - loss: 1.0878 - accuracy: 0.5079 - val_loss: 1.0825 - val_accuracy: 0.5450
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - ETA: 0s - loss: 0.7576 - accuracy: 0.6821
# Epoch 2: val_accuracy did not improve from 0.54500
# 38/38 [==============================] - 4s 113ms/step - loss: 0.7576 - accuracy: 0.6821 - val_loss: 1.4212 - val_accuracy: 0.2833
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.5297 - accuracy: 0.7713
# Epoch 3: val_accuracy did not improve from 0.54500
# 38/38 [==============================] - 4s 114ms/step - loss: 0.5297 - accuracy: 0.7713 - val_loss: 1.0476 - val_accuracy: 0.3367
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4211 - accuracy: 0.8208
# Epoch 4: val_accuracy did not improve from 0.54500
# 38/38 [==============================] - 4s 114ms/step - loss: 0.4211 - accuracy: 0.8208 - val_loss: 0.8797 - val_accuracy: 0.4683
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.9075
# Epoch 5: val_accuracy improved from 0.54500 to 0.61500, saving model to best_model.h5
# 38/38 [==============================] - 4s 118ms/step - loss: 0.2668 - accuracy: 0.9075 - val_loss: 0.7576 - val_accuracy: 0.6150
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9350
# Epoch 6: val_accuracy improved from 0.61500 to 0.84333, saving model to best_model.h5
# 38/38 [==============================] - 4s 118ms/step - loss: 0.1935 - accuracy: 0.9350 - val_loss: 0.3689 - val_accuracy: 0.8433
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1721 - accuracy: 0.9442
# Epoch 7: val_accuracy did not improve from 0.84333
# 38/38 [==============================] - 4s 114ms/step - loss: 0.1721 - accuracy: 0.9442 - val_loss: 0.4836 - val_accuracy: 0.7917
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9262
# Epoch 8: val_accuracy did not improve from 0.84333
# 38/38 [==============================] - 4s 115ms/step - loss: 0.2131 - accuracy: 0.9262 - val_loss: 0.3985 - val_accuracy: 0.8400
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1677 - accuracy: 0.9475
# Epoch 9: val_accuracy improved from 0.84333 to 0.94500, saving model to best_model.h5
# 38/38 [==============================] - 5s 119ms/step - loss: 0.1677 - accuracy: 0.9475 - val_loss: 0.1765 - val_accuracy: 0.9450
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9496
# Epoch 10: val_accuracy did not improve from 0.94500
# 38/38 [==============================] - 4s 115ms/step - loss: 0.1540 - accuracy: 0.9496 - val_loss: 0.2550 - val_accuracy: 0.8967
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9608
# Epoch 11: val_accuracy improved from 0.94500 to 0.95833, saving model to best_model.h5
# 38/38 [==============================] - 5s 119ms/step - loss: 0.1220 - accuracy: 0.9608 - val_loss: 0.1206 - val_accuracy: 0.9583
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9667
# Epoch 12: val_accuracy did not improve from 0.95833
# 38/38 [==============================] - 4s 115ms/step - loss: 0.1087 - accuracy: 0.9667 - val_loss: 0.1216 - val_accuracy: 0.9517
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9663
# Epoch 13: val_accuracy improved from 0.95833 to 0.96833, saving model to best_model.h5
# 38/38 [==============================] - 5s 120ms/step - loss: 0.1094 - accuracy: 0.9663 - val_loss: 0.0998 - val_accuracy: 0.9683
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9692
# Epoch 14: val_accuracy did not improve from 0.96833
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0988 - accuracy: 0.9692 - val_loss: 0.0924 - val_accuracy: 0.9633
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9696
# Epoch 15: val_accuracy did not improve from 0.96833
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0857 - accuracy: 0.9696 - val_loss: 0.2721 - val_accuracy: 0.8867
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9675
# Epoch 16: val_accuracy did not improve from 0.96833
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0883 - accuracy: 0.9675 - val_loss: 0.1067 - val_accuracy: 0.9667
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9692
# Epoch 17: val_accuracy did not improve from 0.96833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0900 - accuracy: 0.9692 - val_loss: 0.0825 - val_accuracy: 0.9667
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9696
# Epoch 18: val_accuracy improved from 0.96833 to 0.97500, saving model to best_model.h5
# 38/38 [==============================] - 5s 121ms/step - loss: 0.0881 - accuracy: 0.9696 - val_loss: 0.0870 - val_accuracy: 0.9750
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9742
# Epoch 19: val_accuracy did not improve from 0.97500
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0677 - accuracy: 0.9742 - val_loss: 0.1277 - val_accuracy: 0.9483
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9700
# Epoch 20: val_accuracy improved from 0.97500 to 0.98667, saving model to best_model.h5
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0817 - accuracy: 0.9700 - val_loss: 0.0598 - val_accuracy: 0.9867
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9704
# Epoch 21: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0791 - accuracy: 0.9704 - val_loss: 0.0560 - val_accuracy: 0.9767
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9729
# Epoch 22: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0817 - accuracy: 0.9729 - val_loss: 0.0806 - val_accuracy: 0.9650
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9808
# Epoch 23: val_accuracy improved from 0.98667 to 0.98833, saving model to best_model.h5
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0593 - accuracy: 0.9808 - val_loss: 0.0459 - val_accuracy: 0.9883
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9783
# Epoch 24: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 119ms/step - loss: 0.0578 - accuracy: 0.9783 - val_loss: 0.0482 - val_accuracy: 0.9850
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9804
# Epoch 25: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0559 - accuracy: 0.9804 - val_loss: 0.0666 - val_accuracy: 0.9733
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9800
# Epoch 26: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 5s 119ms/step - loss: 0.0485 - accuracy: 0.9800 - val_loss: 0.0487 - val_accuracy: 0.9883
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0646 - accuracy: 0.9771
# Epoch 27: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0646 - accuracy: 0.9771 - val_loss: 0.0460 - val_accuracy: 0.9850
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9725
# Epoch 28: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0767 - accuracy: 0.9725 - val_loss: 0.0733 - val_accuracy: 0.9617
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9875
# Epoch 29: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0417 - accuracy: 0.9875 - val_loss: 0.0416 - val_accuracy: 0.9833
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9800
# Epoch 30: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0568 - accuracy: 0.9800 - val_loss: 0.1062 - val_accuracy: 0.9617
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 0.9862
# Epoch 31: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0433 - accuracy: 0.9862 - val_loss: 0.0293 - val_accuracy: 0.9883
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9829
# Epoch 32: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0466 - accuracy: 0.9829 - val_loss: 0.0425 - val_accuracy: 0.9850
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9812
# Epoch 33: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0494 - accuracy: 0.9812 - val_loss: 0.0726 - val_accuracy: 0.9700
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9912
# Epoch 34: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0258 - accuracy: 0.9912 - val_loss: 0.0375 - val_accuracy: 0.9867
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9796
# Epoch 35: val_accuracy improved from 0.98833 to 0.99167, saving model to best_model.h5
# 38/38 [==============================] - 5s 121ms/step - loss: 0.0641 - accuracy: 0.9796 - val_loss: 0.0308 - val_accuracy: 0.9917
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9712
# Epoch 36: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0801 - accuracy: 0.9712 - val_loss: 0.0705 - val_accuracy: 0.9750
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9792
# Epoch 37: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0551 - accuracy: 0.9792 - val_loss: 0.0387 - val_accuracy: 0.9900
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9929
# Epoch 38: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0281 - accuracy: 0.9929 - val_loss: 0.0247 - val_accuracy: 0.9917
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9921
# Epoch 39: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0247 - accuracy: 0.9921 - val_loss: 0.0304 - val_accuracy: 0.9883
# Epoch 40/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9896
# Epoch 40: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0281 - accuracy: 0.9896 - val_loss: 0.0358 - val_accuracy: 0.9850
# Epoch 41/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9921
# Epoch 41: val_accuracy improved from 0.99167 to 0.99333, saving model to best_model.h5
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0270 - accuracy: 0.9921 - val_loss: 0.0180 - val_accuracy: 0.9933
# Epoch 42/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9904
# Epoch 42: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0310 - accuracy: 0.9904 - val_loss: 0.0293 - val_accuracy: 0.9867
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9908
# Epoch 43: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0313 - accuracy: 0.9908 - val_loss: 0.0324 - val_accuracy: 0.9900
# Epoch 44/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9933
# Epoch 44: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0168 - accuracy: 0.9933 - val_loss: 0.0302 - val_accuracy: 0.9883
# Epoch 45/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9871
# Epoch 45: val_accuracy improved from 0.99333 to 0.99667, saving model to best_model.h5
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0346 - accuracy: 0.9871 - val_loss: 0.0162 - val_accuracy: 0.9967
# Epoch 46/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9883
# Epoch 46: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0395 - accuracy: 0.9883 - val_loss: 0.0212 - val_accuracy: 0.9933
# Epoch 47/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9950
# Epoch 47: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 0.0320 - val_accuracy: 0.9867
# Epoch 48/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9950
# Epoch 48: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.0383 - val_accuracy: 0.9867
# Epoch 49/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9854
# Epoch 49: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0384 - accuracy: 0.9854 - val_loss: 0.1602 - val_accuracy: 0.9483
# Epoch 50/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9688
# Epoch 50: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0802 - accuracy: 0.9688 - val_loss: 0.0471 - val_accuracy: 0.9833
# Epoch 51/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9908
# Epoch 51: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0324 - accuracy: 0.9908 - val_loss: 0.0226 - val_accuracy: 0.9950
# Epoch 52/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9921
# Epoch 52: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.0234 - val_accuracy: 0.9933
# Epoch 53/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9879
# Epoch 53: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0343 - accuracy: 0.9879 - val_loss: 0.0292 - val_accuracy: 0.9883
# Epoch 54/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9929
# Epoch 54: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0218 - accuracy: 0.9929 - val_loss: 0.0297 - val_accuracy: 0.9867
# Epoch 55/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9971
# Epoch 55: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.0202 - val_accuracy: 0.9917
# Epoch 56/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9971
# Epoch 56: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0138 - accuracy: 0.9971 - val_loss: 0.0181 - val_accuracy: 0.9967
# Epoch 57/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9904
# Epoch 57: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0219 - accuracy: 0.9904 - val_loss: 0.0385 - val_accuracy: 0.9900
# Epoch 58/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9875
# Epoch 58: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0380 - accuracy: 0.9875 - val_loss: 0.0442 - val_accuracy: 0.9833
# Epoch 59/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9950
# Epoch 59: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0179 - accuracy: 0.9950 - val_loss: 0.0146 - val_accuracy: 0.9950
# Epoch 60/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9975
# Epoch 60: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0114 - accuracy: 0.9975 - val_loss: 0.0173 - val_accuracy: 0.9933
# Epoch 61/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9917
# Epoch 61: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0240 - accuracy: 0.9917 - val_loss: 0.0193 - val_accuracy: 0.9950
# Epoch 62/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9929
# Epoch 62: val_accuracy did not improve from 0.99667
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0215 - accuracy: 0.9929 - val_loss: 0.0320 - val_accuracy: 0.9817
# Epoch 63/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9975
# Epoch 63: val_accuracy improved from 0.99667 to 0.99833, saving model to best_model.h5
# 38/38 [==============================] - 5s 121ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.0073 - val_accuracy: 0.9983
# Epoch 64/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9971
# Epoch 64: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0119 - accuracy: 0.9971 - val_loss: 0.0134 - val_accuracy: 0.9967
# Epoch 65/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9958
# Epoch 65: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0170 - accuracy: 0.9958 - val_loss: 0.0236 - val_accuracy: 0.9900
# Epoch 66/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9717
# Epoch 66: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0804 - accuracy: 0.9717 - val_loss: 0.3516 - val_accuracy: 0.8867
# Epoch 67/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9825
# Epoch 67: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0573 - accuracy: 0.9825 - val_loss: 0.0436 - val_accuracy: 0.9817
# Epoch 68/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9925
# Epoch 68: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0212 - accuracy: 0.9925 - val_loss: 0.0199 - val_accuracy: 0.9917
# Epoch 69/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9933
# Epoch 69: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0228 - accuracy: 0.9933 - val_loss: 0.0171 - val_accuracy: 0.9950
# Epoch 70/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9867
# Epoch 70: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0373 - accuracy: 0.9867 - val_loss: 0.0185 - val_accuracy: 0.9967
# Epoch 71/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9954
# Epoch 71: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0153 - accuracy: 0.9954 - val_loss: 0.0115 - val_accuracy: 0.9967
# Epoch 72/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9971
# Epoch 72: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0245 - val_accuracy: 0.9933
# Epoch 73/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9908
# Epoch 73: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0210 - accuracy: 0.9908 - val_loss: 0.0502 - val_accuracy: 0.9833
# Epoch 74/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9858
# Epoch 74: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0487 - accuracy: 0.9858 - val_loss: 0.0229 - val_accuracy: 0.9967
# Epoch 75/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9979
# Epoch 75: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0106 - accuracy: 0.9979 - val_loss: 0.0166 - val_accuracy: 0.9950
# Epoch 76/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9971
# Epoch 76: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0109 - val_accuracy: 0.9967
# Epoch 77/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9979
# Epoch 77: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0168 - val_accuracy: 0.9933
# Epoch 78/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9975
# Epoch 78: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.0118 - val_accuracy: 0.9967
# Epoch 79/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9967
# Epoch 79: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0067 - accuracy: 0.9967 - val_loss: 0.0063 - val_accuracy: 0.9983
# Epoch 80/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9933
# Epoch 80: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.0419 - val_accuracy: 0.9850
# Epoch 81/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9925
# Epoch 81: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0211 - accuracy: 0.9925 - val_loss: 0.0559 - val_accuracy: 0.9783
# Epoch 82/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9979
# Epoch 82: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0219 - val_accuracy: 0.9900
# Epoch 83/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9996
# Epoch 83: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0041 - accuracy: 0.9996 - val_loss: 0.0241 - val_accuracy: 0.9883
# Epoch 84/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9987
# Epoch 84: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.0462 - val_accuracy: 0.9867
# Epoch 85/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9971
# Epoch 85: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0097 - accuracy: 0.9971 - val_loss: 0.0268 - val_accuracy: 0.9917
# Epoch 86/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9925
# Epoch 86: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.0102 - val_accuracy: 0.9967
# Epoch 87/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9946
# Epoch 87: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0141 - accuracy: 0.9946 - val_loss: 0.0161 - val_accuracy: 0.9950
# Epoch 88/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9942
# Epoch 88: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0118 - accuracy: 0.9942 - val_loss: 0.0139 - val_accuracy: 0.9950
# Epoch 89/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9937
# Epoch 89: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0173 - accuracy: 0.9937 - val_loss: 0.0301 - val_accuracy: 0.9883
# Epoch 90/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9962
# Epoch 90: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0079 - accuracy: 0.9962 - val_loss: 0.0059 - val_accuracy: 0.9983
# Epoch 91/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9996
# Epoch 91: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0046 - accuracy: 0.9996 - val_loss: 0.0075 - val_accuracy: 0.9967
# Epoch 92/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9983
# Epoch 92: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 93/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9854
# Epoch 93: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0517 - accuracy: 0.9854 - val_loss: 0.0882 - val_accuracy: 0.9667
# Epoch 94/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9783
# Epoch 94: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0707 - accuracy: 0.9783 - val_loss: 0.0197 - val_accuracy: 0.9933
# Epoch 95/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9929
# Epoch 95: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0201 - accuracy: 0.9929 - val_loss: 0.0131 - val_accuracy: 0.9950
# Epoch 96/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9983
# Epoch 96: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.0191 - val_accuracy: 0.9933
# Epoch 97/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9975
# Epoch 97: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0186 - val_accuracy: 0.9917
# Epoch 98/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9992
# Epoch 98: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.0212 - val_accuracy: 0.9917
# Epoch 99/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9983
# Epoch 99: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0059 - val_accuracy: 0.9983
# Epoch 100/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992
# Epoch 100: val_accuracy did not improve from 0.99833
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0057 - val_accuracy: 0.9983

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 19/19 [==============================] - 1s 17ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("ShuffleNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# ShuffleNet MODEL SONUÇLARI
# Doğruluk:  0.9983333333333333
# F1_Skor:  0.9983862952027364
# Hassasiyet:  0.9983164983164983
# Duyarlılık:  0.9984639016897082

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# Confusion Matrix
# [[216   1   0]
#  [  0 197   0]
#  [  0   0 186]]
# <Axes: >
