# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']


train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Patato/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 2152 images belonging to 3 classes.
# (2152, 224, 224, 3)
# (2152, 3)

# %%
#Converting  our color images to a vector
x=x.reshape(2152,224*224*3)

# %%
x.shape
# Out:
# (2152, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (3000, 150528)

# %%
y_smote.shape
# Out:
# (3000, 3)

# %%
X_smote=X_smote.reshape(3000,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (2152, 150528)
# Shape of X after SMOTE: (3000, 224, 224, 3)

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (3000, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
def build_vgg():
    vgg = VGG16(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = vgg(x)
    x = Flatten(name="flatten")(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    # multi output
    output = Dense(3,activation = 'softmax', name='root')(x)
    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_vgg = build_vgg()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 3)       84
#
#  vgg16 (Functional)          (None, None, None, 512)   14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 3)                 771
#
# =================================================================
# Total params: 21139351 (80.64 MB)
# Trainable params: 21138839 (80.64 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist_vgg16=model_vgg.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8028 - accuracy: 0.6875
# Epoch 1: val_accuracy improved from -inf to 0.49167, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - 79s 1s/step - loss: 0.8028 - accuracy: 0.6875 - val_loss: 3.6851 - val_accuracy: 0.4917
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.8875
# Epoch 2: val_accuracy improved from 0.49167 to 0.74167, saving model to best_model.h5
# 38/38 [==============================] - 36s 959ms/step - loss: 0.3011 - accuracy: 0.8875 - val_loss: 0.9983 - val_accuracy: 0.7417
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9408
# Epoch 3: val_accuracy did not improve from 0.74167
# 38/38 [==============================] - 35s 920ms/step - loss: 0.1462 - accuracy: 0.9408 - val_loss: 3.9411 - val_accuracy: 0.5833
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9608
# Epoch 4: val_accuracy did not improve from 0.74167
# 38/38 [==============================] - 35s 927ms/step - loss: 0.0978 - accuracy: 0.9608 - val_loss: 1.5576 - val_accuracy: 0.7400
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9812
# Epoch 5: val_accuracy improved from 0.74167 to 0.98833, saving model to best_model.h5
# 38/38 [==============================] - 36s 946ms/step - loss: 0.0464 - accuracy: 0.9812 - val_loss: 0.0329 - val_accuracy: 0.9883
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9929
# Epoch 6: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 35s 928ms/step - loss: 0.0208 - accuracy: 0.9929 - val_loss: 0.0679 - val_accuracy: 0.9650
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9925
# Epoch 7: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 35s 930ms/step - loss: 0.0213 - accuracy: 0.9925 - val_loss: 0.0817 - val_accuracy: 0.9750
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9917
# Epoch 8: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 35s 933ms/step - loss: 0.0274 - accuracy: 0.9917 - val_loss: 1.1327 - val_accuracy: 0.7800
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9887
# Epoch 9: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 35s 933ms/step - loss: 0.0343 - accuracy: 0.9887 - val_loss: 0.0439 - val_accuracy: 0.9817
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9967
# Epoch 10: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 35s 932ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.0752 - val_accuracy: 0.9800
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9983
# Epoch 11: val_accuracy did not improve from 0.98833
# 38/38 [==============================] - 35s 931ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.0367 - val_accuracy: 0.9833
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9987
# Epoch 12: val_accuracy improved from 0.98833 to 0.99833, saving model to best_model.h5
# 38/38 [==============================] - 36s 948ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.0169 - val_accuracy: 0.9983
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9992
# Epoch 13: val_accuracy improved from 0.99833 to 1.00000, saving model to best_model.h5
# 38/38 [==============================] - 36s 947ms/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9979
# Epoch 14: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 929ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9967
# Epoch 15: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 932ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.0120 - val_accuracy: 0.9933
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9908
# Epoch 16: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 930ms/step - loss: 0.0258 - accuracy: 0.9908 - val_loss: 0.6411 - val_accuracy: 0.8267
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9975
# Epoch 17: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 930ms/step - loss: 0.0113 - accuracy: 0.9975 - val_loss: 0.0066 - val_accuracy: 0.9983
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9971
# Epoch 18: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 930ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0100 - val_accuracy: 0.9967
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9992
# Epoch 19: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 931ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0150 - val_accuracy: 0.9950
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 931ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9983
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 6.8207e-04 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 931ms/step - loss: 6.8207e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9983
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 8.5541e-04 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 931ms/step - loss: 8.5541e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9983
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 3.4624e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 932ms/step - loss: 3.4624e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 3.1021e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 930ms/step - loss: 3.1021e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 2.1813e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 931ms/step - loss: 2.1813e-04 - accuracy: 1.0000 - val_loss: 8.6281e-04 - val_accuracy: 1.0000
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 2.2535e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 931ms/step - loss: 2.2535e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 2.0700e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 930ms/step - loss: 2.0700e-04 - accuracy: 1.0000 - val_loss: 7.3498e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6952e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 929ms/step - loss: 1.6952e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9983
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 2.5999e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 929ms/step - loss: 2.5999e-04 - accuracy: 1.0000 - val_loss: 6.3834e-04 - val_accuracy: 1.0000
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 2.3579e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 930ms/step - loss: 2.3579e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 1.6721e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 931ms/step - loss: 1.6721e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1540e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 929ms/step - loss: 1.1540e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1527e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 930ms/step - loss: 1.1527e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3848e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 931ms/step - loss: 1.3848e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0352e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 1.00000
# 38/38 [==============================] - 35s 932ms/step - loss: 1.0352e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 36/100
# 19/38 [==============>...............] - ETA: 16s - loss: 6.2465e-05 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-3339aa084965> in <cell line: 1>()
# ----> 1 hist_vgg16=model_vgg.fit(X_train, Y_train,
#       2                batch_size=BATCH_SIZE,
#       3                epochs=EPOCHS,
#       4                verbose=1,
#       5                validation_data=(X_val, Y_val),
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1787                             logs = tmp_logs
#    1788                             end_step = step + data_handler.step_increment
# -> 1789                             callbacks.on_train_batch_end(end_step, logs)
#    1790                             if self.stop_training:
#    1791                                 break
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1167         if self.verbose == 1:
#    1168             # Only block async when verbose = 1.
# -> 1169             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1171
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     692         return t.item() if np.ndim(t) == 0 else t
#     693
# --> 694     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     695
#     696
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     627     ValueError: If wrong keyword arguments are provided.
#     628   """
# --> 629   return nest_util.map_structure(
#     630       nest_util.Modality.CORE, func, *structure, **kwargs
#     631   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in map_structure(modality, func, *structure, **kwargs)
#    1166   """
#    1167   if modality == Modality.CORE:
# -> 1168     return _tf_core_map_structure(func, *structure, **kwargs)
#    1169   elif modality == Modality.DATA:
#    1170     return _tf_data_map_structure(func, *structure, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_map_structure(func, *structure, **kwargs)
#    1206   return _tf_core_pack_sequence_as(
#    1207       structure[0],
# -> 1208       [func(*x) for x in entries],
#    1209       expand_composites=expand_composites,
#    1210   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in <listcomp>(.0)
#    1206   return _tf_core_pack_sequence_as(
#    1207       structure[0],
# -> 1208       [func(*x) for x in entries],
#    1209       expand_composites=expand_composites,
#    1210   )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     685         # Don't turn ragged or sparse tensors to NumPy.
#     686         if isinstance(t, tf.Tensor):
# --> 687             t = t.numpy()
#     688         # Strings, ragged and sparse tensors don't have .item(). Return them
#     689         # as-is.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#     394     """
#     395     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 396     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     397     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     398
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     360   def _numpy(self):
#     361     try:
# --> 362       return self._numpy_internal()
#     363     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#     364       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 19/19 [==============================] - 3s 136ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# Doğruluk:  1.0
# F1_Skor:  1.0
# Hassasiyet:  1.0
# Duyarlılık:  1.0

# %%
plt.plot(hist_vgg16.history['accuracy'])
plt.plot(hist_vgg16.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

#  loss plot
plt.plot(hist_vgg16.history['loss'])
plt.plot(hist_vgg16.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-3d10487e448c> in <cell line: 1>()
# ----> 1 plt.plot(hist_vgg16.history['accuracy'])
#       2 plt.plot(hist_vgg16.history['val_accuracy'])
#       3 plt.title('model accuracy')
#       4 plt.ylabel('accuracy')
#       5 plt.xlabel('epoch')
#
# NameError: name 'hist_vgg16' is not defined

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[217   0   0]
#  [  0 197   0]
#  [  0   0 186]]
# <Axes: >
