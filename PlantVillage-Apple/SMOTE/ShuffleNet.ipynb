# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import keras
import numpy as np # linear algebra
import keras.backend as K
import time as ti
import cv2
import os
import glob # for including images
import scipy.io as sio
from sklearn.metrics import classification_report, confusion_matrix
from keras import layers
from keras import models
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.layers import *

from tensorflow.python.keras.optimizers import *
from keras.callbacks import *
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.activations import *
import keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf

# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image

from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Apple___Apple_scab',
               'Apple___Black_rot',
               'Apple___Cedar_apple_rust',
               'Apple___healthy',
               ]

train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Apple/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 3171 images belonging to 4 classes.
# (3171, 224, 224, 3)
# (3171, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(3171,224*224*3)

# %%
x.shape
# Out:
# (3171, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (6580, 150528)

# %%
y_smote.shape
# Out:
# (6580, 4)

# %%
X_smote=X_smote.reshape(6580,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (3171, 150528)
# Shape of X after SMOTE: (6580, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (6580, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
pip install keras_applications
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %%
pip install Keras
# Out:
# Requirement already satisfied: Keras in /usr/local/lib/python3.10/dist-packages (2.14.0)

# %%
from keras.utils import plot_model
from keras_applications.imagenet_utils import _obtain_input_shape
#from tensorflow.keras.engine.topology import get_source_inputs
from keras.layers import Input, Conv2D, MaxPool2D, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.layers import Activation, Dense
from keras.models import Model
import keras.backend as K



import os
from keras import backend as K
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.layers import Activation, Add, Concatenate, Conv2D, GlobalMaxPooling2D
from keras.layers import GlobalAveragePooling2D,Input, Dense
from keras.layers import MaxPool2D,AveragePooling2D, BatchNormalization, Lambda, DepthwiseConv2D
import numpy as np


def channel_split(x, name=''):
    # equipartition
    in_channles = x.shape.as_list()[-1]
    ip = in_channles // 2
    c_hat = Lambda(lambda z: z[:, :, :, 0:ip], name='%s/sp%d_slice' % (name, 0))(x)
    c = Lambda(lambda z: z[:, :, :, ip:], name='%s/sp%d_slice' % (name, 1))(x)
    return c_hat, c

def channel_shuffle(x):
    height, width, channels = x.shape.as_list()[1:]
    channels_per_split = channels // 2
    x = K.reshape(x, [-1, height, width, 2, channels_per_split])
    x = K.permute_dimensions(x, (0,1,2,4,3))
    x = K.reshape(x, [-1, height, width, channels])
    return x


def shuffle_unit(inputs, out_channels, bottleneck_ratio,strides=2,stage=1,block=1):
    if K.image_data_format() == 'channels_last':
        bn_axis = -1
    else:
        raise ValueError('Only channels last supported')

    prefix = 'stage{}/block{}'.format(stage, block)
    bottleneck_channels = int(out_channels * bottleneck_ratio)
    if strides < 2:
        c_hat, c = channel_split(inputs, '{}/spl'.format(prefix))
        inputs = c

    x = Conv2D(bottleneck_channels, kernel_size=(1,1), strides=1, padding='same', name='{}/1x1conv_1'.format(prefix))(inputs)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_1'.format(prefix))(x)
    x = Activation('relu', name='{}/relu_1x1conv_1'.format(prefix))(x)
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same', name='{}/3x3dwconv'.format(prefix))(x)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_3x3dwconv'.format(prefix))(x)
    x = Conv2D(bottleneck_channels, kernel_size=1,strides=1,padding='same', name='{}/1x1conv_2'.format(prefix))(x)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_2'.format(prefix))(x)
    x = Activation('relu', name='{}/relu_1x1conv_2'.format(prefix))(x)

    if strides < 2:
        ret = Concatenate(axis=bn_axis, name='{}/concat_1'.format(prefix))([x, c_hat])
    else:
        s2 = DepthwiseConv2D(kernel_size=3, strides=2, padding='same', name='{}/3x3dwconv_2'.format(prefix))(inputs)
        s2 = BatchNormalization(axis=bn_axis, name='{}/bn_3x3dwconv_2'.format(prefix))(s2)
        s2 = Conv2D(bottleneck_channels, kernel_size=1,strides=1,padding='same', name='{}/1x1_conv_3'.format(prefix))(s2)
        s2 = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_3'.format(prefix))(s2)
        s2 = Activation('relu', name='{}/relu_1x1conv_3'.format(prefix))(s2)
        ret = Concatenate(axis=bn_axis, name='{}/concat_2'.format(prefix))([x, s2])

    ret = Lambda(channel_shuffle, name='{}/channel_shuffle'.format(prefix))(ret)

    return ret


def block(x, channel_map, bottleneck_ratio, repeat=1, stage=1):
    x = shuffle_unit(x, out_channels=channel_map[stage-1],
                      strides=2,bottleneck_ratio=bottleneck_ratio,stage=stage,block=1)

    for i in range(1, repeat+1):
        x = shuffle_unit(x, out_channels=channel_map[stage-1],strides=1,
                          bottleneck_ratio=bottleneck_ratio,stage=stage, block=(1+i))

    return x


def ShuffleNetV2(include_top=True,
                 input_tensor=None,
                 scale_factor=1.0,
                 pooling='max',
                 input_shape=(32,32,3),
                 load_model=None,
                 num_shuffle_units=[3,7,3],
                 bottleneck_ratio=1,
                 classes=131):
    if K.backend() != 'tensorflow':
        raise RuntimeError('Only tensorflow supported for now')
    name = 'ShuffleNetV2_{}_{}_{}'.format(scale_factor, bottleneck_ratio, "".join([str(x) for x in num_shuffle_units]))
    input_shape = _obtain_input_shape(input_shape, default_size=224, min_size=28, require_flatten=include_top,
                                      data_format=K.image_data_format())
    out_dim_stage_two = {0.5:48, 1:116, 1.5:176, 2:244}

    if pooling not in ['max', 'avg']:
        raise ValueError('Invalid value for pooling')
    if not (float(scale_factor)*4).is_integer():
        raise ValueError('Invalid value for scale_factor, should be x over 4')
    exp = np.insert(np.arange(len(num_shuffle_units), dtype=np.float32), 0, 0)  # [0., 0., 1., 2.]
    out_channels_in_stage = 2**exp
    out_channels_in_stage *= out_dim_stage_two[bottleneck_ratio]  #  calculate output channels for each stage
    out_channels_in_stage[0] = 24  # first stage has always 24 output channels
    out_channels_in_stage *= scale_factor
    out_channels_in_stage = out_channels_in_stage.astype(int)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    # create shufflenet architecture
    x = Conv2D(filters=out_channels_in_stage[0], kernel_size=(3, 3), padding='same', use_bias=False, strides=(2, 2),
               activation='relu', name='conv1')(img_input)
    x = MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same', name='maxpool1')(x)

    # create stages containing shufflenet units beginning at stage 2
    for stage in range(len(num_shuffle_units)):
        repeat = num_shuffle_units[stage]
        x = block(x, out_channels_in_stage,
                   repeat=repeat,
                   bottleneck_ratio=bottleneck_ratio,
                   stage=stage + 2)

    if bottleneck_ratio < 2:
        k = 1024
    else:
        k = 2048
    x = Conv2D(k, kernel_size=1, padding='same', strides=1, name='1x1conv5_out', activation='relu')(x)

    if pooling == 'avg':
        x = GlobalAveragePooling2D(name='global_avg_pool')(x)
    elif pooling == 'max':
        x = GlobalMaxPooling2D(name='global_max_pool')(x)

    if include_top:
        x = Dense(classes, name='fc')(x)
        x = Activation('softmax', name='softmax')(x)

    if input_tensor:
        inputs = get_source_inputs(input_tensor)

    else:
        inputs = img_input

    model = Model(inputs, x, name=name)

    if load_model:
        model.load_weights('imagenet', by_name=True)

    return model

# %%
model = ShuffleNetV2(include_top=True, input_shape=(224, 224, 3), classes=4)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "ShuffleNetV2_1.0_1_373"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1 (Conv2D)              (None, 112, 112, 24)         648       ['input_1[0][0]']
#
#  maxpool1 (MaxPooling2D)     (None, 56, 56, 24)           0         ['conv1[0][0]']
#
#  stage2/block1/1x1conv_1 (C  (None, 56, 56, 116)          2900      ['maxpool1[0][0]']
#  onv2D)
#
#  stage2/block1/bn_1x1conv_1  (None, 56, 56, 116)          464       ['stage2/block1/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block1/relu_1x1conv  (None, 56, 56, 116)          0         ['stage2/block1/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block1/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block1/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block1/3x3dwconv_2   (None, 28, 28, 24)           240       ['maxpool1[0][0]']
#  (DepthwiseConv2D)
#
#  stage2/block1/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block1/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block1/bn_3x3dwconv  (None, 28, 28, 24)           96        ['stage2/block1/3x3dwconv_2[0]
#  _2 (BatchNormalization)                                            [0]']
#
#  stage2/block1/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block1/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block1/1x1_conv_3 (  (None, 28, 28, 116)          2900      ['stage2/block1/bn_3x3dwconv_2
#  Conv2D)                                                            [0][0]']
#
#  stage2/block1/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block1/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block1/bn_1x1conv_3  (None, 28, 28, 116)          464       ['stage2/block1/1x1_conv_3[0][
#   (BatchNormalization)                                              0]']
#
#  stage2/block1/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block1/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block1/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block1/bn_1x1conv_3[0
#  _3 (Activation)                                                    ][0]']
#
#  stage2/block1/concat_2 (Co  (None, 28, 28, 232)          0         ['stage2/block1/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block1/relu_1x1conv_3
#                                                                     [0][0]']
#
#  stage2/block1/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block1/concat_2[0][0]
#  fle (Lambda)                                                       ']
#
#  stage2/block2/spl/sp1_slic  (None, 28, 28, 116)          0         ['stage2/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block2/1x1conv_1 (C  (None, 28, 28, 116)          13572     ['stage2/block2/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage2/block2/bn_1x1conv_1  (None, 28, 28, 116)          464       ['stage2/block2/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block2/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block2/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block2/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block2/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block2/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block2/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block2/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block2/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block2/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block2/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block2/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block2/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block2/spl/sp0_slic  (None, 28, 28, 116)          0         ['stage2/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block2/concat_1 (Co  (None, 28, 28, 232)          0         ['stage2/block2/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block2/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage2/block2/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block2/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage2/block3/spl/sp1_slic  (None, 28, 28, 116)          0         ['stage2/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block3/1x1conv_1 (C  (None, 28, 28, 116)          13572     ['stage2/block3/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage2/block3/bn_1x1conv_1  (None, 28, 28, 116)          464       ['stage2/block3/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block3/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block3/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block3/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block3/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block3/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block3/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block3/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block3/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block3/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block3/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block3/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block3/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block3/spl/sp0_slic  (None, 28, 28, 116)          0         ['stage2/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block3/concat_1 (Co  (None, 28, 28, 232)          0         ['stage2/block3/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block3/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage2/block3/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block3/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage2/block4/spl/sp1_slic  (None, 28, 28, 116)          0         ['stage2/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block4/1x1conv_1 (C  (None, 28, 28, 116)          13572     ['stage2/block4/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage2/block4/bn_1x1conv_1  (None, 28, 28, 116)          464       ['stage2/block4/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block4/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block4/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block4/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block4/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block4/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block4/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block4/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block4/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block4/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block4/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block4/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block4/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block4/spl/sp0_slic  (None, 28, 28, 116)          0         ['stage2/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block4/concat_1 (Co  (None, 28, 28, 232)          0         ['stage2/block4/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block4/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage2/block4/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block4/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block1/1x1conv_1 (C  (None, 28, 28, 232)          54056     ['stage2/block4/channel_shuffl
#  onv2D)                                                             e[0][0]']
#
#  stage3/block1/bn_1x1conv_1  (None, 28, 28, 232)          928       ['stage3/block1/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block1/relu_1x1conv  (None, 28, 28, 232)          0         ['stage3/block1/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block1/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block1/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block1/3x3dwconv_2   (None, 14, 14, 232)          2320      ['stage2/block4/channel_shuffl
#  (DepthwiseConv2D)                                                  e[0][0]']
#
#  stage3/block1/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block1/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block1/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block1/3x3dwconv_2[0]
#  _2 (BatchNormalization)                                            [0]']
#
#  stage3/block1/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block1/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block1/1x1_conv_3 (  (None, 14, 14, 232)          54056     ['stage3/block1/bn_3x3dwconv_2
#  Conv2D)                                                            [0][0]']
#
#  stage3/block1/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block1/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block1/bn_1x1conv_3  (None, 14, 14, 232)          928       ['stage3/block1/1x1_conv_3[0][
#   (BatchNormalization)                                              0]']
#
#  stage3/block1/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block1/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block1/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block1/bn_1x1conv_3[0
#  _3 (Activation)                                                    ][0]']
#
#  stage3/block1/concat_2 (Co  (None, 14, 14, 464)          0         ['stage3/block1/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block1/relu_1x1conv_3
#                                                                     [0][0]']
#
#  stage3/block1/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block1/concat_2[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block2/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block2/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block2/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block2/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block2/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block2/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block2/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block2/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block2/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block2/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block2/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block2/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block2/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block2/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block2/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block2/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block2/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block2/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block2/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block2/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block2/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block2/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block2/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block3/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block3/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block3/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block3/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block3/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block3/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block3/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block3/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block3/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block3/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block3/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block3/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block3/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block3/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block3/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block3/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block3/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block3/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block3/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block3/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block3/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block3/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block3/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block4/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block4/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block4/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block4/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block4/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block4/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block4/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block4/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block4/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block4/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block4/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block4/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block4/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block4/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block4/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block4/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block4/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block4/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block4/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block4/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block4/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block4/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block4/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block5/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block4/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block5/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block5/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block5/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block5/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block5/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block5/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block5/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block5/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block5/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block5/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block5/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block5/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block5/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block5/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block5/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block5/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block5/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block4/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block5/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block5/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block5/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block5/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block5/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block6/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block5/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block6/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block6/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block6/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block6/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block6/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block6/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block6/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block6/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block6/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block6/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block6/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block6/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block6/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block6/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block6/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block6/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block6/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block5/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block6/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block6/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block6/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block6/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block6/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block7/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block6/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block7/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block7/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block7/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block7/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block7/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block7/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block7/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block7/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block7/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block7/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block7/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block7/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block7/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block7/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block7/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block7/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block7/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block6/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block7/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block7/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block7/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block7/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block7/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block8/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block7/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block8/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block8/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block8/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block8/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block8/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block8/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block8/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block8/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block8/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block8/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block8/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block8/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block8/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block8/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block8/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block8/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block8/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block7/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block8/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block8/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block8/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block8/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block8/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block1/1x1conv_1 (C  (None, 14, 14, 464)          215760    ['stage3/block8/channel_shuffl
# ...
#  (DepthwiseConv2D)                                                  e[0][0]']
#
#  stage4/block1/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block1/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block1/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block1/3x3dwconv_2[0]
#  _2 (BatchNormalization)                                            [0]']
#
#  stage4/block1/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block1/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block1/1x1_conv_3 (  (None, 7, 7, 464)            215760    ['stage4/block1/bn_3x3dwconv_2
#  Conv2D)                                                            [0][0]']
#
#  stage4/block1/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block1/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block1/bn_1x1conv_3  (None, 7, 7, 464)            1856      ['stage4/block1/1x1_conv_3[0][
#   (BatchNormalization)                                              0]']
#
#  stage4/block1/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block1/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block1/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block1/bn_1x1conv_3[0
#  _3 (Activation)                                                    ][0]']
#
#  stage4/block1/concat_2 (Co  (None, 7, 7, 928)            0         ['stage4/block1/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block1/relu_1x1conv_3
#                                                                     [0][0]']
#
#  stage4/block1/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block1/concat_2[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block2/spl/sp1_slic  (None, 7, 7, 464)            0         ['stage4/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block2/1x1conv_1 (C  (None, 7, 7, 464)            215760    ['stage4/block2/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage4/block2/bn_1x1conv_1  (None, 7, 7, 464)            1856      ['stage4/block2/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block2/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block2/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage4/block2/3x3dwconv (D  (None, 7, 7, 464)            4640      ['stage4/block2/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage4/block2/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block2/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block2/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block2/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block2/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block2/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block2/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block2/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block2/spl/sp0_slic  (None, 7, 7, 464)            0         ['stage4/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block2/concat_1 (Co  (None, 7, 7, 928)            0         ['stage4/block2/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block2/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage4/block2/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block2/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block3/spl/sp1_slic  (None, 7, 7, 464)            0         ['stage4/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block3/1x1conv_1 (C  (None, 7, 7, 464)            215760    ['stage4/block3/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage4/block3/bn_1x1conv_1  (None, 7, 7, 464)            1856      ['stage4/block3/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block3/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block3/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage4/block3/3x3dwconv (D  (None, 7, 7, 464)            4640      ['stage4/block3/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage4/block3/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block3/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block3/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block3/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block3/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block3/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block3/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block3/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block3/spl/sp0_slic  (None, 7, 7, 464)            0         ['stage4/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block3/concat_1 (Co  (None, 7, 7, 928)            0         ['stage4/block3/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block3/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage4/block3/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block3/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block4/spl/sp1_slic  (None, 7, 7, 464)            0         ['stage4/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block4/1x1conv_1 (C  (None, 7, 7, 464)            215760    ['stage4/block4/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage4/block4/bn_1x1conv_1  (None, 7, 7, 464)            1856      ['stage4/block4/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block4/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block4/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage4/block4/3x3dwconv (D  (None, 7, 7, 464)            4640      ['stage4/block4/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage4/block4/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block4/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block4/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block4/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block4/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block4/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block4/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block4/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block4/spl/sp0_slic  (None, 7, 7, 464)            0         ['stage4/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block4/concat_1 (Co  (None, 7, 7, 928)            0         ['stage4/block4/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block4/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage4/block4/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block4/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  1x1conv5_out (Conv2D)       (None, 7, 7, 1024)           951296    ['stage4/block4/channel_shuffl
#                                                                     e[0][0]']
#
#  global_max_pool (GlobalMax  (None, 1024)                 0         ['1x1conv5_out[0][0]']
#  Pooling2D)
#
#  fc (Dense)                  (None, 4)                    4100      ['global_max_pool[0][0]']
#
#  softmax (Activation)        (None, 4)                    0         ['fc[0][0]']
#
# ==================================================================================================
# Total params: 4022840 (15.35 MB)
# Trainable params: 3994720 (15.24 MB)
# Non-trainable params: 28120 (109.84 KB)
# __________________________________________________________________________________________________
# None

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist=model.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 83/83 [==============================] - ETA: 0s - loss: 1.1457 - accuracy: 0.6809
# Epoch 1: val_accuracy improved from -inf to 0.26216, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 83/83 [==============================] - 49s 112ms/step - loss: 1.1457 - accuracy: 0.6809 - val_loss: 1.3964 - val_accuracy: 0.2622
# Epoch 2/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.1949 - accuracy: 0.9345
# Epoch 2: val_accuracy did not improve from 0.26216
# 83/83 [==============================] - 6s 69ms/step - loss: 0.1950 - accuracy: 0.9345 - val_loss: 1.4762 - val_accuracy: 0.2622
# Epoch 3/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.1156 - accuracy: 0.9590
# Epoch 3: val_accuracy did not improve from 0.26216
# 83/83 [==============================] - 6s 67ms/step - loss: 0.1162 - accuracy: 0.9588 - val_loss: 1.7078 - val_accuracy: 0.2622
# Epoch 4/100
# 83/83 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9576
# Epoch 4: val_accuracy did not improve from 0.26216
# 83/83 [==============================] - 6s 67ms/step - loss: 0.1403 - accuracy: 0.9576 - val_loss: 1.9663 - val_accuracy: 0.2622
# Epoch 5/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9814
# Epoch 5: val_accuracy improved from 0.26216 to 0.31839, saving model to best_model.h5
# 83/83 [==============================] - 6s 75ms/step - loss: 0.0571 - accuracy: 0.9814 - val_loss: 2.4993 - val_accuracy: 0.3184
# Epoch 6/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9676
# Epoch 6: val_accuracy did not improve from 0.31839
# 83/83 [==============================] - 6s 67ms/step - loss: 0.1034 - accuracy: 0.9677 - val_loss: 4.1334 - val_accuracy: 0.2622
# Epoch 7/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9872
# Epoch 7: val_accuracy did not improve from 0.31839
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0325 - accuracy: 0.9873 - val_loss: 6.3416 - val_accuracy: 0.2622
# Epoch 8/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0789 - accuracy: 0.9798
# Epoch 8: val_accuracy did not improve from 0.31839
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0787 - accuracy: 0.9799 - val_loss: 9.8251 - val_accuracy: 0.3062
# Epoch 9/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0604 - accuracy: 0.9809
# Epoch 9: val_accuracy improved from 0.31839 to 0.81231, saving model to best_model.h5
# 83/83 [==============================] - 6s 75ms/step - loss: 0.0616 - accuracy: 0.9808 - val_loss: 1.0101 - val_accuracy: 0.8123
# Epoch 10/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0573 - accuracy: 0.9829
# Epoch 10: val_accuracy improved from 0.81231 to 0.96657, saving model to best_model.h5
# 83/83 [==============================] - 6s 76ms/step - loss: 0.0572 - accuracy: 0.9829 - val_loss: 0.1142 - val_accuracy: 0.9666
# Epoch 11/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.9909
# Epoch 11: val_accuracy improved from 0.96657 to 0.97264, saving model to best_model.h5
# 83/83 [==============================] - 6s 76ms/step - loss: 0.0263 - accuracy: 0.9909 - val_loss: 0.0886 - val_accuracy: 0.9726
# Epoch 12/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0140 - accuracy: 0.9950
# Epoch 12: val_accuracy did not improve from 0.97264
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.3736 - val_accuracy: 0.9210
# Epoch 13/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 0.9910
# Epoch 13: val_accuracy did not improve from 0.97264
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0256 - accuracy: 0.9909 - val_loss: 0.7140 - val_accuracy: 0.8769
# Epoch 14/100
# 83/83 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9588
# Epoch 14: val_accuracy did not improve from 0.97264
# 83/83 [==============================] - 6s 68ms/step - loss: 0.1881 - accuracy: 0.9588 - val_loss: 1.0989 - val_accuracy: 0.8176
# Epoch 15/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0444 - accuracy: 0.9859
# Epoch 15: val_accuracy improved from 0.97264 to 0.97872, saving model to best_model.h5
# 83/83 [==============================] - 6s 75ms/step - loss: 0.0445 - accuracy: 0.9858 - val_loss: 0.1019 - val_accuracy: 0.9787
# Epoch 16/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9962
# Epoch 16: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 69ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.1383 - val_accuracy: 0.9696
# Epoch 17/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9992
# Epoch 17: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.1376 - val_accuracy: 0.9719
# Epoch 18/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9975
# Epoch 18: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 0.0768 - val_accuracy: 0.9780
# Epoch 19/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9947
# Epoch 19: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0195 - accuracy: 0.9947 - val_loss: 0.2812 - val_accuracy: 0.9476
# Epoch 20/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9983
# Epoch 20: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.1283 - val_accuracy: 0.9711
# Epoch 21/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 21: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.1281 - val_accuracy: 0.9742
# Epoch 22/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9983
# Epoch 22: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.2023 - val_accuracy: 0.9582
# Epoch 23/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9939
# Epoch 23: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0226 - accuracy: 0.9939 - val_loss: 1.2430 - val_accuracy: 0.7736
# Epoch 24/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0893 - accuracy: 0.9726
# Epoch 24: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0895 - accuracy: 0.9723 - val_loss: 2.3586 - val_accuracy: 0.7097
# Epoch 25/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9907
# Epoch 25: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0266 - accuracy: 0.9907 - val_loss: 0.2091 - val_accuracy: 0.9635
# Epoch 26/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9899
# Epoch 26: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0308 - accuracy: 0.9899 - val_loss: 2.6482 - val_accuracy: 0.5889
# Epoch 27/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9953
# Epoch 27: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0172 - accuracy: 0.9953 - val_loss: 0.7260 - val_accuracy: 0.8260
# Epoch 28/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9792
# Epoch 28: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0743 - accuracy: 0.9793 - val_loss: 0.0957 - val_accuracy: 0.9696
# Epoch 29/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 0.9958
# Epoch 29: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0129 - accuracy: 0.9956 - val_loss: 0.2259 - val_accuracy: 0.9521
# Epoch 30/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9910
# Epoch 30: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0313 - accuracy: 0.9909 - val_loss: 0.2523 - val_accuracy: 0.9430
# Epoch 31/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0184 - accuracy: 0.9945
# Epoch 31: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0184 - accuracy: 0.9945 - val_loss: 0.1528 - val_accuracy: 0.9673
# Epoch 32/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9981
# Epoch 32: val_accuracy did not improve from 0.97872
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.5349 - val_accuracy: 0.9027
# Epoch 33/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9990
# Epoch 33: val_accuracy improved from 0.97872 to 0.98252, saving model to best_model.h5
# 83/83 [==============================] - 6s 77ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.0801 - val_accuracy: 0.9825
# Epoch 34/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9983
# Epoch 34: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.2331 - val_accuracy: 0.9628
# Epoch 35/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9960
# Epoch 35: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0152 - accuracy: 0.9960 - val_loss: 0.1614 - val_accuracy: 0.9658
# Epoch 36/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9971
# Epoch 36: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.1303 - val_accuracy: 0.9711
# Epoch 37/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9849
# Epoch 37: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0506 - accuracy: 0.9846 - val_loss: 1.3383 - val_accuracy: 0.8047
# Epoch 38/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0755 - accuracy: 0.9802
# Epoch 38: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0753 - accuracy: 0.9802 - val_loss: 0.5984 - val_accuracy: 0.8161
# Epoch 39/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9943
# Epoch 39: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0175 - accuracy: 0.9943 - val_loss: 0.1937 - val_accuracy: 0.9552
# Epoch 40/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 0.9977
# Epoch 40: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 69ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.1788 - val_accuracy: 0.9574
# Epoch 41/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 0.9973
# Epoch 41: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.1300 - val_accuracy: 0.9666
# Epoch 42/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9983
# Epoch 42: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.4777 - val_accuracy: 0.8868
# Epoch 43/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9975
# Epoch 43: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.2419 - val_accuracy: 0.9453
# Epoch 44/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9960
# Epoch 44: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.1940 - val_accuracy: 0.9468
# Epoch 45/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9966
# Epoch 45: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.4959 - val_accuracy: 0.9073
# Epoch 46/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9945
# Epoch 46: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.2337 - val_accuracy: 0.9650
# Epoch 47/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9964
# Epoch 47: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 0.3970 - val_accuracy: 0.8875
# Epoch 48/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9947
# Epoch 48: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 69ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 1.9523 - val_accuracy: 0.7287
# Epoch 49/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9941
# Epoch 49: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0162 - accuracy: 0.9941 - val_loss: 0.2350 - val_accuracy: 0.9468
# Epoch 50/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0174 - accuracy: 0.9943
# Epoch 50: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 69ms/step - loss: 0.0179 - accuracy: 0.9941 - val_loss: 0.1854 - val_accuracy: 0.9483
# Epoch 51/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0594 - accuracy: 0.9815
# Epoch 51: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0592 - accuracy: 0.9816 - val_loss: 2.1093 - val_accuracy: 0.6831
# Epoch 52/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 0.9977
# Epoch 52: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.1041 - val_accuracy: 0.9764
# Epoch 53/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9987
# Epoch 53: val_accuracy improved from 0.98252 to 0.98556, saving model to best_model.h5
# 83/83 [==============================] - 6s 76ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0849 - val_accuracy: 0.9856
# Epoch 54/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9973
# Epoch 54: val_accuracy did not improve from 0.98556
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.1816 - val_accuracy: 0.9544
# Epoch 55/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9966
# Epoch 55: val_accuracy did not improve from 0.98556
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0085 - accuracy: 0.9966 - val_loss: 0.1245 - val_accuracy: 0.9810
# Epoch 56/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 56: val_accuracy did not improve from 0.98556
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1354 - val_accuracy: 0.9742
# Epoch 57/100
# 82/83 [============================>.] - ETA: 0s - loss: 3.3269e-04 - accuracy: 1.0000
# Epoch 57: val_accuracy improved from 0.98556 to 0.98632, saving model to best_model.h5
# 83/83 [==============================] - 6s 77ms/step - loss: 3.3241e-04 - accuracy: 1.0000 - val_loss: 0.0931 - val_accuracy: 0.9863
# Epoch 58/100
# 82/83 [============================>.] - ETA: 0s - loss: 9.3571e-04 - accuracy: 0.9996
# Epoch 58: val_accuracy improved from 0.98632 to 0.98860, saving model to best_model.h5
# 83/83 [==============================] - 6s 75ms/step - loss: 9.3313e-04 - accuracy: 0.9996 - val_loss: 0.0736 - val_accuracy: 0.9886
# Epoch 59/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.1983e-04 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 6s 67ms/step - loss: 1.2044e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9856
# Epoch 60/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.1230e-04 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 6s 68ms/step - loss: 1.1199e-04 - accuracy: 1.0000 - val_loss: 0.0827 - val_accuracy: 0.9871
# Epoch 61/100
# 82/83 [============================>.] - ETA: 0s - loss: 5.0833e-05 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 6s 67ms/step - loss: 5.0691e-05 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9856
# Epoch 62/100
# 82/83 [============================>.] - ETA: 0s - loss: 2.5305e-05 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 6s 68ms/step - loss: 3.0437e-05 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9863
# Epoch 63/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.5113e-05 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 6s 67ms/step - loss: 1.5069e-05 - accuracy: 1.0000 - val_loss: 0.0809 - val_accuracy: 0.9886
# Epoch 64/100
# 82/83 [============================>.] - ETA: 0s - loss: 3.1375e-05 - accuracy: 1.0000
# Epoch 64: val_accuracy improved from 0.98860 to 0.98936, saving model to best_model.h5
# 83/83 [==============================] - 6s 76ms/step - loss: 3.1479e-05 - accuracy: 1.0000 - val_loss: 0.0806 - val_accuracy: 0.9894
# Epoch 65/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9990
# Epoch 65: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.2367 - val_accuracy: 0.9552
# Epoch 66/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9863
# Epoch 66: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0514 - accuracy: 0.9861 - val_loss: 11.6627 - val_accuracy: 0.3883
# Epoch 67/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.1223 - accuracy: 0.9625
# Epoch 67: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.1219 - accuracy: 0.9626 - val_loss: 1.7807 - val_accuracy: 0.7280
# Epoch 68/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9920
# Epoch 68: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0191 - accuracy: 0.9918 - val_loss: 4.6813 - val_accuracy: 0.5935
# Epoch 69/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0290 - accuracy: 0.9893
# Epoch 69: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0289 - accuracy: 0.9894 - val_loss: 0.2730 - val_accuracy: 0.9460
# Epoch 70/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9973
# Epoch 70: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0088 - accuracy: 0.9973 - val_loss: 0.9333 - val_accuracy: 0.8336
# Epoch 71/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9937
# Epoch 71: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0195 - accuracy: 0.9937 - val_loss: 0.0666 - val_accuracy: 0.9772
# Epoch 72/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9964
# Epoch 72: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0092 - accuracy: 0.9964 - val_loss: 0.1361 - val_accuracy: 0.9643
# Epoch 73/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 0.9962
# Epoch 73: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.1563 - val_accuracy: 0.9650
# Epoch 74/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9922
# Epoch 74: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.2086 - val_accuracy: 0.9476
# Epoch 75/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9937
# Epoch 75: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0166 - accuracy: 0.9935 - val_loss: 0.1173 - val_accuracy: 0.9787
# Epoch 76/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9897
# Epoch 76: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0363 - accuracy: 0.9897 - val_loss: 0.0867 - val_accuracy: 0.9726
# Epoch 77/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9987
# Epoch 77: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.0684 - val_accuracy: 0.9840
# Epoch 78/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 78: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0593 - val_accuracy: 0.9886
# Epoch 79/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.8945e-04 - accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 2.1404e-04 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 0.9894
# Epoch 80/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998
# Epoch 80: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0668 - val_accuracy: 0.9833
# Epoch 81/100
# 82/83 [============================>.] - ETA: 0s - loss: 2.5397e-04 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 2.5356e-04 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9856
# Epoch 82/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.4162e-04 - accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 1.4128e-04 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9894
# Epoch 83/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.3262e-04 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 1.3768e-04 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9894
# Epoch 84/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.7559e-04 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 1.7548e-04 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9886
# Epoch 85/100
# 82/83 [============================>.] - ETA: 0s - loss: 8.3716e-05 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 8.3523e-05 - accuracy: 1.0000 - val_loss: 0.0579 - val_accuracy: 0.9894
# Epoch 86/100
# 82/83 [============================>.] - ETA: 0s - loss: 3.9886e-05 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 4.2256e-05 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9878
# Epoch 87/100
# 82/83 [============================>.] - ETA: 0s - loss: 5.9146e-05 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 5.8971e-05 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9871
# Epoch 88/100
# 82/83 [============================>.] - ETA: 0s - loss: 2.7915e-05 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 2.7840e-05 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9871
# Epoch 89/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.5856e-05 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 1.6393e-05 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9871
# Epoch 90/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.9716e-05 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 1.9704e-05 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9863
# Epoch 91/100
# 82/83 [============================>.] - ETA: 0s - loss: 3.2228e-05 - accuracy: 1.0000
# Epoch 91: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 69ms/step - loss: 3.2136e-05 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9863
# Epoch 92/100
# 82/83 [============================>.] - ETA: 0s - loss: 2.3937e-05 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 2.3868e-05 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9871
# Epoch 93/100
# 82/83 [============================>.] - ETA: 0s - loss: 2.4809e-05 - accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 2.4771e-05 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9878
# Epoch 94/100
# 82/83 [============================>.] - ETA: 0s - loss: 2.2387e-05 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 2.2324e-05 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 0.9871
# Epoch 95/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.5531e-05 - accuracy: 1.0000
# Epoch 95: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 1.7940e-05 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9871
# Epoch 96/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.1216e-05 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 1.1186e-05 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9856
# Epoch 97/100
# 82/83 [============================>.] - ETA: 0s - loss: 8.8424e-06 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 8.8192e-06 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 0.9863
# Epoch 98/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.0474e-05 - accuracy: 1.0000
# Epoch 98: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 1.1130e-05 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 0.9863
# Epoch 99/100
# 82/83 [============================>.] - ETA: 0s - loss: 9.3106e-06 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 68ms/step - loss: 1.0392e-05 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9863
# Epoch 100/100
# 82/83 [============================>.] - ETA: 0s - loss: 1.2473e-05 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 0.98936
# 83/83 [==============================] - 6s 67ms/step - loss: 1.2438e-05 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9863

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = model.predict(X_val)
# Out:
# 42/42 [==============================] - 2s 14ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("ShuffleNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# ShuffleNet MODEL SONUÇLARI
# Doğruluk:  0.986322188449848
# F1_Skor:  0.9863285128480082
# Hassasiyet:  0.9863943748559133
# Duyarlılık:  0.9862981966434636

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix ResNet50v2+IncResnetV2')
cm_dense = confusion_matrix(Y_val, y_pred)
print(cm_dense)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm_dense, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# Confusion Matrix ResNet50v2+IncResnetV2
# [[327   2   0   5]
#  [  2 306   0   0]
#  [  0   0 345   0]
#  [  9   0   0 320]]
# <Axes: >
