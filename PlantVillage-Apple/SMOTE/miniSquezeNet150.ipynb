# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Apple___Apple_scab',
               'Apple___Black_rot',
               'Apple___Cedar_apple_rust',
               'Apple___healthy',
               ]

train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Apple/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 3171 images belonging to 4 classes.
# (3171, 224, 224, 3)
# (3171, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(3171,224*224*3)

# %%
x.shape
# Out:
# (3171, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (6580, 150528)

# %%
y_smote.shape
# Out:
# (6580, 4)

# %%
X_smote=X_smote.reshape(6580,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (3171, 150528)
# Shape of X after SMOTE: (6580, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (6580, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
pip install keras_applications
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
from keras_applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
from keras.layers import Input, Convolution2D, MaxPooling2D, Activation, concatenate, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.utils import get_file
#from keras.utils import layer_utils

sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"

WEIGHTS_PATH = "https://github.com/rcmalli/keras-squeezenet/releases/download/v1.0/squeezenet_weights_tf_dim_ordering_tf_kernels.h5"

# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3

    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


# Original SqueezeNet from paper.

def SqueezeNet(input_tensor=None, input_shape=None,
               weights='imagenet',
               classes=1000,
              use_bn_on_input = False, # to avoid preprocessing
               first_stride = 2
              ):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')


    input_shape = _obtain_input_shape(input_shape,
                                      default_size=224,
                                      min_size=48,
                                      data_format=K.image_data_format(),
                                     require_flatten = False)

    if input_tensor is None:
        raw_img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if use_bn_on_input:
        img_input = BatchNormalization()(raw_img_input)
    else:
        img_input = raw_img_input


    x = Convolution2D(64, (3, 3), strides=(first_stride, first_stride), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    #x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    #x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    #x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    #x = fire_module(x, fire_id=9, squeeze=64, expand=256)
    x = Dropout(0.5, name='drop9')(x)

    x = Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = Activation('relu', name='relu_conv10')(x)
    x = GlobalAveragePooling2D()(x)
    out = Activation('softmax', name='loss')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = raw_img_input

    model = Model(inputs, out, name='squeezenet')

    # load weights
    if weights == 'imagenet':

        weights_path = get_file('squeezenet_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model

# %%
X_train.shape[0:]
# Out:
# (5264, 224, 224, 3)

# %%
model = SqueezeNet(input_shape = (X_train.shape[1:]), weights = None, classes = Y_train.shape[1],
                  use_bn_on_input = True)
# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.Adam(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
loss_history = []
model.summary()
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  batch_normalization (Batch  (None, 224, 224, 3)          12        ['input_1[0][0]']
#  Normalization)
#
#  conv1 (Conv2D)              (None, 111, 111, 64)         1792      ['batch_normalization[0][0]']
#
#  relu_conv1 (Activation)     (None, 111, 111, 64)         0         ['conv1[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 55, 55, 64)           0         ['relu_conv1[0][0]']
#
#  fire2/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           1040      ['pool1[0][0]']
#
#  fire2/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire2/squeeze1x1[0][0]']
#  ivation)
#
#  fire2/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire2/expand1x1[0][0]']
#  vation)
#
#  fire2/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire2/expand3x3[0][0]']
#  vation)
#
#  fire2/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire2/relu_expand1x1[0][0]',
#                                                                      'fire2/relu_expand3x3[0][0]']
#
#  fire3/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           2064      ['fire2/concat[0][0]']
#
#  fire3/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire3/squeeze1x1[0][0]']
#  ivation)
#
#  fire3/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire3/expand1x1[0][0]']
#  vation)
#
#  fire3/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire3/expand3x3[0][0]']
#  vation)
#
#  fire3/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire3/relu_expand1x1[0][0]',
#                                                                      'fire3/relu_expand3x3[0][0]']
#
#  pool3 (MaxPooling2D)        (None, 27, 27, 128)          0         ['fire3/concat[0][0]']
#
#  fire4/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           4128      ['pool3[0][0]']
#
#  fire4/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire4/squeeze1x1[0][0]']
#  ivation)
#
#  fire4/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire4/expand1x1[0][0]']
#  vation)
#
#  fire4/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire4/expand3x3[0][0]']
#  vation)
#
#  fire4/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire4/relu_expand1x1[0][0]',
#                                                                      'fire4/relu_expand3x3[0][0]']
#
#  fire5/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           8224      ['fire4/concat[0][0]']
#
#  fire5/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire5/squeeze1x1[0][0]']
#  ivation)
#
#  fire5/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire5/expand1x1[0][0]']
#  vation)
#
#  fire5/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire5/expand3x3[0][0]']
#  vation)
#
#  fire5/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire5/relu_expand1x1[0][0]',
#                                                                      'fire5/relu_expand3x3[0][0]']
#
#  pool5 (MaxPooling2D)        (None, 13, 13, 256)          0         ['fire5/concat[0][0]']
#
#  drop9 (Dropout)             (None, 13, 13, 256)          0         ['pool5[0][0]']
#
#  conv10 (Conv2D)             (None, 13, 13, 4)            1028      ['drop9[0][0]']
#
#  relu_conv10 (Activation)    (None, 13, 13, 4)            0         ['conv10[0][0]']
#
#  global_average_pooling2d (  (None, 4)                    0         ['relu_conv10[0][0]']
#  GlobalAveragePooling2D)
#
#  loss (Activation)           (None, 4)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 121456 (474.44 KB)
# Trainable params: 121450 (474.41 KB)
# Non-trainable params: 6 (24.00 Byte)
# __________________________________________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
EPOCHS = 150
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist=model.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/150
# 83/83 [==============================] - ETA: 0s - loss: 1.3254 - accuracy: 0.3570
# Epoch 1: val_accuracy improved from -inf to 0.32371, saving model to best_model.h5
# 83/83 [==============================] - 13s 84ms/step - loss: 1.3254 - accuracy: 0.3570 - val_loss: 1.3593 - val_accuracy: 0.3237
# Epoch 2/150
#  1/83 [..............................] - ETA: 3s - loss: 1.2059 - accuracy: 0.4375
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 83/83 [==============================] - ETA: 0s - loss: 0.9160 - accuracy: 0.6343
# Epoch 2: val_accuracy improved from 0.32371 to 0.37310, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.9160 - accuracy: 0.6343 - val_loss: 1.2236 - val_accuracy: 0.3731
# Epoch 3/150
# 83/83 [==============================] - ETA: 0s - loss: 0.5830 - accuracy: 0.7808
# Epoch 3: val_accuracy improved from 0.37310 to 0.65578, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.5830 - accuracy: 0.7808 - val_loss: 0.7828 - val_accuracy: 0.6558
# Epoch 4/150
# 83/83 [==============================] - ETA: 0s - loss: 0.5090 - accuracy: 0.8119
# Epoch 4: val_accuracy improved from 0.65578 to 0.69909, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.5090 - accuracy: 0.8119 - val_loss: 0.6910 - val_accuracy: 0.6991
# Epoch 5/150
# 83/83 [==============================] - ETA: 0s - loss: 0.4454 - accuracy: 0.8368
# Epoch 5: val_accuracy improved from 0.69909 to 0.82295, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.4454 - accuracy: 0.8368 - val_loss: 0.4738 - val_accuracy: 0.8229
# Epoch 6/150
# 83/83 [==============================] - ETA: 0s - loss: 0.3998 - accuracy: 0.8524
# Epoch 6: val_accuracy improved from 0.82295 to 0.83055, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.3998 - accuracy: 0.8524 - val_loss: 0.4436 - val_accuracy: 0.8305
# Epoch 7/150
# 83/83 [==============================] - ETA: 0s - loss: 0.3912 - accuracy: 0.8568
# Epoch 7: val_accuracy improved from 0.83055 to 0.85942, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.3912 - accuracy: 0.8568 - val_loss: 0.3674 - val_accuracy: 0.8594
# Epoch 8/150
# 83/83 [==============================] - ETA: 0s - loss: 0.3292 - accuracy: 0.8773
# Epoch 8: val_accuracy improved from 0.85942 to 0.88146, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.3292 - accuracy: 0.8773 - val_loss: 0.3375 - val_accuracy: 0.8815
# Epoch 9/150
# 83/83 [==============================] - ETA: 0s - loss: 0.3193 - accuracy: 0.8834
# Epoch 9: val_accuracy did not improve from 0.88146
# 83/83 [==============================] - 4s 48ms/step - loss: 0.3193 - accuracy: 0.8834 - val_loss: 0.3548 - val_accuracy: 0.8678
# Epoch 10/150
# 83/83 [==============================] - ETA: 0s - loss: 0.2976 - accuracy: 0.8904
# Epoch 10: val_accuracy improved from 0.88146 to 0.88830, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.2976 - accuracy: 0.8904 - val_loss: 0.3167 - val_accuracy: 0.8883
# Epoch 11/150
# 83/83 [==============================] - ETA: 0s - loss: 0.2678 - accuracy: 0.9041
# Epoch 11: val_accuracy improved from 0.88830 to 0.90426, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.2678 - accuracy: 0.9041 - val_loss: 0.2812 - val_accuracy: 0.9043
# Epoch 12/150
# 83/83 [==============================] - ETA: 0s - loss: 0.2455 - accuracy: 0.9147
# Epoch 12: val_accuracy improved from 0.90426 to 0.91413, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.2455 - accuracy: 0.9147 - val_loss: 0.2532 - val_accuracy: 0.9141
# Epoch 13/150
# 83/83 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9252
# Epoch 13: val_accuracy improved from 0.91413 to 0.92477, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.2190 - accuracy: 0.9252 - val_loss: 0.2333 - val_accuracy: 0.9248
# Epoch 14/150
# 83/83 [==============================] - ETA: 0s - loss: 0.2069 - accuracy: 0.9297
# Epoch 14: val_accuracy improved from 0.92477 to 0.93541, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.2069 - accuracy: 0.9297 - val_loss: 0.2155 - val_accuracy: 0.9354
# Epoch 15/150
# 83/83 [==============================] - ETA: 0s - loss: 0.2089 - accuracy: 0.9280
# Epoch 15: val_accuracy improved from 0.93541 to 0.93921, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.2089 - accuracy: 0.9280 - val_loss: 0.2042 - val_accuracy: 0.9392
# Epoch 16/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1790 - accuracy: 0.9400
# Epoch 16: val_accuracy improved from 0.93921 to 0.93997, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.1790 - accuracy: 0.9400 - val_loss: 0.1928 - val_accuracy: 0.9400
# Epoch 17/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1808 - accuracy: 0.9426
# Epoch 17: val_accuracy improved from 0.93997 to 0.94833, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.1808 - accuracy: 0.9426 - val_loss: 0.1796 - val_accuracy: 0.9483
# Epoch 18/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1697 - accuracy: 0.9462
# Epoch 18: val_accuracy did not improve from 0.94833
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1697 - accuracy: 0.9462 - val_loss: 0.1789 - val_accuracy: 0.9468
# Epoch 19/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1835 - accuracy: 0.9400
# Epoch 19: val_accuracy did not improve from 0.94833
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1835 - accuracy: 0.9400 - val_loss: 0.1838 - val_accuracy: 0.9468
# Epoch 20/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9481
# Epoch 20: val_accuracy improved from 0.94833 to 0.94909, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.1596 - accuracy: 0.9481 - val_loss: 0.1798 - val_accuracy: 0.9491
# Epoch 21/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9428
# Epoch 21: val_accuracy improved from 0.94909 to 0.95669, saving model to best_model.h5
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1704 - accuracy: 0.9428 - val_loss: 0.1660 - val_accuracy: 0.9567
# Epoch 22/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9529
# Epoch 22: val_accuracy improved from 0.95669 to 0.96125, saving model to best_model.h5
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1442 - accuracy: 0.9529 - val_loss: 0.1613 - val_accuracy: 0.9612
# Epoch 23/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9550
# Epoch 23: val_accuracy did not improve from 0.96125
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1442 - accuracy: 0.9550 - val_loss: 0.1612 - val_accuracy: 0.9567
# Epoch 24/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9605
# Epoch 24: val_accuracy did not improve from 0.96125
# 83/83 [==============================] - 4s 47ms/step - loss: 0.1263 - accuracy: 0.9605 - val_loss: 0.1822 - val_accuracy: 0.9498
# Epoch 25/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9588
# Epoch 25: val_accuracy did not improve from 0.96125
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1316 - accuracy: 0.9588 - val_loss: 0.2067 - val_accuracy: 0.9362
# Epoch 26/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9576
# Epoch 26: val_accuracy improved from 0.96125 to 0.96277, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.1307 - accuracy: 0.9576 - val_loss: 0.1435 - val_accuracy: 0.9628
# Epoch 27/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9506
# Epoch 27: val_accuracy did not improve from 0.96277
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1503 - accuracy: 0.9506 - val_loss: 0.1586 - val_accuracy: 0.9612
# Epoch 28/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9535
# Epoch 28: val_accuracy improved from 0.96277 to 0.96809, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.1375 - accuracy: 0.9535 - val_loss: 0.1421 - val_accuracy: 0.9681
# Epoch 29/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9620
# Epoch 29: val_accuracy did not improve from 0.96809
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1163 - accuracy: 0.9620 - val_loss: 0.1391 - val_accuracy: 0.9673
# Epoch 30/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9557
# Epoch 30: val_accuracy did not improve from 0.96809
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1293 - accuracy: 0.9557 - val_loss: 0.1570 - val_accuracy: 0.9567
# Epoch 31/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9626
# Epoch 31: val_accuracy did not improve from 0.96809
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1151 - accuracy: 0.9626 - val_loss: 0.2027 - val_accuracy: 0.9460
# Epoch 32/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9542
# Epoch 32: val_accuracy did not improve from 0.96809
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1403 - accuracy: 0.9542 - val_loss: 0.1458 - val_accuracy: 0.9536
# Epoch 33/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9643
# Epoch 33: val_accuracy did not improve from 0.96809
# 83/83 [==============================] - 4s 47ms/step - loss: 0.1116 - accuracy: 0.9643 - val_loss: 0.1521 - val_accuracy: 0.9559
# Epoch 34/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1108 - accuracy: 0.9652
# Epoch 34: val_accuracy did not improve from 0.96809
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1108 - accuracy: 0.9652 - val_loss: 0.1358 - val_accuracy: 0.9673
# Epoch 35/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1023 - accuracy: 0.9673
# Epoch 35: val_accuracy did not improve from 0.96809
# 83/83 [==============================] - 4s 47ms/step - loss: 0.1023 - accuracy: 0.9673 - val_loss: 0.1607 - val_accuracy: 0.9574
# Epoch 36/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9643
# Epoch 36: val_accuracy improved from 0.96809 to 0.97112, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.1155 - accuracy: 0.9643 - val_loss: 0.1219 - val_accuracy: 0.9711
# Epoch 37/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9673
# Epoch 37: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1034 - accuracy: 0.9673 - val_loss: 0.1645 - val_accuracy: 0.9521
# Epoch 38/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9664
# Epoch 38: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 47ms/step - loss: 0.1089 - accuracy: 0.9664 - val_loss: 0.1428 - val_accuracy: 0.9643
# Epoch 39/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9599
# Epoch 39: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1144 - accuracy: 0.9599 - val_loss: 0.1815 - val_accuracy: 0.9483
# Epoch 40/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9681
# Epoch 40: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1019 - accuracy: 0.9681 - val_loss: 0.1598 - val_accuracy: 0.9559
# Epoch 41/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9706
# Epoch 41: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0919 - accuracy: 0.9706 - val_loss: 0.1332 - val_accuracy: 0.9666
# Epoch 42/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9658
# Epoch 42: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1047 - accuracy: 0.9658 - val_loss: 0.1327 - val_accuracy: 0.9696
# Epoch 43/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9696
# Epoch 43: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0969 - accuracy: 0.9696 - val_loss: 0.1505 - val_accuracy: 0.9612
# Epoch 44/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9719
# Epoch 44: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0873 - accuracy: 0.9719 - val_loss: 0.1368 - val_accuracy: 0.9590
# Epoch 45/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9685
# Epoch 45: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1001 - accuracy: 0.9685 - val_loss: 0.1216 - val_accuracy: 0.9688
# Epoch 46/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9683
# Epoch 46: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0938 - accuracy: 0.9683 - val_loss: 0.1080 - val_accuracy: 0.9711
# Epoch 47/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9713
# Epoch 47: val_accuracy did not improve from 0.97112
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0892 - accuracy: 0.9713 - val_loss: 0.1340 - val_accuracy: 0.9658
# Epoch 48/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9717
# Epoch 48: val_accuracy improved from 0.97112 to 0.97340, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.0910 - accuracy: 0.9717 - val_loss: 0.1091 - val_accuracy: 0.9734
# Epoch 49/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9736
# Epoch 49: val_accuracy improved from 0.97340 to 0.97720, saving model to best_model.h5
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0832 - accuracy: 0.9736 - val_loss: 0.1037 - val_accuracy: 0.9772
# Epoch 50/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9660
# Epoch 50: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0969 - accuracy: 0.9660 - val_loss: 0.1164 - val_accuracy: 0.9711
# Epoch 51/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.9622
# Epoch 51: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1129 - accuracy: 0.9622 - val_loss: 0.1177 - val_accuracy: 0.9719
# Epoch 52/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9736
# Epoch 52: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0829 - accuracy: 0.9736 - val_loss: 0.1176 - val_accuracy: 0.9726
# Epoch 53/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9766
# Epoch 53: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0746 - accuracy: 0.9766 - val_loss: 0.1081 - val_accuracy: 0.9711
# Epoch 54/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9715
# Epoch 54: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0889 - accuracy: 0.9715 - val_loss: 0.1204 - val_accuracy: 0.9643
# Epoch 55/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9728
# Epoch 55: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0872 - accuracy: 0.9728 - val_loss: 0.1360 - val_accuracy: 0.9567
# Epoch 56/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9725
# Epoch 56: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0815 - accuracy: 0.9725 - val_loss: 0.1002 - val_accuracy: 0.9772
# Epoch 57/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9763
# Epoch 57: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0758 - accuracy: 0.9763 - val_loss: 0.1123 - val_accuracy: 0.9681
# Epoch 58/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9736
# Epoch 58: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0793 - accuracy: 0.9736 - val_loss: 0.1160 - val_accuracy: 0.9681
# Epoch 59/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9749
# Epoch 59: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0756 - accuracy: 0.9749 - val_loss: 0.1094 - val_accuracy: 0.9726
# Epoch 60/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9764
# Epoch 60: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0750 - accuracy: 0.9764 - val_loss: 0.1019 - val_accuracy: 0.9749
# Epoch 61/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9755
# Epoch 61: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0744 - accuracy: 0.9755 - val_loss: 0.1101 - val_accuracy: 0.9749
# Epoch 62/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9732
# Epoch 62: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0758 - accuracy: 0.9732 - val_loss: 0.0949 - val_accuracy: 0.9772
# Epoch 63/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9757
# Epoch 63: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0749 - accuracy: 0.9757 - val_loss: 0.1043 - val_accuracy: 0.9742
# Epoch 64/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9789
# Epoch 64: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0693 - accuracy: 0.9789 - val_loss: 0.1188 - val_accuracy: 0.9688
# Epoch 65/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9770
# Epoch 65: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0748 - accuracy: 0.9770 - val_loss: 0.1272 - val_accuracy: 0.9681
# Epoch 66/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9801
# Epoch 66: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0610 - accuracy: 0.9801 - val_loss: 0.1034 - val_accuracy: 0.9749
# Epoch 67/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9823
# Epoch 67: val_accuracy did not improve from 0.97720
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0586 - accuracy: 0.9823 - val_loss: 0.0979 - val_accuracy: 0.9749
# Epoch 68/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9736
# Epoch 68: val_accuracy improved from 0.97720 to 0.97872, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.0753 - accuracy: 0.9736 - val_loss: 0.0899 - val_accuracy: 0.9787
# Epoch 69/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9774
# Epoch 69: val_accuracy improved from 0.97872 to 0.97948, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.0659 - accuracy: 0.9774 - val_loss: 0.0988 - val_accuracy: 0.9795
# Epoch 70/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9774
# Epoch 70: val_accuracy did not improve from 0.97948
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0667 - accuracy: 0.9774 - val_loss: 0.1004 - val_accuracy: 0.9726
# Epoch 71/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9768
# Epoch 71: val_accuracy did not improve from 0.97948
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0697 - accuracy: 0.9768 - val_loss: 0.0883 - val_accuracy: 0.9772
# Epoch 72/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9749
# Epoch 72: val_accuracy did not improve from 0.97948
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0694 - accuracy: 0.9749 - val_loss: 0.1052 - val_accuracy: 0.9772
# Epoch 73/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9829
# Epoch 73: val_accuracy did not improve from 0.97948
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0554 - accuracy: 0.9829 - val_loss: 0.0890 - val_accuracy: 0.9749
# Epoch 74/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9783
# Epoch 74: val_accuracy did not improve from 0.97948
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0665 - accuracy: 0.9783 - val_loss: 0.1034 - val_accuracy: 0.9749
# Epoch 75/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9816
# Epoch 75: val_accuracy improved from 0.97948 to 0.98100, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.0568 - accuracy: 0.9816 - val_loss: 0.0902 - val_accuracy: 0.9810
# Epoch 76/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9808
# Epoch 76: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0621 - accuracy: 0.9808 - val_loss: 0.1948 - val_accuracy: 0.9438
# Epoch 77/150
# 83/83 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9576
# Epoch 77: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1299 - accuracy: 0.9576 - val_loss: 0.0844 - val_accuracy: 0.9795
# Epoch 78/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9797
# Epoch 78: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0602 - accuracy: 0.9797 - val_loss: 0.0789 - val_accuracy: 0.9810
# Epoch 79/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9818
# Epoch 79: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0584 - accuracy: 0.9818 - val_loss: 0.0914 - val_accuracy: 0.9780
# Epoch 80/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9778
# Epoch 80: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0652 - accuracy: 0.9778 - val_loss: 0.1067 - val_accuracy: 0.9696
# Epoch 81/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9823
# Epoch 81: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0553 - accuracy: 0.9823 - val_loss: 0.0974 - val_accuracy: 0.9787
# Epoch 82/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9825
# Epoch 82: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0530 - accuracy: 0.9825 - val_loss: 0.0890 - val_accuracy: 0.9757
# Epoch 83/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9825
# Epoch 83: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0489 - accuracy: 0.9825 - val_loss: 0.1077 - val_accuracy: 0.9742
# Epoch 84/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9755
# Epoch 84: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0721 - accuracy: 0.9755 - val_loss: 0.0892 - val_accuracy: 0.9802
# Epoch 85/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9810
# Epoch 85: val_accuracy did not improve from 0.98100
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0588 - accuracy: 0.9810 - val_loss: 0.0848 - val_accuracy: 0.9795
# Epoch 86/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9780
# Epoch 86: val_accuracy improved from 0.98100 to 0.98252, saving model to best_model.h5
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0599 - accuracy: 0.9780 - val_loss: 0.0860 - val_accuracy: 0.9825
# Epoch 87/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9827
# Epoch 87: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0480 - accuracy: 0.9827 - val_loss: 0.0806 - val_accuracy: 0.9802
# Epoch 88/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9846
# Epoch 88: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0456 - accuracy: 0.9846 - val_loss: 0.0725 - val_accuracy: 0.9749
# Epoch 89/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0493 - accuracy: 0.9821
# Epoch 89: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0493 - accuracy: 0.9821 - val_loss: 0.0797 - val_accuracy: 0.9780
# Epoch 90/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9848
# Epoch 90: val_accuracy improved from 0.98252 to 0.98328, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.0455 - accuracy: 0.9848 - val_loss: 0.0886 - val_accuracy: 0.9833
# Epoch 91/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9859
# Epoch 91: val_accuracy did not improve from 0.98328
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0428 - accuracy: 0.9859 - val_loss: 0.0876 - val_accuracy: 0.9795
# Epoch 92/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9818
# Epoch 92: val_accuracy did not improve from 0.98328
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0568 - accuracy: 0.9818 - val_loss: 0.0675 - val_accuracy: 0.9802
# Epoch 93/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9835
# Epoch 93: val_accuracy did not improve from 0.98328
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0495 - accuracy: 0.9835 - val_loss: 0.0897 - val_accuracy: 0.9726
# Epoch 94/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9774
# Epoch 94: val_accuracy did not improve from 0.98328
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0696 - accuracy: 0.9774 - val_loss: 0.0898 - val_accuracy: 0.9734
# Epoch 95/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9804
# Epoch 95: val_accuracy did not improve from 0.98328
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0554 - accuracy: 0.9804 - val_loss: 0.0698 - val_accuracy: 0.9825
# Epoch 96/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9814
# Epoch 96: val_accuracy did not improve from 0.98328
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0503 - accuracy: 0.9814 - val_loss: 0.0858 - val_accuracy: 0.9757
# Epoch 97/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9846
# Epoch 97: val_accuracy did not improve from 0.98328
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0461 - accuracy: 0.9846 - val_loss: 0.0881 - val_accuracy: 0.9818
# Epoch 98/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9837
# Epoch 98: val_accuracy improved from 0.98328 to 0.98404, saving model to best_model.h5
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0484 - accuracy: 0.9837 - val_loss: 0.0634 - val_accuracy: 0.9840
# Epoch 99/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9831
# Epoch 99: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0460 - accuracy: 0.9831 - val_loss: 0.0714 - val_accuracy: 0.9818
# Epoch 100/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9854
# Epoch 100: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0425 - accuracy: 0.9854 - val_loss: 0.0883 - val_accuracy: 0.9780
# Epoch 101/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9825
# Epoch 101: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0473 - accuracy: 0.9825 - val_loss: 0.0664 - val_accuracy: 0.9825
# Epoch 102/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9873
# Epoch 102: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0442 - accuracy: 0.9873 - val_loss: 0.0929 - val_accuracy: 0.9810
# Epoch 103/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9808
# Epoch 103: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0540 - accuracy: 0.9808 - val_loss: 0.0897 - val_accuracy: 0.9681
# Epoch 104/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9814
# Epoch 104: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0531 - accuracy: 0.9814 - val_loss: 0.0737 - val_accuracy: 0.9810
# Epoch 105/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9846
# Epoch 105: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0421 - accuracy: 0.9846 - val_loss: 0.0693 - val_accuracy: 0.9818
# Epoch 106/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9812
# Epoch 106: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0649 - accuracy: 0.9812 - val_loss: 0.0740 - val_accuracy: 0.9818
# Epoch 107/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9875
# Epoch 107: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0341 - accuracy: 0.9875 - val_loss: 0.0756 - val_accuracy: 0.9818
# Epoch 108/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9878
# Epoch 108: val_accuracy improved from 0.98404 to 0.98480, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.0365 - accuracy: 0.9878 - val_loss: 0.0608 - val_accuracy: 0.9848
# Epoch 109/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9877
# Epoch 109: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0372 - accuracy: 0.9877 - val_loss: 0.0634 - val_accuracy: 0.9848
# Epoch 110/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9867
# Epoch 110: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0404 - accuracy: 0.9867 - val_loss: 0.0597 - val_accuracy: 0.9818
# Epoch 111/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9844
# Epoch 111: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0445 - accuracy: 0.9844 - val_loss: 0.0662 - val_accuracy: 0.9833
# Epoch 112/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9880
# Epoch 112: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0352 - accuracy: 0.9880 - val_loss: 0.0792 - val_accuracy: 0.9764
# Epoch 113/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9878
# Epoch 113: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0371 - accuracy: 0.9878 - val_loss: 0.0748 - val_accuracy: 0.9802
# Epoch 114/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9831
# Epoch 114: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0468 - accuracy: 0.9831 - val_loss: 0.0651 - val_accuracy: 0.9818
# Epoch 115/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9894
# Epoch 115: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0306 - accuracy: 0.9894 - val_loss: 0.0725 - val_accuracy: 0.9764
# Epoch 116/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9875
# Epoch 116: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0344 - accuracy: 0.9875 - val_loss: 0.0584 - val_accuracy: 0.9833
# Epoch 117/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9880
# Epoch 117: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0337 - accuracy: 0.9880 - val_loss: 0.0774 - val_accuracy: 0.9757
# Epoch 118/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9890
# Epoch 118: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0304 - accuracy: 0.9890 - val_loss: 0.0645 - val_accuracy: 0.9825
# Epoch 119/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9916
# Epoch 119: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0270 - accuracy: 0.9916 - val_loss: 0.0731 - val_accuracy: 0.9772
# Epoch 120/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9867
# Epoch 120: val_accuracy did not improve from 0.98480
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0392 - accuracy: 0.9867 - val_loss: 0.0793 - val_accuracy: 0.9757
# Epoch 121/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9865
# Epoch 121: val_accuracy improved from 0.98480 to 0.98632, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.0363 - accuracy: 0.9865 - val_loss: 0.0586 - val_accuracy: 0.9863
# Epoch 122/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9907
# Epoch 122: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0281 - accuracy: 0.9907 - val_loss: 0.0657 - val_accuracy: 0.9825
# Epoch 123/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9894
# Epoch 123: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0359 - accuracy: 0.9894 - val_loss: 0.0548 - val_accuracy: 0.9810
# Epoch 124/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9899
# Epoch 124: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0331 - accuracy: 0.9899 - val_loss: 0.1355 - val_accuracy: 0.9643
# Epoch 125/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9863
# Epoch 125: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0398 - accuracy: 0.9863 - val_loss: 0.0687 - val_accuracy: 0.9818
# Epoch 126/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9873
# Epoch 126: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0395 - accuracy: 0.9873 - val_loss: 0.0697 - val_accuracy: 0.9818
# Epoch 127/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9884
# Epoch 127: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0323 - accuracy: 0.9884 - val_loss: 0.0978 - val_accuracy: 0.9749
# Epoch 128/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9814
# Epoch 128: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0538 - accuracy: 0.9814 - val_loss: 0.0756 - val_accuracy: 0.9787
# Epoch 129/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9833
# Epoch 129: val_accuracy improved from 0.98632 to 0.98708, saving model to best_model.h5
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0442 - accuracy: 0.9833 - val_loss: 0.0424 - val_accuracy: 0.9871
# Epoch 130/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9892
# Epoch 130: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0267 - accuracy: 0.9892 - val_loss: 0.0811 - val_accuracy: 0.9742
# Epoch 131/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9877
# Epoch 131: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0343 - accuracy: 0.9877 - val_loss: 0.0638 - val_accuracy: 0.9818
# Epoch 132/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9882
# Epoch 132: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0308 - accuracy: 0.9882 - val_loss: 0.0535 - val_accuracy: 0.9863
# Epoch 133/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9928
# Epoch 133: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.0562 - val_accuracy: 0.9825
# Epoch 134/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9918
# Epoch 134: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0225 - accuracy: 0.9918 - val_loss: 0.0444 - val_accuracy: 0.9871
# Epoch 135/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9920
# Epoch 135: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0240 - accuracy: 0.9920 - val_loss: 0.0674 - val_accuracy: 0.9802
# Epoch 136/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9865
# Epoch 136: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0419 - accuracy: 0.9865 - val_loss: 0.0531 - val_accuracy: 0.9848
# Epoch 137/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9890
# Epoch 137: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0284 - accuracy: 0.9890 - val_loss: 0.0527 - val_accuracy: 0.9810
# Epoch 138/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9922
# Epoch 138: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0217 - accuracy: 0.9922 - val_loss: 0.0796 - val_accuracy: 0.9764
# Epoch 139/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9896
# Epoch 139: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0329 - accuracy: 0.9896 - val_loss: 0.0460 - val_accuracy: 0.9863
# Epoch 140/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9928
# Epoch 140: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 0.0606 - val_accuracy: 0.9802
# Epoch 141/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9911
# Epoch 141: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 0.0660 - val_accuracy: 0.9833
# Epoch 142/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9896
# Epoch 142: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0304 - accuracy: 0.9896 - val_loss: 0.0474 - val_accuracy: 0.9871
# Epoch 143/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9930
# Epoch 143: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0209 - accuracy: 0.9930 - val_loss: 0.0508 - val_accuracy: 0.9833
# Epoch 144/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9953
# Epoch 144: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0176 - accuracy: 0.9953 - val_loss: 0.0523 - val_accuracy: 0.9825
# Epoch 145/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9918
# Epoch 145: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0229 - accuracy: 0.9918 - val_loss: 0.0551 - val_accuracy: 0.9848
# Epoch 146/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9913
# Epoch 146: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0228 - accuracy: 0.9913 - val_loss: 0.0462 - val_accuracy: 0.9871
# Epoch 147/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9924
# Epoch 147: val_accuracy did not improve from 0.98708
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0219 - accuracy: 0.9924 - val_loss: 0.0427 - val_accuracy: 0.9863
# Epoch 148/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9916
# Epoch 148: val_accuracy improved from 0.98708 to 0.98784, saving model to best_model.h5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.0237 - accuracy: 0.9916 - val_loss: 0.0390 - val_accuracy: 0.9878
# Epoch 149/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9911
# Epoch 149: val_accuracy did not improve from 0.98784
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0262 - accuracy: 0.9911 - val_loss: 0.0456 - val_accuracy: 0.9856
# Epoch 150/150
# 83/83 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9897
# Epoch 150: val_accuracy did not improve from 0.98784
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0268 - accuracy: 0.9897 - val_loss: 0.0456 - val_accuracy: 0.9863

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 42/42 [==============================] - 1s 14ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("SquezeNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# SquezeNet MODEL SONUÇLARI
# Doğruluk:  0.9878419452887538
# F1_Skor:  0.9877941480562449
# Hassasiyet:  0.9878016184630131
# Duyarlılık:  0.9878988224159584

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[329   2   0   3]
#  [  0 308   0   0]
#  [  0   0 345   0]
#  [  9   2   0 318]]
# <Axes: >
