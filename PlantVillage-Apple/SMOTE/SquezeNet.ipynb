# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Apple___Apple_scab',
               'Apple___Black_rot',
               'Apple___Cedar_apple_rust',
               'Apple___healthy',
               ]

train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Apple/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 3171 images belonging to 4 classes.
# (3171, 224, 224, 3)
# (3171, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(3171,224*224*3)

# %%
x.shape
# Out:
# (3171, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (6580, 150528)

# %%
y_smote.shape
# Out:
# (6580, 4)

# %%
X_smote=X_smote.reshape(6580,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (3171, 150528)
# Shape of X after SMOTE: (6580, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (6580, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
pip install keras_applications
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
from keras_applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
from keras.layers import Input, Convolution2D, MaxPooling2D, Activation, concatenate, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.utils import get_file
#from keras.utils import layer_utils

sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"

WEIGHTS_PATH = "https://github.com/rcmalli/keras-squeezenet/releases/download/v1.0/squeezenet_weights_tf_dim_ordering_tf_kernels.h5"

# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3

    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


# Original SqueezeNet from paper.

def SqueezeNet(input_tensor=None, input_shape=None,
               weights='imagenet',
               classes=1000,
              use_bn_on_input = False, # to avoid preprocessing
               first_stride = 2
              ):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')


    input_shape = _obtain_input_shape(input_shape,
                                      default_size=227,
                                      min_size=48,
                                      data_format=K.image_data_format(),
                                     require_flatten = False)

    if input_tensor is None:
        raw_img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if use_bn_on_input:
        img_input = BatchNormalization()(raw_img_input)
    else:
        img_input = raw_img_input


    x = Convolution2D(64, (3, 3), strides=(first_stride, first_stride), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    x = fire_module(x, fire_id=9, squeeze=64, expand=256)
    x = Dropout(0.5, name='drop9')(x)

    x = Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = Activation('relu', name='relu_conv10')(x)
    x = GlobalAveragePooling2D()(x)
    out = Activation('softmax', name='loss')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = raw_img_input

    model = Model(inputs, out, name='squeezenet')

    # load weights
    if weights == 'imagenet':

        weights_path = get_file('squeezenet_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model

# %%
model = SqueezeNet(input_shape = X_train.shape[1:], weights = None, classes = Y_train.shape[1],
                  use_bn_on_input = True)
# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.Adam(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
loss_history = []
model.summary()
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  batch_normalization (Batch  (None, 224, 224, 3)          12        ['input_1[0][0]']
#  Normalization)
#
#  conv1 (Conv2D)              (None, 111, 111, 64)         1792      ['batch_normalization[0][0]']
#
#  relu_conv1 (Activation)     (None, 111, 111, 64)         0         ['conv1[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 55, 55, 64)           0         ['relu_conv1[0][0]']
#
#  fire2/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           1040      ['pool1[0][0]']
#
#  fire2/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire2/squeeze1x1[0][0]']
#  ivation)
#
#  fire2/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire2/expand1x1[0][0]']
#  vation)
#
#  fire2/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire2/expand3x3[0][0]']
#  vation)
#
#  fire2/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire2/relu_expand1x1[0][0]',
#                                                                      'fire2/relu_expand3x3[0][0]']
#
#  fire3/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           2064      ['fire2/concat[0][0]']
#
#  fire3/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire3/squeeze1x1[0][0]']
#  ivation)
#
#  fire3/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire3/expand1x1[0][0]']
#  vation)
#
#  fire3/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire3/expand3x3[0][0]']
#  vation)
#
#  fire3/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire3/relu_expand1x1[0][0]',
#                                                                      'fire3/relu_expand3x3[0][0]']
#
#  pool3 (MaxPooling2D)        (None, 27, 27, 128)          0         ['fire3/concat[0][0]']
#
#  fire4/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           4128      ['pool3[0][0]']
#
#  fire4/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire4/squeeze1x1[0][0]']
#  ivation)
#
#  fire4/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire4/expand1x1[0][0]']
#  vation)
#
#  fire4/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire4/expand3x3[0][0]']
#  vation)
#
#  fire4/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire4/relu_expand1x1[0][0]',
#                                                                      'fire4/relu_expand3x3[0][0]']
#
#  fire5/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           8224      ['fire4/concat[0][0]']
#
#  fire5/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire5/squeeze1x1[0][0]']
#  ivation)
#
#  fire5/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire5/expand1x1[0][0]']
#  vation)
#
#  fire5/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire5/expand3x3[0][0]']
#  vation)
#
#  fire5/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire5/relu_expand1x1[0][0]',
#                                                                      'fire5/relu_expand3x3[0][0]']
#
#  pool5 (MaxPooling2D)        (None, 13, 13, 256)          0         ['fire5/concat[0][0]']
#
#  fire6/squeeze1x1 (Conv2D)   (None, 13, 13, 48)           12336     ['pool5[0][0]']
#
#  fire6/relu_squeeze1x1 (Act  (None, 13, 13, 48)           0         ['fire6/squeeze1x1[0][0]']
#  ivation)
#
#  fire6/expand1x1 (Conv2D)    (None, 13, 13, 192)          9408      ['fire6/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire6/expand3x3 (Conv2D)    (None, 13, 13, 192)          83136     ['fire6/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire6/relu_expand1x1 (Acti  (None, 13, 13, 192)          0         ['fire6/expand1x1[0][0]']
#  vation)
#
#  fire6/relu_expand3x3 (Acti  (None, 13, 13, 192)          0         ['fire6/expand3x3[0][0]']
#  vation)
#
#  fire6/concat (Concatenate)  (None, 13, 13, 384)          0         ['fire6/relu_expand1x1[0][0]',
#                                                                      'fire6/relu_expand3x3[0][0]']
#
#  fire7/squeeze1x1 (Conv2D)   (None, 13, 13, 48)           18480     ['fire6/concat[0][0]']
#
#  fire7/relu_squeeze1x1 (Act  (None, 13, 13, 48)           0         ['fire7/squeeze1x1[0][0]']
#  ivation)
#
#  fire7/expand1x1 (Conv2D)    (None, 13, 13, 192)          9408      ['fire7/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire7/expand3x3 (Conv2D)    (None, 13, 13, 192)          83136     ['fire7/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire7/relu_expand1x1 (Acti  (None, 13, 13, 192)          0         ['fire7/expand1x1[0][0]']
#  vation)
#
#  fire7/relu_expand3x3 (Acti  (None, 13, 13, 192)          0         ['fire7/expand3x3[0][0]']
#  vation)
#
#  fire7/concat (Concatenate)  (None, 13, 13, 384)          0         ['fire7/relu_expand1x1[0][0]',
#                                                                      'fire7/relu_expand3x3[0][0]']
#
#  fire8/squeeze1x1 (Conv2D)   (None, 13, 13, 64)           24640     ['fire7/concat[0][0]']
#
#  fire8/relu_squeeze1x1 (Act  (None, 13, 13, 64)           0         ['fire8/squeeze1x1[0][0]']
#  ivation)
#
#  fire8/expand1x1 (Conv2D)    (None, 13, 13, 256)          16640     ['fire8/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire8/expand3x3 (Conv2D)    (None, 13, 13, 256)          147712    ['fire8/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire8/relu_expand1x1 (Acti  (None, 13, 13, 256)          0         ['fire8/expand1x1[0][0]']
#  vation)
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#
#  fire8/relu_expand3x3 (Acti  (None, 13, 13, 256)          0         ['fire8/expand3x3[0][0]']
#  vation)
#
#  fire8/concat (Concatenate)  (None, 13, 13, 512)          0         ['fire8/relu_expand1x1[0][0]',
#                                                                      'fire8/relu_expand3x3[0][0]']
#
#  fire9/squeeze1x1 (Conv2D)   (None, 13, 13, 64)           32832     ['fire8/concat[0][0]']
#
#  fire9/relu_squeeze1x1 (Act  (None, 13, 13, 64)           0         ['fire9/squeeze1x1[0][0]']
#  ivation)
#
#  fire9/expand1x1 (Conv2D)    (None, 13, 13, 256)          16640     ['fire9/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire9/expand3x3 (Conv2D)    (None, 13, 13, 256)          147712    ['fire9/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire9/relu_expand1x1 (Acti  (None, 13, 13, 256)          0         ['fire9/expand1x1[0][0]']
#  vation)
#
#  fire9/relu_expand3x3 (Acti  (None, 13, 13, 256)          0         ['fire9/expand3x3[0][0]']
#  vation)
#
#  fire9/concat (Concatenate)  (None, 13, 13, 512)          0         ['fire9/relu_expand1x1[0][0]',
#                                                                      'fire9/relu_expand3x3[0][0]']
#
#  drop9 (Dropout)             (None, 13, 13, 512)          0         ['fire9/concat[0][0]']
#
#  conv10 (Conv2D)             (None, 13, 13, 4)            2052      ['drop9[0][0]']
#
#  relu_conv10 (Activation)    (None, 13, 13, 4)            0         ['conv10[0][0]']
#
#  global_average_pooling2d (  (None, 4)                    0         ['relu_conv10[0][0]']
#  GlobalAveragePooling2D)
#
#  loss (Activation)           (None, 4)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 724560 (2.76 MB)
# Trainable params: 724554 (2.76 MB)
# Non-trainable params: 6 (24.00 Byte)
# __________________________________________________________________________________________________

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=227
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist=model.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 83/83 [==============================] - ETA: 0s - loss: 1.2255 - accuracy: 0.4510
# Epoch 1: val_accuracy improved from -inf to 0.26444, saving model to best_model.h5
# 83/83 [==============================] - 18s 65ms/step - loss: 1.2255 - accuracy: 0.4510 - val_loss: 2.3527 - val_accuracy: 0.2644
# Epoch 2/100
#  1/83 [..............................] - ETA: 2s - loss: 0.7944 - accuracy: 0.6562
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 83/83 [==============================] - ETA: 0s - loss: 0.8171 - accuracy: 0.6220
# Epoch 2: val_accuracy improved from 0.26444 to 0.30471, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.8171 - accuracy: 0.6220 - val_loss: 1.8657 - val_accuracy: 0.3047
# Epoch 3/100
# 83/83 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.6947
# Epoch 3: val_accuracy improved from 0.30471 to 0.49924, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.7192 - accuracy: 0.6947 - val_loss: 1.1567 - val_accuracy: 0.4992
# Epoch 4/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.6222 - accuracy: 0.7681
# Epoch 4: val_accuracy improved from 0.49924 to 0.69681, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.6228 - accuracy: 0.7682 - val_loss: 0.7388 - val_accuracy: 0.6968
# Epoch 5/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.4875 - accuracy: 0.8237
# Epoch 5: val_accuracy improved from 0.69681 to 0.77356, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.4863 - accuracy: 0.8239 - val_loss: 0.5973 - val_accuracy: 0.7736
# Epoch 6/100
# 83/83 [==============================] - ETA: 0s - loss: 0.4259 - accuracy: 0.8514
# Epoch 6: val_accuracy improved from 0.77356 to 0.81991, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.4259 - accuracy: 0.8514 - val_loss: 0.5083 - val_accuracy: 0.8199
# Epoch 7/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.3882 - accuracy: 0.8553
# Epoch 7: val_accuracy improved from 0.81991 to 0.85790, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.3891 - accuracy: 0.8554 - val_loss: 0.3901 - val_accuracy: 0.8579
# Epoch 8/100
# 83/83 [==============================] - ETA: 0s - loss: 0.3692 - accuracy: 0.8687
# Epoch 8: val_accuracy improved from 0.85790 to 0.89058, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.3692 - accuracy: 0.8687 - val_loss: 0.3336 - val_accuracy: 0.8906
# Epoch 9/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.3114 - accuracy: 0.8845
# Epoch 9: val_accuracy improved from 0.89058 to 0.89286, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.3129 - accuracy: 0.8839 - val_loss: 0.3082 - val_accuracy: 0.8929
# Epoch 10/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.3148 - accuracy: 0.8866
# Epoch 10: val_accuracy improved from 0.89286 to 0.89514, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.3152 - accuracy: 0.8866 - val_loss: 0.2849 - val_accuracy: 0.8951
# Epoch 11/100
# 83/83 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.8923
# Epoch 11: val_accuracy improved from 0.89514 to 0.90046, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.2886 - accuracy: 0.8923 - val_loss: 0.2880 - val_accuracy: 0.9005
# Epoch 12/100
# 83/83 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.9031
# Epoch 12: val_accuracy improved from 0.90046 to 0.90274, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.2689 - accuracy: 0.9031 - val_loss: 0.2858 - val_accuracy: 0.9027
# Epoch 13/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.2751 - accuracy: 0.8995
# Epoch 13: val_accuracy improved from 0.90274 to 0.91109, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.2731 - accuracy: 0.9006 - val_loss: 0.2687 - val_accuracy: 0.9111
# Epoch 14/100
# 83/83 [==============================] - ETA: 0s - loss: 0.2299 - accuracy: 0.9198
# Epoch 14: val_accuracy improved from 0.91109 to 0.91337, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.2299 - accuracy: 0.9198 - val_loss: 0.2491 - val_accuracy: 0.9134
# Epoch 15/100
# 83/83 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9094
# Epoch 15: val_accuracy improved from 0.91337 to 0.91793, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.2371 - accuracy: 0.9094 - val_loss: 0.2417 - val_accuracy: 0.9179
# Epoch 16/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.2188 - accuracy: 0.9219
# Epoch 16: val_accuracy did not improve from 0.91793
# 83/83 [==============================] - 3s 40ms/step - loss: 0.2217 - accuracy: 0.9208 - val_loss: 0.2571 - val_accuracy: 0.9164
# Epoch 17/100
# 83/83 [==============================] - ETA: 0s - loss: 0.2202 - accuracy: 0.9202
# Epoch 17: val_accuracy improved from 0.91793 to 0.92021, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.2202 - accuracy: 0.9202 - val_loss: 0.2267 - val_accuracy: 0.9202
# Epoch 18/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.2004 - accuracy: 0.9290
# Epoch 18: val_accuracy improved from 0.92021 to 0.94301, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.1995 - accuracy: 0.9291 - val_loss: 0.1744 - val_accuracy: 0.9430
# Epoch 19/100
# 83/83 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9367
# Epoch 19: val_accuracy improved from 0.94301 to 0.95137, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.1753 - accuracy: 0.9367 - val_loss: 0.1549 - val_accuracy: 0.9514
# Epoch 20/100
# 83/83 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9470
# Epoch 20: val_accuracy improved from 0.95137 to 0.95365, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.1503 - accuracy: 0.9470 - val_loss: 0.1507 - val_accuracy: 0.9536
# Epoch 21/100
# 83/83 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9517
# Epoch 21: val_accuracy did not improve from 0.95365
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1416 - accuracy: 0.9517 - val_loss: 0.1860 - val_accuracy: 0.9422
# Epoch 22/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.1366 - accuracy: 0.9522
# Epoch 22: val_accuracy improved from 0.95365 to 0.95973, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.1352 - accuracy: 0.9527 - val_loss: 0.1346 - val_accuracy: 0.9597
# Epoch 23/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.1157 - accuracy: 0.9597
# Epoch 23: val_accuracy did not improve from 0.95973
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1167 - accuracy: 0.9593 - val_loss: 0.1374 - val_accuracy: 0.9582
# Epoch 24/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.1730 - accuracy: 0.9427
# Epoch 24: val_accuracy did not improve from 0.95973
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1723 - accuracy: 0.9428 - val_loss: 0.1575 - val_accuracy: 0.9552
# Epoch 25/100
# 83/83 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9533
# Epoch 25: val_accuracy improved from 0.95973 to 0.96049, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.1315 - accuracy: 0.9533 - val_loss: 0.1365 - val_accuracy: 0.9605
# Epoch 26/100
# 83/83 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9607
# Epoch 26: val_accuracy improved from 0.96049 to 0.96657, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.1150 - accuracy: 0.9607 - val_loss: 0.1143 - val_accuracy: 0.9666
# Epoch 27/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.1077 - accuracy: 0.9612
# Epoch 27: val_accuracy did not improve from 0.96657
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1066 - accuracy: 0.9618 - val_loss: 0.1154 - val_accuracy: 0.9628
# Epoch 28/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9529
# Epoch 28: val_accuracy did not improve from 0.96657
# 83/83 [==============================] - 3s 39ms/step - loss: 0.1290 - accuracy: 0.9533 - val_loss: 0.2082 - val_accuracy: 0.9309
# Epoch 29/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9618
# Epoch 29: val_accuracy did not improve from 0.96657
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1073 - accuracy: 0.9616 - val_loss: 0.1332 - val_accuracy: 0.9574
# Epoch 30/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9664
# Epoch 30: val_accuracy improved from 0.96657 to 0.97188, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0992 - accuracy: 0.9664 - val_loss: 0.0953 - val_accuracy: 0.9719
# Epoch 31/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0851 - accuracy: 0.9705
# Epoch 31: val_accuracy did not improve from 0.97188
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0853 - accuracy: 0.9706 - val_loss: 0.1294 - val_accuracy: 0.9605
# Epoch 32/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.9610
# Epoch 32: val_accuracy did not improve from 0.97188
# 83/83 [==============================] - 3s 39ms/step - loss: 0.1082 - accuracy: 0.9612 - val_loss: 0.1075 - val_accuracy: 0.9666
# Epoch 33/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9650
# Epoch 33: val_accuracy did not improve from 0.97188
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0984 - accuracy: 0.9650 - val_loss: 0.1158 - val_accuracy: 0.9681
# Epoch 34/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9675
# Epoch 34: val_accuracy did not improve from 0.97188
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0853 - accuracy: 0.9675 - val_loss: 0.0902 - val_accuracy: 0.9696
# Epoch 35/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0778 - accuracy: 0.9724
# Epoch 35: val_accuracy did not improve from 0.97188
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0775 - accuracy: 0.9726 - val_loss: 0.0988 - val_accuracy: 0.9696
# Epoch 36/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0768 - accuracy: 0.9703
# Epoch 36: val_accuracy did not improve from 0.97188
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0782 - accuracy: 0.9702 - val_loss: 0.1354 - val_accuracy: 0.9612
# Epoch 37/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9742
# Epoch 37: val_accuracy improved from 0.97188 to 0.97492, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0760 - accuracy: 0.9742 - val_loss: 0.0776 - val_accuracy: 0.9749
# Epoch 38/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0722 - accuracy: 0.9738
# Epoch 38: val_accuracy did not improve from 0.97492
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0719 - accuracy: 0.9740 - val_loss: 0.1292 - val_accuracy: 0.9620
# Epoch 39/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.1032 - accuracy: 0.9630
# Epoch 39: val_accuracy did not improve from 0.97492
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1021 - accuracy: 0.9633 - val_loss: 0.0903 - val_accuracy: 0.9704
# Epoch 40/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0655 - accuracy: 0.9770
# Epoch 40: val_accuracy improved from 0.97492 to 0.97568, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0674 - accuracy: 0.9764 - val_loss: 0.0794 - val_accuracy: 0.9757
# Epoch 41/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0650 - accuracy: 0.9792
# Epoch 41: val_accuracy did not improve from 0.97568
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0645 - accuracy: 0.9793 - val_loss: 0.0913 - val_accuracy: 0.9757
# Epoch 42/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9783
# Epoch 42: val_accuracy did not improve from 0.97568
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0572 - accuracy: 0.9783 - val_loss: 0.0823 - val_accuracy: 0.9719
# Epoch 43/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0680 - accuracy: 0.9740
# Epoch 43: val_accuracy did not improve from 0.97568
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0675 - accuracy: 0.9740 - val_loss: 0.1020 - val_accuracy: 0.9726
# Epoch 44/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0996 - accuracy: 0.9660
# Epoch 44: val_accuracy improved from 0.97568 to 0.97872, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0983 - accuracy: 0.9666 - val_loss: 0.0685 - val_accuracy: 0.9787
# Epoch 45/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0540 - accuracy: 0.9807
# Epoch 45: val_accuracy improved from 0.97872 to 0.98100, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.0536 - accuracy: 0.9810 - val_loss: 0.0614 - val_accuracy: 0.9810
# Epoch 46/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0424 - accuracy: 0.9846
# Epoch 46: val_accuracy improved from 0.98100 to 0.98176, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0419 - accuracy: 0.9848 - val_loss: 0.0675 - val_accuracy: 0.9818
# Epoch 47/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0516 - accuracy: 0.9817
# Epoch 47: val_accuracy did not improve from 0.98176
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0518 - accuracy: 0.9818 - val_loss: 0.1175 - val_accuracy: 0.9658
# Epoch 48/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9850
# Epoch 48: val_accuracy did not improve from 0.98176
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0403 - accuracy: 0.9850 - val_loss: 0.0602 - val_accuracy: 0.9818
# Epoch 49/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0412 - accuracy: 0.9867
# Epoch 49: val_accuracy did not improve from 0.98176
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0409 - accuracy: 0.9867 - val_loss: 0.0749 - val_accuracy: 0.9780
# Epoch 50/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0685 - accuracy: 0.9743
# Epoch 50: val_accuracy did not improve from 0.98176
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0687 - accuracy: 0.9740 - val_loss: 0.0583 - val_accuracy: 0.9810
# Epoch 51/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0501 - accuracy: 0.9807
# Epoch 51: val_accuracy did not improve from 0.98176
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0504 - accuracy: 0.9804 - val_loss: 0.0608 - val_accuracy: 0.9818
# Epoch 52/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.9900
# Epoch 52: val_accuracy did not improve from 0.98176
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0287 - accuracy: 0.9899 - val_loss: 0.0710 - val_accuracy: 0.9795
# Epoch 53/100
# 82/83 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9832
# Epoch 53: val_accuracy did not improve from 0.98176
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0539 - accuracy: 0.9831 - val_loss: 0.0597 - val_accuracy: 0.9787
# Epoch 54/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9848
# Epoch 54: val_accuracy improved from 0.98176 to 0.98404, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0356 - accuracy: 0.9850 - val_loss: 0.0473 - val_accuracy: 0.9840
# Epoch 55/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9795
# Epoch 55: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0495 - accuracy: 0.9795 - val_loss: 0.1092 - val_accuracy: 0.9635
# Epoch 56/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0356 - accuracy: 0.9869
# Epoch 56: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0357 - accuracy: 0.9867 - val_loss: 0.0593 - val_accuracy: 0.9818
# Epoch 57/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9871
# Epoch 57: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0369 - accuracy: 0.9869 - val_loss: 0.0581 - val_accuracy: 0.9787
# Epoch 58/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0736 - accuracy: 0.9728
# Epoch 58: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0732 - accuracy: 0.9730 - val_loss: 0.0609 - val_accuracy: 0.9818
# Epoch 59/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0348 - accuracy: 0.9886
# Epoch 59: val_accuracy did not improve from 0.98404
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0344 - accuracy: 0.9888 - val_loss: 0.0505 - val_accuracy: 0.9818
# Epoch 60/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9901
# Epoch 60: val_accuracy improved from 0.98404 to 0.98632, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0282 - accuracy: 0.9901 - val_loss: 0.0467 - val_accuracy: 0.9863
# Epoch 61/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9884
# Epoch 61: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0306 - accuracy: 0.9884 - val_loss: 0.1256 - val_accuracy: 0.9559
# Epoch 62/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9900
# Epoch 62: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0255 - accuracy: 0.9901 - val_loss: 0.0434 - val_accuracy: 0.9863
# Epoch 63/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0609 - accuracy: 0.9788
# Epoch 63: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0605 - accuracy: 0.9789 - val_loss: 0.0954 - val_accuracy: 0.9688
# Epoch 64/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9836
# Epoch 64: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0411 - accuracy: 0.9839 - val_loss: 0.0476 - val_accuracy: 0.9840
# Epoch 65/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0292 - accuracy: 0.9913
# Epoch 65: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0288 - accuracy: 0.9915 - val_loss: 0.0914 - val_accuracy: 0.9704
# Epoch 66/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0265 - accuracy: 0.9905
# Epoch 66: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0261 - accuracy: 0.9907 - val_loss: 0.0851 - val_accuracy: 0.9742
# Epoch 67/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9904
# Epoch 67: val_accuracy did not improve from 0.98632
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 0.0636 - val_accuracy: 0.9818
# Epoch 68/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9927
# Epoch 68: val_accuracy improved from 0.98632 to 0.98708, saving model to best_model.h5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.0438 - val_accuracy: 0.9871
# Epoch 69/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9947
# Epoch 69: val_accuracy improved from 0.98708 to 0.98860, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0149 - accuracy: 0.9947 - val_loss: 0.0435 - val_accuracy: 0.9886
# Epoch 70/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0275 - accuracy: 0.9905
# Epoch 70: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0273 - accuracy: 0.9907 - val_loss: 0.0411 - val_accuracy: 0.9878
# Epoch 71/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0141 - accuracy: 0.9954
# Epoch 71: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0139 - accuracy: 0.9954 - val_loss: 0.0732 - val_accuracy: 0.9787
# Epoch 72/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0464 - accuracy: 0.9838
# Epoch 72: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0462 - accuracy: 0.9839 - val_loss: 0.0451 - val_accuracy: 0.9840
# Epoch 73/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9939
# Epoch 73: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0200 - accuracy: 0.9939 - val_loss: 0.0742 - val_accuracy: 0.9802
# Epoch 74/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9884
# Epoch 74: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0297 - accuracy: 0.9882 - val_loss: 0.0937 - val_accuracy: 0.9711
# Epoch 75/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.9913
# Epoch 75: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0276 - accuracy: 0.9915 - val_loss: 0.0425 - val_accuracy: 0.9871
# Epoch 76/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0260 - accuracy: 0.9911
# Epoch 76: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0259 - accuracy: 0.9911 - val_loss: 0.0496 - val_accuracy: 0.9878
# Epoch 77/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9917
# Epoch 77: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.0909 - val_accuracy: 0.9742
# Epoch 78/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0644 - accuracy: 0.9801
# Epoch 78: val_accuracy did not improve from 0.98860
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0637 - accuracy: 0.9804 - val_loss: 0.0461 - val_accuracy: 0.9856
# Epoch 79/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9939
# Epoch 79: val_accuracy improved from 0.98860 to 0.99012, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0180 - accuracy: 0.9939 - val_loss: 0.0351 - val_accuracy: 0.9901
# Epoch 80/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 0.9929
# Epoch 80: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0230 - accuracy: 0.9928 - val_loss: 0.0449 - val_accuracy: 0.9863
# Epoch 81/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9956
# Epoch 81: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.0629 - val_accuracy: 0.9818
# Epoch 82/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9927
# Epoch 82: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0196 - accuracy: 0.9926 - val_loss: 0.0635 - val_accuracy: 0.9856
# Epoch 83/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9903
# Epoch 83: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0249 - accuracy: 0.9903 - val_loss: 0.0424 - val_accuracy: 0.9886
# Epoch 84/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9931
# Epoch 84: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0170 - accuracy: 0.9930 - val_loss: 0.0421 - val_accuracy: 0.9878
# Epoch 85/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9958
# Epoch 85: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0113 - accuracy: 0.9958 - val_loss: 0.0458 - val_accuracy: 0.9894
# Epoch 86/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9942
# Epoch 86: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0151 - accuracy: 0.9943 - val_loss: 0.0571 - val_accuracy: 0.9833
# Epoch 87/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9958
# Epoch 87: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0129 - accuracy: 0.9956 - val_loss: 0.0602 - val_accuracy: 0.9856
# Epoch 88/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9945
# Epoch 88: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0209 - accuracy: 0.9945 - val_loss: 0.1437 - val_accuracy: 0.9666
# Epoch 89/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0236 - accuracy: 0.9913
# Epoch 89: val_accuracy did not improve from 0.99012
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0233 - accuracy: 0.9915 - val_loss: 0.0362 - val_accuracy: 0.9886
# Epoch 90/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9965
# Epoch 90: val_accuracy improved from 0.99012 to 0.99088, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.0317 - val_accuracy: 0.9909
# Epoch 91/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9956
# Epoch 91: val_accuracy did not improve from 0.99088
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0118 - accuracy: 0.9956 - val_loss: 0.0563 - val_accuracy: 0.9810
# Epoch 92/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9896
# Epoch 92: val_accuracy did not improve from 0.99088
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0332 - accuracy: 0.9896 - val_loss: 0.0534 - val_accuracy: 0.9863
# Epoch 93/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9952
# Epoch 93: val_accuracy did not improve from 0.99088
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0168 - accuracy: 0.9947 - val_loss: 0.0423 - val_accuracy: 0.9878
# Epoch 94/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9839
# Epoch 94: val_accuracy did not improve from 0.99088
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0497 - accuracy: 0.9839 - val_loss: 0.0427 - val_accuracy: 0.9886
# Epoch 95/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0138 - accuracy: 0.9950
# Epoch 95: val_accuracy improved from 0.99088 to 0.99164, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.0335 - val_accuracy: 0.9916
# Epoch 96/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9939
# Epoch 96: val_accuracy improved from 0.99164 to 0.99316, saving model to best_model.h5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0175 - accuracy: 0.9939 - val_loss: 0.0336 - val_accuracy: 0.9932
# Epoch 97/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9958
# Epoch 97: val_accuracy did not improve from 0.99316
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0113 - accuracy: 0.9958 - val_loss: 0.0422 - val_accuracy: 0.9894
# Epoch 98/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9917
# Epoch 98: val_accuracy did not improve from 0.99316
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0206 - accuracy: 0.9918 - val_loss: 0.0353 - val_accuracy: 0.9901
# Epoch 99/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9983
# Epoch 99: val_accuracy did not improve from 0.99316
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0387 - val_accuracy: 0.9894
# Epoch 100/100
# 81/83 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9934
# Epoch 100: val_accuracy did not improve from 0.99316
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.0542 - val_accuracy: 0.9886

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 42/42 [==============================] - 1s 10ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("SquezeNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# SquezeNet MODEL SONUÇLARI
# Doğruluk:  0.993161094224924
# F1_Skor:  0.9931544565736411
# Hassasiyet:  0.9931744956114223
# Duyarlılık:  0.9931434106090113

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# Confusion Matrix
# [[331   0   0   3]
#  [  1 307   0   0]
#  [  0   0 345   0]
#  [  4   1   0 324]]
# <Axes: >
