# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Apple___Apple_scab',
               'Apple___Black_rot',
               'Apple___Cedar_apple_rust',
               'Apple___healthy',
               ]

train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Apple/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 3171 images belonging to 4 classes.
# (3171, 224, 224, 3)
# (3171, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(3171,224*224*3)

# %%
x.shape
# Out:
# (3171, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape

# %%
y_smote.shape

# %%
X_smote=X_smote.reshape(6580,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (3171, 150528)
# Shape of X after SMOTE: (6580, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (6580, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
from keras.applications import MobileNetV2
def build_MobilNetV2():
    mobilnetv2 = MobileNetV2(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = mobilnetv2(x)
    x = Flatten(name="flatten")(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    # multi output
    output = Dense(4,activation = 'softmax', name='root')(x)
    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_mobilnet=build_MobilNetV2()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 3)       84
#
#  mobilenetv2_1.00_224 (Func  (None, None, None, 1280   2257984
#  tional)                     )
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dropout (Dropout)           (None, 62720)             0
#
#  dense (Dense)               (None, 256)               16056576
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 4)                 1028
#
# =================================================================
# Total params: 18316696 (69.87 MB)
# Trainable params: 18282072 (69.74 MB)
# Non-trainable params: 34624 (135.25 KB)
# _________________________________________________________________

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist_mobilnetv1=model_mobilnet.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 83/83 [==============================] - ETA: 0s - loss: 0.2940 - accuracy: 0.8976
# Epoch 1: val_accuracy improved from -inf to 0.40198, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 83/83 [==============================] - 66s 331ms/step - loss: 0.2940 - accuracy: 0.8976 - val_loss: 3.7506 - val_accuracy: 0.4020
# Epoch 2/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9909
# Epoch 2: val_accuracy did not improve from 0.40198
# 83/83 [==============================] - 23s 276ms/step - loss: 0.0294 - accuracy: 0.9909 - val_loss: 4.0119 - val_accuracy: 0.3298
# Epoch 3/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9970
# Epoch 3: val_accuracy did not improve from 0.40198
# 83/83 [==============================] - 23s 277ms/step - loss: 0.0126 - accuracy: 0.9970 - val_loss: 4.9733 - val_accuracy: 0.2751
# Epoch 4/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9972
# Epoch 4: val_accuracy did not improve from 0.40198
# 83/83 [==============================] - 23s 279ms/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 4.8459 - val_accuracy: 0.3062
# Epoch 5/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9983
# Epoch 5: val_accuracy did not improve from 0.40198
# 83/83 [==============================] - 23s 281ms/step - loss: 0.0077 - accuracy: 0.9983 - val_loss: 5.7574 - val_accuracy: 0.2903
# Epoch 6/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9977
# Epoch 6: val_accuracy did not improve from 0.40198
# 83/83 [==============================] - 23s 282ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 4.1396 - val_accuracy: 0.3739
# Epoch 7/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9992
# Epoch 7: val_accuracy improved from 0.40198 to 0.40578, saving model to best_model.h5
# 83/83 [==============================] - 25s 296ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 4.0884 - val_accuracy: 0.4058
# Epoch 8/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9985
# Epoch 8: val_accuracy did not improve from 0.40578
# 83/83 [==============================] - 24s 284ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 4.8916 - val_accuracy: 0.3427
# Epoch 9/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9987
# Epoch 9: val_accuracy did not improve from 0.40578
# 83/83 [==============================] - 24s 285ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 4.8332 - val_accuracy: 0.3442
# Epoch 10/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9991
# Epoch 10: val_accuracy did not improve from 0.40578
# 83/83 [==============================] - 24s 286ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 4.7764 - val_accuracy: 0.3435
# Epoch 11/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 11: val_accuracy did not improve from 0.40578
# 83/83 [==============================] - 24s 286ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 4.8506 - val_accuracy: 0.3587
# Epoch 12/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 12: val_accuracy did not improve from 0.40578
# 83/83 [==============================] - 24s 286ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 4.6441 - val_accuracy: 0.3997
# Epoch 13/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 13: val_accuracy improved from 0.40578 to 0.42477, saving model to best_model.h5
# 83/83 [==============================] - 25s 298ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 4.1443 - val_accuracy: 0.4248
# Epoch 14/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992
# Epoch 14: val_accuracy did not improve from 0.42477
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 4.5212 - val_accuracy: 0.3883
# Epoch 15/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9991
# Epoch 15: val_accuracy improved from 0.42477 to 0.44301, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 4.1856 - val_accuracy: 0.4430
# Epoch 16/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9989
# Epoch 16: val_accuracy did not improve from 0.44301
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 4.6183 - val_accuracy: 0.4141
# Epoch 17/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9989
# Epoch 17: val_accuracy did not improve from 0.44301
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 4.7395 - val_accuracy: 0.4225
# Epoch 18/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 18: val_accuracy did not improve from 0.44301
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 5.3959 - val_accuracy: 0.3754
# Epoch 19/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 19: val_accuracy did not improve from 0.44301
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 4.6711 - val_accuracy: 0.4217
# Epoch 20/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 20: val_accuracy did not improve from 0.44301
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 4.4919 - val_accuracy: 0.4255
# Epoch 21/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 21: val_accuracy improved from 0.44301 to 0.48176, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 4.0526 - val_accuracy: 0.4818
# Epoch 22/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 22: val_accuracy improved from 0.48176 to 0.52736, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 3.7876 - val_accuracy: 0.5274
# Epoch 23/100
# 83/83 [==============================] - ETA: 0s - loss: 6.1912e-04 - accuracy: 0.9998
# Epoch 23: val_accuracy improved from 0.52736 to 0.55471, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 6.1912e-04 - accuracy: 0.9998 - val_loss: 3.0041 - val_accuracy: 0.5547
# Epoch 24/100
# 83/83 [==============================] - ETA: 0s - loss: 3.1796e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy improved from 0.55471 to 0.61170, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 3.1796e-04 - accuracy: 1.0000 - val_loss: 2.4652 - val_accuracy: 0.6117
# Epoch 25/100
# 83/83 [==============================] - ETA: 0s - loss: 3.0780e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy improved from 0.61170 to 0.63450, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 3.0780e-04 - accuracy: 1.0000 - val_loss: 2.2482 - val_accuracy: 0.6345
# Epoch 26/100
# 83/83 [==============================] - ETA: 0s - loss: 2.2020e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy improved from 0.63450 to 0.68237, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 2.2020e-04 - accuracy: 1.0000 - val_loss: 1.7727 - val_accuracy: 0.6824
# Epoch 27/100
# 83/83 [==============================] - ETA: 0s - loss: 2.2883e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy improved from 0.68237 to 0.73784, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 2.2883e-04 - accuracy: 1.0000 - val_loss: 1.3777 - val_accuracy: 0.7378
# Epoch 28/100
# 83/83 [==============================] - ETA: 0s - loss: 2.6659e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy improved from 0.73784 to 0.77660, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 2.6659e-04 - accuracy: 1.0000 - val_loss: 1.0528 - val_accuracy: 0.7766
# Epoch 29/100
# 83/83 [==============================] - ETA: 0s - loss: 2.2831e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy improved from 0.77660 to 0.81383, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 2.2831e-04 - accuracy: 1.0000 - val_loss: 0.8040 - val_accuracy: 0.8138
# Epoch 30/100
# 83/83 [==============================] - ETA: 0s - loss: 2.4430e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy improved from 0.81383 to 0.86246, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 2.4430e-04 - accuracy: 1.0000 - val_loss: 0.5372 - val_accuracy: 0.8625
# Epoch 31/100
# 83/83 [==============================] - ETA: 0s - loss: 9.9194e-05 - accuracy: 1.0000
# Epoch 31: val_accuracy improved from 0.86246 to 0.88298, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 9.9194e-05 - accuracy: 1.0000 - val_loss: 0.4430 - val_accuracy: 0.8830
# Epoch 32/100
# 83/83 [==============================] - ETA: 0s - loss: 3.2366e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy improved from 0.88298 to 0.91337, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 3.2366e-04 - accuracy: 1.0000 - val_loss: 0.3148 - val_accuracy: 0.9134
# Epoch 33/100
# 83/83 [==============================] - ETA: 0s - loss: 4.2345e-04 - accuracy: 0.9998
# Epoch 33: val_accuracy did not improve from 0.91337
# 83/83 [==============================] - 24s 288ms/step - loss: 4.2345e-04 - accuracy: 0.9998 - val_loss: 0.3484 - val_accuracy: 0.9103
# Epoch 34/100
# 83/83 [==============================] - ETA: 0s - loss: 7.1307e-04 - accuracy: 0.9998
# Epoch 34: val_accuracy improved from 0.91337 to 0.92477, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 7.1307e-04 - accuracy: 0.9998 - val_loss: 0.3221 - val_accuracy: 0.9248
# Epoch 35/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9989
# Epoch 35: val_accuracy improved from 0.92477 to 0.94225, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.2524 - val_accuracy: 0.9422
# Epoch 36/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9981
# Epoch 36: val_accuracy improved from 0.94225 to 0.98252, saving model to best_model.h5
# 83/83 [==============================] - 25s 299ms/step - loss: 0.0042 - accuracy: 0.9981 - val_loss: 0.0626 - val_accuracy: 0.9825
# Epoch 37/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9954
# Epoch 37: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0857 - val_accuracy: 0.9764
# Epoch 38/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9970
# Epoch 38: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0613 - val_accuracy: 0.9795
# Epoch 39/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9983
# Epoch 39: val_accuracy did not improve from 0.98252
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0038 - accuracy: 0.9983 - val_loss: 0.0736 - val_accuracy: 0.9795
# Epoch 40/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9987
# Epoch 40: val_accuracy improved from 0.98252 to 0.98404, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0529 - val_accuracy: 0.9840
# Epoch 41/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 41: val_accuracy improved from 0.98404 to 0.98860, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0307 - val_accuracy: 0.9886
# Epoch 42/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9985
# Epoch 42: val_accuracy improved from 0.98860 to 0.99468, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0216 - val_accuracy: 0.9947
# Epoch 43/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994
# Epoch 43: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0169 - val_accuracy: 0.9947
# Epoch 44/100
# 83/83 [==============================] - ETA: 0s - loss: 4.7863e-04 - accuracy: 1.0000
# Epoch 44: val_accuracy improved from 0.99468 to 0.99544, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 4.7863e-04 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9954
# Epoch 45/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9992
# Epoch 45: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0183 - val_accuracy: 0.9932
# Epoch 46/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9987
# Epoch 46: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0029 - accuracy: 0.9987 - val_loss: 0.0240 - val_accuracy: 0.9909
# Epoch 47/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9981
# Epoch 47: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0048 - accuracy: 0.9981 - val_loss: 0.0191 - val_accuracy: 0.9947
# Epoch 48/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9981
# Epoch 48: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0049 - accuracy: 0.9981 - val_loss: 0.0478 - val_accuracy: 0.9909
# Epoch 49/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9985
# Epoch 49: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0326 - val_accuracy: 0.9924
# Epoch 50/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 50: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0154 - val_accuracy: 0.9954
# Epoch 51/100
# 83/83 [==============================] - ETA: 0s - loss: 9.6097e-04 - accuracy: 0.9994
# Epoch 51: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 289ms/step - loss: 9.6097e-04 - accuracy: 0.9994 - val_loss: 0.0155 - val_accuracy: 0.9947
# Epoch 52/100
# 83/83 [==============================] - ETA: 0s - loss: 3.2152e-04 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 288ms/step - loss: 3.2152e-04 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9939
# Epoch 53/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 53: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0648 - val_accuracy: 0.9863
# Epoch 54/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 54: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0225 - val_accuracy: 0.9947
# Epoch 55/100
# 83/83 [==============================] - ETA: 0s - loss: 1.9291e-04 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 289ms/step - loss: 1.9291e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9947
# Epoch 56/100
# 83/83 [==============================] - ETA: 0s - loss: 3.8569e-04 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 289ms/step - loss: 3.8569e-04 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 0.9954
# Epoch 57/100
# 83/83 [==============================] - ETA: 0s - loss: 2.4280e-04 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 289ms/step - loss: 2.4280e-04 - accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 0.9924
# Epoch 58/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9985
# Epoch 58: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.0237 - val_accuracy: 0.9932
# Epoch 59/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9973
# Epoch 59: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0112 - accuracy: 0.9973 - val_loss: 0.0246 - val_accuracy: 0.9916
# Epoch 60/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9989
# Epoch 60: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0139 - val_accuracy: 0.9954
# Epoch 61/100
# 83/83 [==============================] - ETA: 0s - loss: 7.6631e-04 - accuracy: 0.9998
# Epoch 61: val_accuracy did not improve from 0.99544
# 83/83 [==============================] - 24s 288ms/step - loss: 7.6631e-04 - accuracy: 0.9998 - val_loss: 0.0225 - val_accuracy: 0.9924
# Epoch 62/100
# 83/83 [==============================] - ETA: 0s - loss: 5.8033e-04 - accuracy: 0.9998
# Epoch 62: val_accuracy improved from 0.99544 to 0.99696, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 5.8033e-04 - accuracy: 0.9998 - val_loss: 0.0077 - val_accuracy: 0.9970
# Epoch 63/100
# 83/83 [==============================] - ETA: 0s - loss: 9.2954e-05 - accuracy: 1.0000
# Epoch 63: val_accuracy improved from 0.99696 to 0.99772, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 9.2954e-05 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9977
# Epoch 64/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9973
# Epoch 64: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0102 - accuracy: 0.9973 - val_loss: 0.0382 - val_accuracy: 0.9871
# Epoch 65/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9987
# Epoch 65: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0243 - val_accuracy: 0.9916
# Epoch 66/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 66: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0276 - val_accuracy: 0.9939
# Epoch 67/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9991
# Epoch 67: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0095 - val_accuracy: 0.9970
# Epoch 68/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994
# Epoch 68: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 0.0098 - val_accuracy: 0.9962
# Epoch 69/100
# 83/83 [==============================] - ETA: 0s - loss: 3.0115e-04 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 24s 288ms/step - loss: 3.0115e-04 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9954
# Epoch 70/100
# 83/83 [==============================] - ETA: 0s - loss: 7.2991e-05 - accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 24s 288ms/step - loss: 7.2991e-05 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9954
# Epoch 71/100
# 83/83 [==============================] - ETA: 0s - loss: 3.5428e-04 - accuracy: 0.9998
# Epoch 71: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 24s 288ms/step - loss: 3.5428e-04 - accuracy: 0.9998 - val_loss: 0.0063 - val_accuracy: 0.9970
# Epoch 72/100
# 83/83 [==============================] - ETA: 0s - loss: 5.9185e-04 - accuracy: 0.9998
# Epoch 72: val_accuracy improved from 0.99772 to 1.00000, saving model to best_model.h5
# 83/83 [==============================] - 25s 300ms/step - loss: 5.9185e-04 - accuracy: 0.9998 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 73/100
# 83/83 [==============================] - ETA: 0s - loss: 7.8936e-04 - accuracy: 0.9996
# Epoch 73: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 288ms/step - loss: 7.8936e-04 - accuracy: 0.9996 - val_loss: 0.0067 - val_accuracy: 0.9977
# Epoch 74/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 74: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0044 - val_accuracy: 0.9970
# Epoch 75/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 75: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0092 - val_accuracy: 0.9962
# Epoch 76/100
# 83/83 [==============================] - ETA: 0s - loss: 4.4232e-04 - accuracy: 0.9998
# Epoch 76: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 288ms/step - loss: 4.4232e-04 - accuracy: 0.9998 - val_loss: 0.0061 - val_accuracy: 0.9962
# Epoch 77/100
# 83/83 [==============================] - ETA: 0s - loss: 1.8248e-04 - accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 1.8248e-04 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9962
# Epoch 78/100
# 83/83 [==============================] - ETA: 0s - loss: 2.4141e-04 - accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 288ms/step - loss: 2.4141e-04 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9977
# Epoch 79/100
# 83/83 [==============================] - ETA: 0s - loss: 7.7462e-04 - accuracy: 0.9998
# Epoch 79: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 288ms/step - loss: 7.7462e-04 - accuracy: 0.9998 - val_loss: 0.0127 - val_accuracy: 0.9970
# Epoch 80/100
# 83/83 [==============================] - ETA: 0s - loss: 2.7129e-04 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 288ms/step - loss: 2.7129e-04 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9977
# Epoch 81/100
# 83/83 [==============================] - ETA: 0s - loss: 8.4977e-04 - accuracy: 0.9996
# Epoch 81: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 8.4977e-04 - accuracy: 0.9996 - val_loss: 0.0098 - val_accuracy: 0.9962
# Epoch 82/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 82: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0565 - val_accuracy: 0.9878
# Epoch 83/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994
# Epoch 83: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0377 - val_accuracy: 0.9878
# Epoch 84/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 84: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0237 - val_accuracy: 0.9939
# Epoch 85/100
# 83/83 [==============================] - ETA: 0s - loss: 3.8470e-04 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 3.8470e-04 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 0.9939
# Epoch 86/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 86: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0497 - val_accuracy: 0.9909
# Epoch 87/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9970
# Epoch 87: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0119 - accuracy: 0.9970 - val_loss: 0.0135 - val_accuracy: 0.9939
# Epoch 88/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9987
# Epoch 88: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 288ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0025 - val_accuracy: 0.9977
# Epoch 89/100
# 83/83 [==============================] - ETA: 0s - loss: 8.1488e-04 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 8.1488e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9985
# Epoch 90/100
# 83/83 [==============================] - ETA: 0s - loss: 2.0615e-04 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 2.0615e-04 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9977
# Epoch 91/100
# 83/83 [==============================] - ETA: 0s - loss: 4.6166e-04 - accuracy: 1.0000
# Epoch 91: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 4.6166e-04 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9985
# Epoch 92/100
# 83/83 [==============================] - ETA: 0s - loss: 4.7128e-04 - accuracy: 0.9998
# Epoch 92: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 4.7128e-04 - accuracy: 0.9998 - val_loss: 0.0045 - val_accuracy: 0.9970
# Epoch 93/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9985
# Epoch 93: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.2743 - val_accuracy: 0.9628
# Epoch 94/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9987
# Epoch 94: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 0.1453 - val_accuracy: 0.9704
# Epoch 95/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 95: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0524 - val_accuracy: 0.9886
# Epoch 96/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992
# Epoch 96: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0981 - val_accuracy: 0.9795
# Epoch 97/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 97: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0305 - val_accuracy: 0.9916
# Epoch 98/100
# 83/83 [==============================] - ETA: 0s - loss: 9.5042e-04 - accuracy: 0.9996
# Epoch 98: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 9.5042e-04 - accuracy: 0.9996 - val_loss: 0.0317 - val_accuracy: 0.9909
# Epoch 99/100
# 83/83 [==============================] - ETA: 0s - loss: 2.4497e-04 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 2.4497e-04 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9954
# Epoch 100/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9983
# Epoch 100: val_accuracy did not improve from 1.00000
# 83/83 [==============================] - 24s 289ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 0.0639 - val_accuracy: 0.9848

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 42/42 [==============================] - 3s 43ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("MobilNetv2 MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred, average='macro'))
print("Hassasiyet: ",precision_score(Y_val, y_pred, average='macro'))
print("Duyarlılık: ", recall_score(Y_val, y_pred, average='macro'))
# Out:
# MobilNetv2 MODEL SONUÇLARI
# Doğruluk:  1.0
# F1_Skor:  1.0
# Hassasiyet:  1.0
# Duyarlılık:  1.0

# %%
plt.plot(hist_mobilnetv1.history['accuracy'])
plt.plot(hist_mobilnetv1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist_mobilnetv1.history['loss'])
plt.plot(hist_mobilnetv1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# Confusion Matrix
# [[334   0   0   0]
#  [  0 308   0   0]
#  [  0   0 345   0]
#  [  0   0   0 329]]
# <Axes: >
