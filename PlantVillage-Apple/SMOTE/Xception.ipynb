# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Apple___Apple_scab',
               'Apple___Black_rot',
               'Apple___Cedar_apple_rust',
               'Apple___healthy',
               ]

train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Apple/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 3171 images belonging to 4 classes.
# (3171, 224, 224, 3)
# (3171, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(3171,224*224*3)

# %%
x.shape
# Out:
# (3171, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (6580, 150528)

# %%
y_smote.shape
# Out:
# (6580, 4)

# %%
X_smote=X_smote.reshape(6580,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (3171, 150528)
# Shape of X after SMOTE: (6580, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (6580, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
from keras.applications import Xception
def build_xception():
    xception = Xception(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = xception(x)
    x = Flatten(name="flatten")(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    # multi output
    output = Dense(4,activation = 'softmax', name='root')(x)
    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_xception= build_xception()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_4 (Conv2D)           (None, 224, 224, 3)       84
#
#  xception (Functional)       (None, None, None, 2048   20861480
#                              )
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dropout (Dropout)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 4)                 1028
#
# =================================================================
# Total params: 46553984 (177.59 MB)
# Trainable params: 46498944 (177.38 MB)
# Non-trainable params: 55040 (215.00 KB)
# _________________________________________________________________

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist_xception=model_xception.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 83/83 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.9177
# Epoch 1: val_accuracy improved from -inf to 0.81003, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 83/83 [==============================] - 62s 358ms/step - loss: 0.2588 - accuracy: 0.9177 - val_loss: 0.6233 - val_accuracy: 0.8100
# Epoch 2/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9935
# Epoch 2: val_accuracy improved from 0.81003 to 0.92933, saving model to best_model.h5
# 83/83 [==============================] - 26s 318ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.2366 - val_accuracy: 0.9293
# Epoch 3/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9981
# Epoch 3: val_accuracy improved from 0.92933 to 0.98252, saving model to best_model.h5
# 83/83 [==============================] - 28s 335ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0534 - val_accuracy: 0.9825
# Epoch 4/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9989
# Epoch 4: val_accuracy improved from 0.98252 to 0.98860, saving model to best_model.h5
# 83/83 [==============================] - 26s 319ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0362 - val_accuracy: 0.9886
# Epoch 5/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9987
# Epoch 5: val_accuracy improved from 0.98860 to 0.99164, saving model to best_model.h5
# 83/83 [==============================] - 26s 318ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0324 - val_accuracy: 0.9916
# Epoch 6/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9994
# Epoch 6: val_accuracy improved from 0.99164 to 0.99468, saving model to best_model.h5
# 83/83 [==============================] - 26s 318ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0260 - val_accuracy: 0.9947
# Epoch 7/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9994
# Epoch 7: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 302ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0444 - val_accuracy: 0.9924
# Epoch 8/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9992
# Epoch 8: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0297 - val_accuracy: 0.9924
# Epoch 9/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9991
# Epoch 9: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 0.0267 - val_accuracy: 0.9909
# Epoch 10/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9983
# Epoch 10: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0287 - val_accuracy: 0.9939
# Epoch 11/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9994
# Epoch 11: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0045 - accuracy: 0.9994 - val_loss: 0.0381 - val_accuracy: 0.9932
# Epoch 12/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9972
# Epoch 12: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0110 - accuracy: 0.9972 - val_loss: 0.0460 - val_accuracy: 0.9894
# Epoch 13/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9991
# Epoch 13: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0444 - val_accuracy: 0.9909
# Epoch 14/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 14: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0463 - val_accuracy: 0.9901
# Epoch 15/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9983
# Epoch 15: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.0472 - val_accuracy: 0.9909
# Epoch 16/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 16: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0414 - val_accuracy: 0.9901
# Epoch 17/100
# 83/83 [==============================] - ETA: 0s - loss: 6.6478e-04 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 6.6478e-04 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9901
# Epoch 18/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 18: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 304ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0321 - val_accuracy: 0.9924
# Epoch 19/100
# 83/83 [==============================] - ETA: 0s - loss: 4.8775e-04 - accuracy: 0.9998
# Epoch 19: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 4.8775e-04 - accuracy: 0.9998 - val_loss: 0.0267 - val_accuracy: 0.9932
# Epoch 20/100
# 83/83 [==============================] - ETA: 0s - loss: 4.6024e-04 - accuracy: 0.9998
# Epoch 20: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 4.6024e-04 - accuracy: 0.9998 - val_loss: 0.0231 - val_accuracy: 0.9916
# Epoch 21/100
# 83/83 [==============================] - ETA: 0s - loss: 4.6638e-04 - accuracy: 0.9998
# Epoch 21: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 4.6638e-04 - accuracy: 0.9998 - val_loss: 0.0231 - val_accuracy: 0.9939
# Epoch 22/100
# 83/83 [==============================] - ETA: 0s - loss: 5.5947e-04 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 5.5947e-04 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9932
# Epoch 23/100
# 83/83 [==============================] - ETA: 0s - loss: 1.7602e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 1.7602e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9939
# Epoch 24/100
# 83/83 [==============================] - ETA: 0s - loss: 8.5174e-04 - accuracy: 0.9996
# Epoch 24: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 8.5174e-04 - accuracy: 0.9996 - val_loss: 0.0276 - val_accuracy: 0.9932
# Epoch 25/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9953
# Epoch 25: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.0755 - val_accuracy: 0.9825
# Epoch 26/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9966
# Epoch 26: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.0447 - val_accuracy: 0.9916
# Epoch 27/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9994
# Epoch 27: val_accuracy did not improve from 0.99468
# 83/83 [==============================] - 25s 304ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0285 - val_accuracy: 0.9939
# Epoch 28/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9992
# Epoch 28: val_accuracy improved from 0.99468 to 0.99696, saving model to best_model.h5
# 83/83 [==============================] - 27s 321ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0128 - val_accuracy: 0.9970
# Epoch 29/100
# 83/83 [==============================] - ETA: 0s - loss: 4.0060e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy improved from 0.99696 to 0.99772, saving model to best_model.h5
# 83/83 [==============================] - 26s 318ms/step - loss: 4.0060e-04 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 0.9977
# Epoch 30/100
# 83/83 [==============================] - ETA: 0s - loss: 2.5533e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 2.5533e-04 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9970
# Epoch 31/100
# 83/83 [==============================] - ETA: 0s - loss: 2.8578e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 302ms/step - loss: 2.8578e-04 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9970
# Epoch 32/100
# 83/83 [==============================] - ETA: 0s - loss: 1.8046e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 1.8046e-04 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9970
# Epoch 33/100
# 83/83 [==============================] - ETA: 0s - loss: 2.2313e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 2.2313e-04 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 0.9962
# Epoch 34/100
# 83/83 [==============================] - ETA: 0s - loss: 1.7131e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 1.7131e-04 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 0.9962
# Epoch 35/100
# 83/83 [==============================] - ETA: 0s - loss: 2.7001e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 2.7001e-04 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9954
# Epoch 36/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 36: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0187 - val_accuracy: 0.9954
# Epoch 37/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9935
# Epoch 37: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 302ms/step - loss: 0.0221 - accuracy: 0.9935 - val_loss: 0.0166 - val_accuracy: 0.9962
# Epoch 38/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9966
# Epoch 38: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.0254 - val_accuracy: 0.9954
# Epoch 39/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9983
# Epoch 39: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0147 - val_accuracy: 0.9962
# Epoch 40/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9985
# Epoch 40: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.0206 - val_accuracy: 0.9970
# Epoch 41/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 41: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0148 - val_accuracy: 0.9954
# Epoch 42/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 42: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0127 - val_accuracy: 0.9962
# Epoch 43/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9994
# Epoch 43: val_accuracy did not improve from 0.99772
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.0135 - val_accuracy: 0.9977
# Epoch 44/100
# 83/83 [==============================] - ETA: 0s - loss: 6.3436e-04 - accuracy: 0.9996
# Epoch 44: val_accuracy improved from 0.99772 to 0.99848, saving model to best_model.h5
# 83/83 [==============================] - 26s 319ms/step - loss: 6.3436e-04 - accuracy: 0.9996 - val_loss: 0.0085 - val_accuracy: 0.9985
# Epoch 45/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 45: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0032 - val_accuracy: 0.9985
# Epoch 46/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9987
# Epoch 46: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0084 - val_accuracy: 0.9985
# Epoch 47/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9953
# Epoch 47: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.0229 - val_accuracy: 0.9947
# Epoch 48/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9992
# Epoch 48: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0132 - val_accuracy: 0.9977
# Epoch 49/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 49: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0165 - val_accuracy: 0.9970
# Epoch 50/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 50: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0086 - val_accuracy: 0.9985
# Epoch 51/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 51: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0051 - val_accuracy: 0.9962
# Epoch 52/100
# 83/83 [==============================] - ETA: 0s - loss: 5.5328e-04 - accuracy: 0.9998
# Epoch 52: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 5.5328e-04 - accuracy: 0.9998 - val_loss: 0.0104 - val_accuracy: 0.9970
# Epoch 53/100
# 83/83 [==============================] - ETA: 0s - loss: 2.2675e-04 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 2.2675e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9970
# Epoch 54/100
# 83/83 [==============================] - ETA: 0s - loss: 1.5160e-04 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 1.5160e-04 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9970
# Epoch 55/100
# 83/83 [==============================] - ETA: 0s - loss: 3.7123e-04 - accuracy: 0.9998
# Epoch 55: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 3.7123e-04 - accuracy: 0.9998 - val_loss: 0.0111 - val_accuracy: 0.9970
# Epoch 56/100
# 83/83 [==============================] - ETA: 0s - loss: 9.8829e-04 - accuracy: 0.9998
# Epoch 56: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 9.8829e-04 - accuracy: 0.9998 - val_loss: 0.0130 - val_accuracy: 0.9962
# Epoch 57/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9964
# Epoch 57: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0133 - accuracy: 0.9964 - val_loss: 0.0381 - val_accuracy: 0.9909
# Epoch 58/100
# 83/83 [==============================] - ETA: 0s - loss: 9.2474e-04 - accuracy: 0.9998
# Epoch 58: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 9.2474e-04 - accuracy: 0.9998 - val_loss: 0.0089 - val_accuracy: 0.9962
# Epoch 59/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9994
# Epoch 59: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0162 - val_accuracy: 0.9947
# Epoch 60/100
# 83/83 [==============================] - ETA: 0s - loss: 8.6473e-04 - accuracy: 0.9998
# Epoch 60: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 8.6473e-04 - accuracy: 0.9998 - val_loss: 0.0133 - val_accuracy: 0.9970
# Epoch 61/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994
# Epoch 61: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0100 - val_accuracy: 0.9970
# Epoch 62/100
# 83/83 [==============================] - ETA: 0s - loss: 3.8233e-04 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 3.8233e-04 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9977
# Epoch 63/100
# 83/83 [==============================] - ETA: 0s - loss: 1.3697e-04 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 1.3697e-04 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9977
# Epoch 64/100
# 83/83 [==============================] - ETA: 0s - loss: 2.7659e-04 - accuracy: 0.9998
# Epoch 64: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 2.7659e-04 - accuracy: 0.9998 - val_loss: 0.0103 - val_accuracy: 0.9977
# Epoch 65/100
# 83/83 [==============================] - ETA: 0s - loss: 1.6638e-04 - accuracy: 1.0000
# Epoch 65: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 1.6638e-04 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9970
# Epoch 66/100
# 83/83 [==============================] - ETA: 0s - loss: 1.4701e-04 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 1.4701e-04 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9977
# Epoch 67/100
# 83/83 [==============================] - ETA: 0s - loss: 1.6202e-04 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 1.6202e-04 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9977
# Epoch 68/100
# 83/83 [==============================] - ETA: 0s - loss: 8.7013e-04 - accuracy: 0.9996
# Epoch 68: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 8.7013e-04 - accuracy: 0.9996 - val_loss: 0.0141 - val_accuracy: 0.9970
# Epoch 69/100
# 83/83 [==============================] - ETA: 0s - loss: 4.2212e-04 - accuracy: 0.9998
# Epoch 69: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 4.2212e-04 - accuracy: 0.9998 - val_loss: 0.0123 - val_accuracy: 0.9970
# Epoch 70/100
# 83/83 [==============================] - ETA: 0s - loss: 6.2968e-04 - accuracy: 0.9998
# Epoch 70: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 6.2968e-04 - accuracy: 0.9998 - val_loss: 0.0111 - val_accuracy: 0.9970
# Epoch 71/100
# 83/83 [==============================] - ETA: 0s - loss: 1.5041e-04 - accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 1.5041e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9970
# Epoch 72/100
# 83/83 [==============================] - ETA: 0s - loss: 6.4490e-05 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 6.4490e-05 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9970
# Epoch 73/100
# 83/83 [==============================] - ETA: 0s - loss: 6.4367e-05 - accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 6.4367e-05 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9970
# Epoch 74/100
# 83/83 [==============================] - ETA: 0s - loss: 4.3465e-05 - accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 4.3465e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9970
# Epoch 75/100
# 83/83 [==============================] - ETA: 0s - loss: 1.0462e-04 - accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 1.0462e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9970
# Epoch 76/100
# 83/83 [==============================] - ETA: 0s - loss: 7.9861e-05 - accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 7.9861e-05 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9970
# Epoch 77/100
# 83/83 [==============================] - ETA: 0s - loss: 4.5022e-05 - accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 4.5022e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9970
# Epoch 78/100
# 83/83 [==============================] - ETA: 0s - loss: 5.1265e-05 - accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 5.1265e-05 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9962
# Epoch 79/100
# 83/83 [==============================] - ETA: 0s - loss: 2.9527e-05 - accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 2.9527e-05 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9962
# Epoch 80/100
# 83/83 [==============================] - ETA: 0s - loss: 3.5987e-05 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 3.5987e-05 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9970
# Epoch 81/100
# 83/83 [==============================] - ETA: 0s - loss: 2.6804e-05 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 2.6804e-05 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9970
# Epoch 82/100
# 83/83 [==============================] - ETA: 0s - loss: 3.7388e-05 - accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 3.7388e-05 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9962
# Epoch 83/100
# 83/83 [==============================] - ETA: 0s - loss: 1.7932e-05 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 1.7932e-05 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9962
# Epoch 84/100
# 83/83 [==============================] - ETA: 0s - loss: 1.5884e-05 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 1.5884e-05 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9962
# Epoch 85/100
# 83/83 [==============================] - ETA: 0s - loss: 2.8150e-05 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 2.8150e-05 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9962
# Epoch 86/100
# 83/83 [==============================] - ETA: 0s - loss: 2.1917e-05 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 2.1917e-05 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9962
# Epoch 87/100
# 83/83 [==============================] - ETA: 0s - loss: 2.3857e-05 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 2.3857e-05 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9962
# Epoch 88/100
# 83/83 [==============================] - ETA: 0s - loss: 2.7620e-05 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 2.7620e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9962
# Epoch 89/100
# 83/83 [==============================] - ETA: 0s - loss: 2.9780e-05 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 2.9780e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9962
# Epoch 90/100
# 83/83 [==============================] - ETA: 0s - loss: 2.0101e-05 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 2.0101e-05 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9962
# Epoch 91/100
# 83/83 [==============================] - ETA: 0s - loss: 6.6053e-04 - accuracy: 0.9998
# Epoch 91: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 6.6053e-04 - accuracy: 0.9998 - val_loss: 0.0166 - val_accuracy: 0.9970
# Epoch 92/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9949
# Epoch 92: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0177 - accuracy: 0.9949 - val_loss: 0.0352 - val_accuracy: 0.9932
# Epoch 93/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9994
# Epoch 93: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.0077 - val_accuracy: 0.9962
# Epoch 94/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9985
# Epoch 94: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0033 - accuracy: 0.9985 - val_loss: 0.0388 - val_accuracy: 0.9939
# Epoch 95/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9985
# Epoch 95: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0130 - val_accuracy: 0.9962
# Epoch 96/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992
# Epoch 96: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0059 - val_accuracy: 0.9970
# Epoch 97/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9973
# Epoch 97: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.0127 - val_accuracy: 0.9962
# Epoch 98/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9996
# Epoch 98: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.0034 - val_accuracy: 0.9985
# Epoch 99/100
# 83/83 [==============================] - ETA: 0s - loss: 9.3119e-04 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 303ms/step - loss: 9.3119e-04 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9977
# Epoch 100/100
# 83/83 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9989
# Epoch 100: val_accuracy did not improve from 0.99848
# 83/83 [==============================] - 25s 304ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0078 - val_accuracy: 0.9977

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 42/42 [==============================] - 3s 47ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("VGG16 MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred, average='macro'))
print("Hassasiyet: ",precision_score(Y_val, y_pred, average='macro'))
print("Duyarlılık: ", recall_score(Y_val, y_pred, average='macro'))
# Out:
# VGG16 MODEL SONUÇLARI
# Doğruluk:  0.9984802431610942
# F1_Skor:  0.9984356084138185
# Hassasiyet:  0.9983870967741936
# Duyarlılık:  0.9984916185865351

# %%
plt.plot(hist_xception.history['accuracy'])
plt.plot(hist_xception.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist_xception.history['loss'])
plt.plot(hist_xception.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# Confusion Matrix
# [[333   1   0   0]
#  [  0 308   0   0]
#  [  0   0 345   0]
#  [  0   1   0 328]]
# <Axes: >
