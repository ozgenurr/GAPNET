# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']


train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/KODLAR/PlantVillage-Patato/Dataset',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 2152 images belonging to 3 classes.
# (2152, 224, 224, 3)
# (2152, 3)

# %%
#Converting  our color images to a vector
x=x.reshape(2152,224*224*3)

# %%
x.shape
# Out:
# (2152, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (3000, 150528)

# %%
y_smote.shape
# Out:
# (3000, 3)

# %%
X_smote=X_smote.reshape(3000,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (2152, 150528)
# Shape of X after SMOTE: (3000, 224, 224, 3)

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (3000, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
pip install keras_applications
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
from keras_applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
from keras.layers import Input, Convolution2D, MaxPooling2D, Activation, concatenate, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.utils import get_file
#from keras.utils import layer_utils

sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"

WEIGHTS_PATH = "https://github.com/rcmalli/keras-squeezenet/releases/download/v1.0/squeezenet_weights_tf_dim_ordering_tf_kernels.h5"

# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3

    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


# Original SqueezeNet from paper.

def SqueezeNet(input_tensor=None, input_shape=None,
               weights='imagenet',
               classes=1000,
              use_bn_on_input = False, # to avoid preprocessing
               first_stride = 2
              ):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')


    input_shape = _obtain_input_shape(input_shape,
                                      default_size=224,
                                      min_size=48,
                                      data_format=K.image_data_format(),
                                     require_flatten = False)

    if input_tensor is None:
        raw_img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if use_bn_on_input:
        img_input = BatchNormalization()(raw_img_input)
    else:
        img_input = raw_img_input


    x = Convolution2D(64, (3, 3), strides=(first_stride, first_stride), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    #x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    #x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    #x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    #x = fire_module(x, fire_id=9, squeeze=64, expand=256)
    x = Dropout(0.5, name='drop9')(x)

    x = Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = Activation('relu', name='relu_conv10')(x)
    x = GlobalAveragePooling2D()(x)
    out = Activation('softmax', name='loss')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = raw_img_input

    model = Model(inputs, out, name='squeezenet')

    # load weights
    if weights == 'imagenet':

        weights_path = get_file('squeezenet_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model

# %%
X_train.shape[0:]
# Out:
# (2400, 224, 224, 3)

# %%
model = SqueezeNet(input_shape = (X_train.shape[1:]), weights = None, classes = Y_train.shape[1],
                  use_bn_on_input = True)
# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.Adam(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
loss_history = []
model.summary()
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  batch_normalization (Batch  (None, 224, 224, 3)          12        ['input_1[0][0]']
#  Normalization)
#
#  conv1 (Conv2D)              (None, 111, 111, 64)         1792      ['batch_normalization[0][0]']
#
#  relu_conv1 (Activation)     (None, 111, 111, 64)         0         ['conv1[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 55, 55, 64)           0         ['relu_conv1[0][0]']
#
#  fire2/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           1040      ['pool1[0][0]']
#
#  fire2/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire2/squeeze1x1[0][0]']
#  ivation)
#
#  fire2/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire2/expand1x1[0][0]']
#  vation)
#
#  fire2/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire2/expand3x3[0][0]']
#  vation)
#
#  fire2/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire2/relu_expand1x1[0][0]',
#                                                                      'fire2/relu_expand3x3[0][0]']
#
#  fire3/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           2064      ['fire2/concat[0][0]']
#
#  fire3/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire3/squeeze1x1[0][0]']
#  ivation)
#
#  fire3/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire3/expand1x1[0][0]']
#  vation)
#
#  fire3/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire3/expand3x3[0][0]']
#  vation)
#
#  fire3/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire3/relu_expand1x1[0][0]',
#                                                                      'fire3/relu_expand3x3[0][0]']
#
#  pool3 (MaxPooling2D)        (None, 27, 27, 128)          0         ['fire3/concat[0][0]']
#
#  fire4/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           4128      ['pool3[0][0]']
#
#  fire4/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire4/squeeze1x1[0][0]']
#  ivation)
#
#  fire4/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire4/expand1x1[0][0]']
#  vation)
#
#  fire4/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire4/expand3x3[0][0]']
#  vation)
#
#  fire4/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire4/relu_expand1x1[0][0]',
#                                                                      'fire4/relu_expand3x3[0][0]']
#
#  fire5/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           8224      ['fire4/concat[0][0]']
#
#  fire5/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire5/squeeze1x1[0][0]']
#  ivation)
#
#  fire5/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire5/expand1x1[0][0]']
#  vation)
#
#  fire5/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire5/expand3x3[0][0]']
#  vation)
#
#  fire5/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire5/relu_expand1x1[0][0]',
#                                                                      'fire5/relu_expand3x3[0][0]']
#
#  pool5 (MaxPooling2D)        (None, 13, 13, 256)          0         ['fire5/concat[0][0]']
#
#  drop9 (Dropout)             (None, 13, 13, 256)          0         ['pool5[0][0]']
#
#  conv10 (Conv2D)             (None, 13, 13, 3)            771       ['drop9[0][0]']
#
#  relu_conv10 (Activation)    (None, 13, 13, 3)            0         ['conv10[0][0]']
#
#  global_average_pooling2d (  (None, 3)                    0         ['relu_conv10[0][0]']
#  GlobalAveragePooling2D)
#
#  loss (Activation)           (None, 3)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 121199 (473.43 KB)
# Trainable params: 121193 (473.41 KB)
# Non-trainable params: 6 (24.00 Byte)
# __________________________________________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
keras.utils.plot_model(model, show_shapes = True)

# %%
EPOCHS = 150
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist=model.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/150
# 38/38 [==============================] - ETA: 0s - loss: 1.0824 - accuracy: 0.3262
# Epoch 1: val_accuracy improved from -inf to 0.36167, saving model to best_model.h5
# 38/38 [==============================] - 16s 142ms/step - loss: 1.0824 - accuracy: 0.3262 - val_loss: 1.0834 - val_accuracy: 0.3617
# Epoch 2/150
#  1/38 [..............................] - ETA: 3s - loss: 1.0357 - accuracy: 0.3438
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 37/38 [============================>.] - ETA: 0s - loss: 0.9534 - accuracy: 0.4755
# Epoch 2: val_accuracy improved from 0.36167 to 0.55167, saving model to best_model.h5
# 38/38 [==============================] - 4s 99ms/step - loss: 0.9511 - accuracy: 0.4787 - val_loss: 1.0351 - val_accuracy: 0.5517
# Epoch 3/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.6428 - accuracy: 0.7927
# Epoch 3: val_accuracy improved from 0.55167 to 0.59667, saving model to best_model.h5
# 38/38 [==============================] - 4s 98ms/step - loss: 0.6401 - accuracy: 0.7937 - val_loss: 0.8347 - val_accuracy: 0.5967
# Epoch 4/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.4109 - accuracy: 0.8552
# Epoch 4: val_accuracy improved from 0.59667 to 0.67167, saving model to best_model.h5
# 38/38 [==============================] - 4s 99ms/step - loss: 0.4100 - accuracy: 0.8550 - val_loss: 0.7244 - val_accuracy: 0.6717
# Epoch 5/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.3366 - accuracy: 0.8708
# Epoch 5: val_accuracy improved from 0.67167 to 0.78667, saving model to best_model.h5
# 38/38 [==============================] - 4s 99ms/step - loss: 0.3361 - accuracy: 0.8704 - val_loss: 0.5821 - val_accuracy: 0.7867
# Epoch 6/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.3074 - accuracy: 0.8843
# Epoch 6: val_accuracy improved from 0.78667 to 0.83333, saving model to best_model.h5
# 38/38 [==============================] - 4s 99ms/step - loss: 0.3083 - accuracy: 0.8842 - val_loss: 0.4692 - val_accuracy: 0.8333
# Epoch 7/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.2716 - accuracy: 0.9020
# Epoch 7: val_accuracy improved from 0.83333 to 0.86167, saving model to best_model.h5
# 38/38 [==============================] - 4s 99ms/step - loss: 0.2729 - accuracy: 0.9008 - val_loss: 0.4059 - val_accuracy: 0.8617
# Epoch 8/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.2503 - accuracy: 0.9143
# Epoch 8: val_accuracy improved from 0.86167 to 0.89333, saving model to best_model.h5
# 38/38 [==============================] - 4s 99ms/step - loss: 0.2495 - accuracy: 0.9146 - val_loss: 0.3223 - val_accuracy: 0.8933
# Epoch 9/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.2330 - accuracy: 0.9147
# Epoch 9: val_accuracy did not improve from 0.89333
# 38/38 [==============================] - 4s 99ms/step - loss: 0.2345 - accuracy: 0.9137 - val_loss: 0.3169 - val_accuracy: 0.8933
# Epoch 10/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.2075 - accuracy: 0.9227
# Epoch 10: val_accuracy improved from 0.89333 to 0.90333, saving model to best_model.h5
# 38/38 [==============================] - 4s 100ms/step - loss: 0.2079 - accuracy: 0.9233 - val_loss: 0.2939 - val_accuracy: 0.9033
# Epoch 11/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1856 - accuracy: 0.9345
# Epoch 11: val_accuracy improved from 0.90333 to 0.91500, saving model to best_model.h5
# 38/38 [==============================] - 4s 100ms/step - loss: 0.1862 - accuracy: 0.9342 - val_loss: 0.2269 - val_accuracy: 0.9150
# Epoch 12/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1692 - accuracy: 0.9400
# Epoch 12: val_accuracy improved from 0.91500 to 0.92167, saving model to best_model.h5
# 38/38 [==============================] - 4s 100ms/step - loss: 0.1712 - accuracy: 0.9392 - val_loss: 0.2053 - val_accuracy: 0.9217
# Epoch 13/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1544 - accuracy: 0.9443
# Epoch 13: val_accuracy improved from 0.92167 to 0.92667, saving model to best_model.h5
# 38/38 [==============================] - 4s 100ms/step - loss: 0.1550 - accuracy: 0.9442 - val_loss: 0.1918 - val_accuracy: 0.9267
# Epoch 14/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1483 - accuracy: 0.9459
# Epoch 14: val_accuracy improved from 0.92667 to 0.93833, saving model to best_model.h5
# 38/38 [==============================] - 4s 101ms/step - loss: 0.1484 - accuracy: 0.9458 - val_loss: 0.1434 - val_accuracy: 0.9383
# Epoch 15/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1359 - accuracy: 0.9489
# Epoch 15: val_accuracy improved from 0.93833 to 0.94167, saving model to best_model.h5
# 38/38 [==============================] - 4s 100ms/step - loss: 0.1359 - accuracy: 0.9488 - val_loss: 0.1320 - val_accuracy: 0.9417
# Epoch 16/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1315 - accuracy: 0.9548
# Epoch 16: val_accuracy did not improve from 0.94167
# 38/38 [==============================] - 4s 99ms/step - loss: 0.1309 - accuracy: 0.9550 - val_loss: 0.1341 - val_accuracy: 0.9383
# Epoch 17/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1351 - accuracy: 0.9464
# Epoch 17: val_accuracy did not improve from 0.94167
# 38/38 [==============================] - 4s 99ms/step - loss: 0.1337 - accuracy: 0.9471 - val_loss: 0.1368 - val_accuracy: 0.9350
# Epoch 18/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1103 - accuracy: 0.9586
# Epoch 18: val_accuracy did not improve from 0.94167
# 38/38 [==============================] - 4s 99ms/step - loss: 0.1105 - accuracy: 0.9588 - val_loss: 0.1180 - val_accuracy: 0.9417
# Epoch 19/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1130 - accuracy: 0.9569
# Epoch 19: val_accuracy improved from 0.94167 to 0.94500, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.1127 - accuracy: 0.9571 - val_loss: 0.1127 - val_accuracy: 0.9450
# Epoch 20/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1086 - accuracy: 0.9603
# Epoch 20: val_accuracy did not improve from 0.94500
# 38/38 [==============================] - 4s 99ms/step - loss: 0.1100 - accuracy: 0.9588 - val_loss: 0.1292 - val_accuracy: 0.9433
# Epoch 21/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9645
# Epoch 21: val_accuracy improved from 0.94500 to 0.95667, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0990 - accuracy: 0.9642 - val_loss: 0.1055 - val_accuracy: 0.9567
# Epoch 22/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0995 - accuracy: 0.9637
# Epoch 22: val_accuracy did not improve from 0.95667
# 38/38 [==============================] - 4s 100ms/step - loss: 0.1029 - accuracy: 0.9621 - val_loss: 0.1190 - val_accuracy: 0.9483
# Epoch 23/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1054 - accuracy: 0.9620
# Epoch 23: val_accuracy did not improve from 0.95667
# 38/38 [==============================] - 4s 101ms/step - loss: 0.1049 - accuracy: 0.9625 - val_loss: 0.1683 - val_accuracy: 0.9317
# Epoch 24/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9611
# Epoch 24: val_accuracy did not improve from 0.95667
# 38/38 [==============================] - 4s 101ms/step - loss: 0.1098 - accuracy: 0.9604 - val_loss: 0.0964 - val_accuracy: 0.9567
# Epoch 25/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9645
# Epoch 25: val_accuracy did not improve from 0.95667
# 38/38 [==============================] - 4s 100ms/step - loss: 0.1028 - accuracy: 0.9646 - val_loss: 0.0860 - val_accuracy: 0.9533
# Epoch 26/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0802 - accuracy: 0.9700
# Epoch 26: val_accuracy improved from 0.95667 to 0.96333, saving model to best_model.h5
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0801 - accuracy: 0.9704 - val_loss: 0.0930 - val_accuracy: 0.9633
# Epoch 27/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0847 - accuracy: 0.9683
# Epoch 27: val_accuracy improved from 0.96333 to 0.96667, saving model to best_model.h5
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0841 - accuracy: 0.9688 - val_loss: 0.0773 - val_accuracy: 0.9667
# Epoch 28/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0726 - accuracy: 0.9721
# Epoch 28: val_accuracy did not improve from 0.96667
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0728 - accuracy: 0.9721 - val_loss: 0.0854 - val_accuracy: 0.9617
# Epoch 29/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9759
# Epoch 29: val_accuracy improved from 0.96667 to 0.97167, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0779 - accuracy: 0.9762 - val_loss: 0.0668 - val_accuracy: 0.9717
# Epoch 30/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0676 - accuracy: 0.9764
# Epoch 30: val_accuracy did not improve from 0.97167
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0683 - accuracy: 0.9762 - val_loss: 0.0759 - val_accuracy: 0.9650
# Epoch 31/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0785 - accuracy: 0.9692
# Epoch 31: val_accuracy did not improve from 0.97167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0820 - accuracy: 0.9679 - val_loss: 0.0676 - val_accuracy: 0.9717
# Epoch 32/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9755
# Epoch 32: val_accuracy improved from 0.97167 to 0.97333, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0689 - accuracy: 0.9758 - val_loss: 0.0580 - val_accuracy: 0.9733
# Epoch 33/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0574 - accuracy: 0.9810
# Epoch 33: val_accuracy improved from 0.97333 to 0.97500, saving model to best_model.h5
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0568 - accuracy: 0.9812 - val_loss: 0.0573 - val_accuracy: 0.9750
# Epoch 34/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9764
# Epoch 34: val_accuracy did not improve from 0.97500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0662 - accuracy: 0.9767 - val_loss: 0.0520 - val_accuracy: 0.9750
# Epoch 35/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0531 - accuracy: 0.9835
# Epoch 35: val_accuracy improved from 0.97500 to 0.97833, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0538 - accuracy: 0.9829 - val_loss: 0.0614 - val_accuracy: 0.9783
# Epoch 36/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0578 - accuracy: 0.9806
# Epoch 36: val_accuracy did not improve from 0.97833
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0573 - accuracy: 0.9808 - val_loss: 0.0714 - val_accuracy: 0.9767
# Epoch 37/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0557 - accuracy: 0.9806
# Epoch 37: val_accuracy improved from 0.97833 to 0.98000, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0559 - accuracy: 0.9804 - val_loss: 0.0484 - val_accuracy: 0.9800
# Epoch 38/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9856
# Epoch 38: val_accuracy did not improve from 0.98000
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0447 - accuracy: 0.9858 - val_loss: 0.0626 - val_accuracy: 0.9750
# Epoch 39/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9793
# Epoch 39: val_accuracy improved from 0.98000 to 0.98167, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0534 - accuracy: 0.9796 - val_loss: 0.0446 - val_accuracy: 0.9817
# Epoch 40/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9848
# Epoch 40: val_accuracy did not improve from 0.98167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0463 - accuracy: 0.9842 - val_loss: 0.0636 - val_accuracy: 0.9783
# Epoch 41/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9852
# Epoch 41: val_accuracy did not improve from 0.98167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0516 - accuracy: 0.9846 - val_loss: 0.0448 - val_accuracy: 0.9800
# Epoch 42/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0454 - accuracy: 0.9869
# Epoch 42: val_accuracy improved from 0.98167 to 0.98667, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0455 - accuracy: 0.9867 - val_loss: 0.0387 - val_accuracy: 0.9867
# Epoch 43/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0389 - accuracy: 0.9856
# Epoch 43: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0389 - accuracy: 0.9858 - val_loss: 0.0440 - val_accuracy: 0.9850
# Epoch 44/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9852
# Epoch 44: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0481 - accuracy: 0.9846 - val_loss: 0.0402 - val_accuracy: 0.9817
# Epoch 45/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0412 - accuracy: 0.9852
# Epoch 45: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0406 - accuracy: 0.9854 - val_loss: 0.0598 - val_accuracy: 0.9750
# Epoch 46/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9831
# Epoch 46: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0499 - accuracy: 0.9821 - val_loss: 0.0382 - val_accuracy: 0.9800
# Epoch 47/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0484 - accuracy: 0.9878
# Epoch 47: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0484 - accuracy: 0.9875 - val_loss: 0.0432 - val_accuracy: 0.9867
# Epoch 48/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0394 - accuracy: 0.9844
# Epoch 48: val_accuracy did not improve from 0.98667
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0391 - accuracy: 0.9846 - val_loss: 0.0527 - val_accuracy: 0.9833
# Epoch 49/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0338 - accuracy: 0.9907
# Epoch 49: val_accuracy improved from 0.98667 to 0.99000, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0338 - accuracy: 0.9908 - val_loss: 0.0397 - val_accuracy: 0.9900
# Epoch 50/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9861
# Epoch 50: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0410 - accuracy: 0.9862 - val_loss: 0.0494 - val_accuracy: 0.9800
# Epoch 51/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0400 - accuracy: 0.9878
# Epoch 51: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0400 - accuracy: 0.9879 - val_loss: 0.0292 - val_accuracy: 0.9900
# Epoch 52/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9899
# Epoch 52: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0325 - accuracy: 0.9900 - val_loss: 0.0411 - val_accuracy: 0.9817
# Epoch 53/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9916
# Epoch 53: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0320 - accuracy: 0.9917 - val_loss: 0.0321 - val_accuracy: 0.9867
# Epoch 54/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0405 - accuracy: 0.9869
# Epoch 54: val_accuracy did not improve from 0.99000
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0420 - accuracy: 0.9862 - val_loss: 0.0497 - val_accuracy: 0.9800
# Epoch 55/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0446 - accuracy: 0.9852
# Epoch 55: val_accuracy improved from 0.99000 to 0.99167, saving model to best_model.h5
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0441 - accuracy: 0.9854 - val_loss: 0.0327 - val_accuracy: 0.9917
# Epoch 56/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9873
# Epoch 56: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0369 - accuracy: 0.9871 - val_loss: 0.0526 - val_accuracy: 0.9783
# Epoch 57/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0343 - accuracy: 0.9903
# Epoch 57: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0349 - accuracy: 0.9900 - val_loss: 0.0352 - val_accuracy: 0.9850
# Epoch 58/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9920
# Epoch 58: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0276 - accuracy: 0.9912 - val_loss: 0.0309 - val_accuracy: 0.9900
# Epoch 59/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0360 - accuracy: 0.9873
# Epoch 59: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0356 - accuracy: 0.9875 - val_loss: 0.0394 - val_accuracy: 0.9850
# Epoch 60/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0365 - accuracy: 0.9882
# Epoch 60: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.0263 - val_accuracy: 0.9900
# Epoch 61/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9875
# Epoch 61: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0362 - accuracy: 0.9875 - val_loss: 0.0273 - val_accuracy: 0.9917
# Epoch 62/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9903
# Epoch 62: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0308 - accuracy: 0.9904 - val_loss: 0.0319 - val_accuracy: 0.9917
# Epoch 63/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9886
# Epoch 63: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0310 - accuracy: 0.9887 - val_loss: 0.0265 - val_accuracy: 0.9900
# Epoch 64/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0367 - accuracy: 0.9878
# Epoch 64: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0363 - accuracy: 0.9879 - val_loss: 0.0560 - val_accuracy: 0.9767
# Epoch 65/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0287 - accuracy: 0.9907
# Epoch 65: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0287 - accuracy: 0.9908 - val_loss: 0.0378 - val_accuracy: 0.9883
# Epoch 66/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0275 - accuracy: 0.9907
# Epoch 66: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0273 - accuracy: 0.9908 - val_loss: 0.0359 - val_accuracy: 0.9867
# Epoch 67/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9920
# Epoch 67: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0287 - accuracy: 0.9921 - val_loss: 0.0305 - val_accuracy: 0.9883
# Epoch 68/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0413 - accuracy: 0.9856
# Epoch 68: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0414 - accuracy: 0.9854 - val_loss: 0.0564 - val_accuracy: 0.9800
# Epoch 69/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.9882
# Epoch 69: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0328 - accuracy: 0.9883 - val_loss: 0.0456 - val_accuracy: 0.9850
# Epoch 70/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0280 - accuracy: 0.9907
# Epoch 70: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0282 - accuracy: 0.9904 - val_loss: 0.0358 - val_accuracy: 0.9867
# Epoch 71/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9865
# Epoch 71: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0393 - accuracy: 0.9867 - val_loss: 0.0527 - val_accuracy: 0.9800
# Epoch 72/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9907
# Epoch 72: val_accuracy did not improve from 0.99167
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0318 - accuracy: 0.9904 - val_loss: 0.0250 - val_accuracy: 0.9900
# Epoch 73/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9920
# Epoch 73: val_accuracy improved from 0.99167 to 0.99333, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0283 - accuracy: 0.9912 - val_loss: 0.0247 - val_accuracy: 0.9933
# Epoch 74/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0385 - accuracy: 0.9865
# Epoch 74: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0382 - accuracy: 0.9867 - val_loss: 0.0563 - val_accuracy: 0.9800
# Epoch 75/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0280 - accuracy: 0.9911
# Epoch 75: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 0.0246 - val_accuracy: 0.9917
# Epoch 76/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9937
# Epoch 76: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0233 - accuracy: 0.9937 - val_loss: 0.0396 - val_accuracy: 0.9850
# Epoch 77/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0255 - accuracy: 0.9907
# Epoch 77: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0288 - accuracy: 0.9900 - val_loss: 0.0222 - val_accuracy: 0.9933
# Epoch 78/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9958
# Epoch 78: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0231 - accuracy: 0.9958 - val_loss: 0.0302 - val_accuracy: 0.9900
# Epoch 79/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0241 - accuracy: 0.9928
# Epoch 79: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 108ms/step - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.0307 - val_accuracy: 0.9883
# Epoch 80/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9894
# Epoch 80: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0320 - accuracy: 0.9896 - val_loss: 0.0285 - val_accuracy: 0.9917
# Epoch 81/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9932
# Epoch 81: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0209 - accuracy: 0.9933 - val_loss: 0.0272 - val_accuracy: 0.9900
# Epoch 82/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0251 - accuracy: 0.9920
# Epoch 82: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0258 - accuracy: 0.9912 - val_loss: 0.0303 - val_accuracy: 0.9883
# Epoch 83/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9886
# Epoch 83: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0332 - accuracy: 0.9887 - val_loss: 0.0487 - val_accuracy: 0.9817
# Epoch 84/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9941
# Epoch 84: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0225 - accuracy: 0.9942 - val_loss: 0.0481 - val_accuracy: 0.9817
# Epoch 85/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0286 - accuracy: 0.9916
# Epoch 85: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0284 - accuracy: 0.9917 - val_loss: 0.0608 - val_accuracy: 0.9750
# Epoch 86/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9903
# Epoch 86: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0270 - accuracy: 0.9904 - val_loss: 0.0218 - val_accuracy: 0.9933
# Epoch 87/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9916
# Epoch 87: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0231 - accuracy: 0.9912 - val_loss: 0.0779 - val_accuracy: 0.9733
# Epoch 88/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0242 - accuracy: 0.9911
# Epoch 88: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0239 - accuracy: 0.9912 - val_loss: 0.0246 - val_accuracy: 0.9933
# Epoch 89/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 0.9920
# Epoch 89: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0216 - accuracy: 0.9921 - val_loss: 0.0331 - val_accuracy: 0.9883
# Epoch 90/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9937
# Epoch 90: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.0406 - val_accuracy: 0.9783
# Epoch 91/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9899
# Epoch 91: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0263 - accuracy: 0.9900 - val_loss: 0.0254 - val_accuracy: 0.9933
# Epoch 92/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9949
# Epoch 92: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0179 - accuracy: 0.9950 - val_loss: 0.0221 - val_accuracy: 0.9917
# Epoch 93/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0261 - accuracy: 0.9899
# Epoch 93: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0258 - accuracy: 0.9900 - val_loss: 0.0394 - val_accuracy: 0.9867
# Epoch 94/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9882
# Epoch 94: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0312 - accuracy: 0.9879 - val_loss: 0.0297 - val_accuracy: 0.9900
# Epoch 95/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9903
# Epoch 95: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0311 - accuracy: 0.9904 - val_loss: 0.0302 - val_accuracy: 0.9900
# Epoch 96/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9945
# Epoch 96: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0194 - accuracy: 0.9946 - val_loss: 0.0270 - val_accuracy: 0.9917
# Epoch 97/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9907
# Epoch 97: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0227 - accuracy: 0.9908 - val_loss: 0.0227 - val_accuracy: 0.9933
# Epoch 98/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0143 - accuracy: 0.9958
# Epoch 98: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 0.0297 - val_accuracy: 0.9900
# Epoch 99/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0150 - accuracy: 0.9937
# Epoch 99: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0148 - accuracy: 0.9937 - val_loss: 0.0206 - val_accuracy: 0.9933
# Epoch 100/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9873
# Epoch 100: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0332 - accuracy: 0.9875 - val_loss: 0.1074 - val_accuracy: 0.9700
# Epoch 101/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9890
# Epoch 101: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0373 - accuracy: 0.9892 - val_loss: 0.0379 - val_accuracy: 0.9867
# Epoch 102/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9937
# Epoch 102: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.0211 - val_accuracy: 0.9917
# Epoch 103/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9954
# Epoch 103: val_accuracy did not improve from 0.99333
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.0411 - val_accuracy: 0.9850
# Epoch 104/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9954
# Epoch 104: val_accuracy improved from 0.99333 to 0.99500, saving model to best_model.h5
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0181 - accuracy: 0.9954 - val_loss: 0.0217 - val_accuracy: 0.9950
# Epoch 105/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0150 - accuracy: 0.9954
# Epoch 105: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.0491 - val_accuracy: 0.9817
# Epoch 106/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9894
# Epoch 106: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0266 - accuracy: 0.9896 - val_loss: 0.0655 - val_accuracy: 0.9750
# Epoch 107/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.9928
# Epoch 107: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0276 - accuracy: 0.9929 - val_loss: 0.0255 - val_accuracy: 0.9900
# Epoch 108/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9954
# Epoch 108: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.0338 - val_accuracy: 0.9883
# Epoch 109/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0276 - accuracy: 0.9903
# Epoch 109: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0315 - accuracy: 0.9887 - val_loss: 0.0378 - val_accuracy: 0.9817
# Epoch 110/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0330 - accuracy: 0.9878
# Epoch 110: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0326 - accuracy: 0.9879 - val_loss: 0.0223 - val_accuracy: 0.9933
# Epoch 111/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9954
# Epoch 111: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0415 - val_accuracy: 0.9817
# Epoch 112/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 0.9920
# Epoch 112: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0252 - accuracy: 0.9917 - val_loss: 0.0325 - val_accuracy: 0.9867
# Epoch 113/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9941
# Epoch 113: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 0.0183 - val_accuracy: 0.9933
# Epoch 114/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9937
# Epoch 114: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0175 - accuracy: 0.9929 - val_loss: 0.0244 - val_accuracy: 0.9917
# Epoch 115/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9945
# Epoch 115: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0140 - accuracy: 0.9946 - val_loss: 0.0313 - val_accuracy: 0.9883
# Epoch 116/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0294 - accuracy: 0.9903
# Epoch 116: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0292 - accuracy: 0.9904 - val_loss: 0.0339 - val_accuracy: 0.9867
# Epoch 117/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9941
# Epoch 117: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0180 - accuracy: 0.9942 - val_loss: 0.0462 - val_accuracy: 0.9833
# Epoch 118/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 0.9954
# Epoch 118: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0159 - accuracy: 0.9954 - val_loss: 0.0216 - val_accuracy: 0.9933
# Epoch 119/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9958
# Epoch 119: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0190 - val_accuracy: 0.9933
# Epoch 120/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9886
# Epoch 120: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0283 - accuracy: 0.9883 - val_loss: 0.0173 - val_accuracy: 0.9950
# Epoch 121/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9949
# Epoch 121: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0149 - accuracy: 0.9946 - val_loss: 0.0302 - val_accuracy: 0.9900
# Epoch 122/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0198 - accuracy: 0.9932
# Epoch 122: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0196 - accuracy: 0.9933 - val_loss: 0.0196 - val_accuracy: 0.9933
# Epoch 123/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 0.9962
# Epoch 123: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0370 - val_accuracy: 0.9883
# Epoch 124/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9958
# Epoch 124: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0149 - accuracy: 0.9954 - val_loss: 0.0187 - val_accuracy: 0.9933
# Epoch 125/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9924
# Epoch 125: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0228 - accuracy: 0.9925 - val_loss: 0.0270 - val_accuracy: 0.9917
# Epoch 126/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0207 - accuracy: 0.9954
# Epoch 126: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0205 - accuracy: 0.9954 - val_loss: 0.0171 - val_accuracy: 0.9933
# Epoch 127/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9945
# Epoch 127: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.0338 - val_accuracy: 0.9900
# Epoch 128/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9966
# Epoch 128: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.0174 - val_accuracy: 0.9950
# Epoch 129/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9949
# Epoch 129: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0127 - accuracy: 0.9950 - val_loss: 0.0331 - val_accuracy: 0.9900
# Epoch 130/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0138 - accuracy: 0.9958
# Epoch 130: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.0183 - val_accuracy: 0.9933
# Epoch 131/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 0.9954
# Epoch 131: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0171 - val_accuracy: 0.9933
# Epoch 132/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9907
# Epoch 132: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0246 - accuracy: 0.9908 - val_loss: 0.0285 - val_accuracy: 0.9883
# Epoch 133/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9928
# Epoch 133: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.0630 - val_accuracy: 0.9767
# Epoch 134/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9924
# Epoch 134: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0264 - accuracy: 0.9925 - val_loss: 0.0286 - val_accuracy: 0.9917
# Epoch 135/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9970
# Epoch 135: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0129 - accuracy: 0.9971 - val_loss: 0.0187 - val_accuracy: 0.9950
# Epoch 136/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0147 - accuracy: 0.9954
# Epoch 136: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.0178 - val_accuracy: 0.9933
# Epoch 137/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9958
# Epoch 137: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0164 - val_accuracy: 0.9933
# Epoch 138/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9975
# Epoch 138: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0173 - val_accuracy: 0.9933
# Epoch 139/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9941
# Epoch 139: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0155 - accuracy: 0.9942 - val_loss: 0.0478 - val_accuracy: 0.9800
# Epoch 140/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9932
# Epoch 140: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0200 - accuracy: 0.9925 - val_loss: 0.0375 - val_accuracy: 0.9867
# Epoch 141/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 0.9928
# Epoch 141: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0221 - accuracy: 0.9925 - val_loss: 0.0250 - val_accuracy: 0.9950
# Epoch 142/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 0.9941
# Epoch 142: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 0.0169 - val_accuracy: 0.9933
# Epoch 143/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9979
# Epoch 143: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.0160 - val_accuracy: 0.9933
# Epoch 144/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9958
# Epoch 144: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0108 - accuracy: 0.9958 - val_loss: 0.0179 - val_accuracy: 0.9933
# Epoch 145/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9966
# Epoch 145: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0257 - val_accuracy: 0.9917
# Epoch 146/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9966
# Epoch 146: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0153 - accuracy: 0.9967 - val_loss: 0.0178 - val_accuracy: 0.9950
# Epoch 147/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9941
# Epoch 147: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.0293 - val_accuracy: 0.9883
# Epoch 148/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9941
# Epoch 148: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0153 - accuracy: 0.9942 - val_loss: 0.0181 - val_accuracy: 0.9950
# Epoch 149/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9983
# Epoch 149: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0282 - val_accuracy: 0.9900
# Epoch 150/150
# 37/38 [============================>.] - ETA: 0s - loss: 0.0366 - accuracy: 0.9865
# Epoch 150: val_accuracy did not improve from 0.99500
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0363 - accuracy: 0.9867 - val_loss: 0.0728 - val_accuracy: 0.9783

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 19/19 [==============================] - 1s 14ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("SquezeNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# SquezeNet MODEL SONUÇLARI
# Doğruluk:  0.995
# F1_Skor:  0.995019748206048
# Hassasiyet:  0.9951733287752628
# Duyarlılık:  0.9949238578680203

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[217   0   0]
#  [  2 194   1]
#  [  0   0 186]]
# <Axes: >
